# %%
import pandas as pd
df = pd.read_csv('MACCSkeys_descriptors.csv')
df2 = df.iloc[:,13:].dropna()
y = df2.iloc[:,0]
X = df2.iloc[:,1:]

# %%
import numpy as np
from sklearn.model_selection import cross_val_score, GridSearchCV, RepeatedKFold
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0, 0.2, 0.4, 0.5, 0.6, 0.8, 1],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },    
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10, 15],
        'randomforestregressor__min_samples_leaf': [1, 2, 5],
    },
    "SVR": {
        'svr__C': [0.01, 0.1, 1, 10, 100],
        'svr__epsilon': [0.5, 1.0, 2.0],
        'svr__kernel': ['rbf', 'linear'],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [2, 5, 10],
        'xgbregressor__n_estimators': [50, 100, 200],
        'xgbregressor__subsample': [0.6, 0.8, 1.0],
        'xgbregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "LightGBM": {
        'lgbmregressor__n_estimators': [50, 100, 200],
        'lgbmregressor__max_depth': [3, 5, 7],
        'lgbmregressor__learning_rate': [0.01, 0.05, 0.1],
        'lgbmregressor__subsample': [0.6, 0.8, 1.0],
        'lgbmregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1, 0.2],
        "histgradientboostingregressor__max_depth": [1, 3, 5, 7],
        "histgradientboostingregressor__max_iter": [100, 200],
        "histgradientboostingregressor__l2_regularization": [0.0, 0.1, 1.0],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7, 10],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__metric': ['euclidean', 'manhattan'],
        'kneighborsregressor__p': [1, 2]
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,), (50, 20)],
        'mlpregressor__alpha': [1e-4, 1e-3, 1e-2],
        'mlpregressor__learning_rate_init': [0.0001, 0.001, 0.01],
    }
}

# モデルの設定
models = {
    "Linear": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "ElasticNet": ElasticNet(max_iter=10000),
    "PolyRidge": make_pipeline( PCA(n_components=20), PolynomialFeatures(), StandardScaler(), Ridge()),
    "RandomForest": RandomForestRegressor(),
    "SVR": SVR(),
    "XGBoost": XGBRegressor(verbosity=0, n_jobs=-1),
    "LightGBM": LGBMRegressor(verbose=-1, n_jobs=-1),
    "HistGB": HistGradientBoostingRegressor(early_stopping=True, n_jobs=-1),
    "KNN": KNeighborsRegressor(),
    "MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1, n_jobs=-1)
}

n_repeats = 10
outer_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)
    if name in param_grids:
        grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
        nested_scores = cross_val_score(grid, X, y, cv=outer_cv, scoring='r2', n_jobs=-1)
        print(f"{name} - nested CV R2(test, average): {nested_scores.mean():.3f}")
        grid.fit(X, y)
        print(f"{name} - Best Params used by all data: {grid.best_params_}")
        
    else:
        # case of Linear
        scores = cross_val_score(pipeline, X, y, cv=outer_cv, scoring='r2', n_jobs=-1)
        print(f"{name} - outer-CV R2-score(test, average): {scores.mean():.3f}")
# Out:
# Linear - outer-CV R2-score(test, average): 0.506
# Lasso - nested CV R2(test, average): 0.475
# Lasso - Best Params used by all data: {'lasso__alpha': 0.01}
# Ridge - nested CV R2(test, average): 0.487
# Ridge - Best Params used by all data: {'ridge__alpha': 10}
# ElasticNet - nested CV R2(test, average): 0.481
# ElasticNet - Best Params used by all data: {'elasticnet__alpha': 0.01, 'elasticnet__l1_ratio': 1}
# PolyRidge - nested CV R2(test, average): 0.337
# PolyRidge - Best Params used by all data: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}
# RandomForest - nested CV R2(test, average): 0.477
# RandomForest - Best Params used by all data: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}
# SVR - nested CV R2(test, average): 0.460
# SVR - Best Params used by all data: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}
# XGBoost - nested CV R2(test, average): 0.497
# XGBoost - Best Params used by all data: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}
# LightGBM - nested CV R2(test, average): 0.458
# LightGBM - Best Params used by all data: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}
# HistGB - nested CV R2(test, average): 0.385
# HistGB - Best Params used by all data: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 200}
# KNN - nested CV R2(test, average): 0.089
# KNN - Best Params used by all data: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}
# MLP - nested CV R2(test, average): 0.112
# MLP - Best Params used by all data: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}

# %%
import numpy as np
from sklearn.model_selection import cross_val_score, GridSearchCV, RepeatedKFold
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0, 0.2, 0.4, 0.5, 0.6, 0.8, 1],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },    
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10, 15],
        'randomforestregressor__min_samples_leaf': [1, 2, 5],
    },
    "SVR": {
        'svr__C': [0.01, 0.1, 1, 10, 100],
        'svr__epsilon': [0.5, 1.0, 2.0],
        'svr__kernel': ['rbf', 'linear'],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [2, 5, 10],
        'xgbregressor__n_estimators': [50, 100, 200],
        'xgbregressor__subsample': [0.6, 0.8, 1.0],
        'xgbregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "LightGBM": {
        'lgbmregressor__n_estimators': [50, 100, 200],
        'lgbmregressor__max_depth': [3, 5, 7],
        'lgbmregressor__learning_rate': [0.01, 0.05, 0.1],
        'lgbmregressor__subsample': [0.6, 0.8, 1.0],
        'lgbmregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1, 0.2],
        "histgradientboostingregressor__max_depth": [1, 3, 5, 7],
        "histgradientboostingregressor__max_iter": [100, 200],
        "histgradientboostingregressor__l2_regularization": [0.0, 0.1, 1.0],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7, 10],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__metric': ['euclidean', 'manhattan'],
        'kneighborsregressor__p': [1, 2]
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,), (50, 20)],
        'mlpregressor__alpha': [1e-4, 1e-3, 1e-2],
        'mlpregressor__learning_rate_init': [0.0001, 0.001, 0.01],
    }
}

# モデルの設定
models = {
    "Linear": LinearRegression(),
    "Lasso": Lasso(max_iter=10000),
    "Ridge": Ridge(max_iter=10000),
    "ElasticNet": ElasticNet(max_iter=50000),
    "PolyRidge": make_pipeline( PCA(n_components=20), PolynomialFeatures(), StandardScaler(), Ridge()),
    "RandomForest": RandomForestRegressor(),
    "SVR": SVR(),
    "XGBoost": XGBRegressor(verbosity=0, n_jobs=-1),
    "LightGBM": LGBMRegressor(verbose=-1, n_jobs=-1),
    "HistGB": HistGradientBoostingRegressor(early_stopping=True),
    "KNN": KNeighborsRegressor(),
    "MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1)
}

n_repeats = 10
outer_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    print( '----------', name, '----------\nparams, R2(train), R2(test)')
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)

    tot_train = []
    tot_test = []
    
    for train_idx, test_idx in outer_cv.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        if name in param_grids:
            grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
            grid.fit(X_train, y_train)
            
            y_train_pred = grid.predict(X_train)
            y_test_pred  = grid.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"inner CV: R2(test): {grid.best_score_:.3f}, params: {grid.best_params_}, outer CV R2(train):{train_r2:.3f}, R2(test):{test_r2:.3f}" )
        
        else:
            pipeline.fit(X_train, y_train)
            y_train_pred = pipeline.predict(X_train)
            y_test_pred  = pipeline.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
            
        tot_train.append(train_r2)
        tot_test.append(test_r2)
    
    print(f"[{name}] total result: R2(train) {np.mean(tot_train):.3f}, R2(test) {np.mean(tot_test):.3f}")
# Out:
# ---------- Linear ----------
# params, R2(train), R2(test)
# outer CV R2(train): 0.727, R2(test): 0.593
# outer CV R2(train): 0.747, R2(test): 0.512
# outer CV R2(train): 0.739, R2(test): 0.536
# outer CV R2(train): 0.723, R2(test): 0.550
# outer CV R2(train): 0.745, R2(test): 0.518
# outer CV R2(train): 0.752, R2(test): 0.487
# outer CV R2(train): 0.698, R2(test): 0.641
# outer CV R2(train): 0.757, R2(test): 0.503
# outer CV R2(train): 0.756, R2(test): 0.469
# outer CV R2(train): 0.706, R2(test): 0.600
# outer CV R2(train): 0.740, R2(test): 0.507
# outer CV R2(train): 0.791, R2(test): 0.389
# outer CV R2(train): 0.753, R2(test): 0.520
# outer CV R2(train): 0.716, R2(test): 0.568
# outer CV R2(train): 0.767, R2(test): 0.287
# outer CV R2(train): 0.693, R2(test): 0.536
# outer CV R2(train): 0.734, R2(test): 0.570
# outer CV R2(train): 0.782, R2(test): 0.312
# outer CV R2(train): 0.786, R2(test): 0.378
# outer CV R2(train): 0.708, R2(test): 0.630
# outer CV R2(train): 0.741, R2(test): 0.498
# outer CV R2(train): 0.741, R2(test): 0.531
# outer CV R2(train): 0.725, R2(test): 0.572
# outer CV R2(train): 0.744, R2(test): 0.580
# outer CV R2(train): 0.740, R2(test): 0.552
# outer CV R2(train): 0.757, R2(test): 0.129
# outer CV R2(train): 0.749, R2(test): 0.420
# outer CV R2(train): 0.704, R2(test): 0.629
# outer CV R2(train): 0.736, R2(test): 0.605
# outer CV R2(train): 0.758, R2(test): 0.549
# [Linear] total result: R2(train) 0.740, R2(test) 0.506
# ---------- Lasso ----------
# params, R2(train), R2(test)
# inner CV: R2(test, mean): 0.395, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.591, R2(test):0.529
# inner CV: R2(test, mean): 0.477, params: {'lasso__alpha': 0.01}, outer CV R2(train):0.743, R2(test):0.513
# inner CV: R2(test, mean): 0.441, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.651, R2(test):0.410
# inner CV: R2(test, mean): 0.380, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.595, R2(test):0.555
# inner CV: R2(test, mean): 0.499, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.641, R2(test):0.472
# inner CV: R2(test, mean): 0.475, params: {'lasso__alpha': 0.01}, outer CV R2(train):0.748, R2(test):0.498
# inner CV: R2(test, mean): 0.320, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.560, R2(test):0.590
# inner CV: R2(test, mean): 0.447, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.640, R2(test):0.452
# inner CV: R2(test, mean): 0.453, params: {'lasso__alpha': 0.01}, outer CV R2(train):0.752, R2(test):0.492
# inner CV: R2(test, mean): 0.368, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.571, R2(test):0.465
# inner CV: R2(test, mean): 0.427, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.615, R2(test):0.462
# inner CV: R2(test, mean): 0.539, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.692, R2(test):0.427
# inner CV: R2(test, mean): 0.487, params: {'lasso__alpha': 0.01}, outer CV R2(train):0.750, R2(test):0.515
# inner CV: R2(test, mean): 0.356, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.575, R2(test):0.498
# inner CV: R2(test, mean): 0.529, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.681, R2(test):0.221
# inner CV: R2(test, mean): 0.242, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.518, R2(test):0.447
# inner CV: R2(test, mean): 0.505, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.645, R2(test):0.468
# inner CV: R2(test, mean): 0.517, params: {'lasso__alpha': 0.01}, outer CV R2(train):0.776, R2(test):0.342
# inner CV: R2(test, mean): 0.425, params: {'lasso__alpha': 0.01}, outer CV R2(train):0.780, R2(test):0.394
# inner CV: R2(test, mean): 0.384, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.607, R2(test):0.493
# inner CV: R2(test, mean): 0.470, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.618, R2(test):0.490
# inner CV: R2(test, mean): 0.426, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.621, R2(test):0.522
# inner CV: R2(test, mean): 0.403, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.599, R2(test):0.579
# inner CV: R2(test, mean): 0.410, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.629, R2(test):0.501
# inner CV: R2(test, mean): 0.387, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.588, R2(test):0.426
# inner CV: R2(test, mean): 0.456, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.642, R2(test):0.414
# inner CV: R2(test, mean): 0.429, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.618, R2(test):0.504
# inner CV: R2(test, mean): 0.295, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.574, R2(test):0.599
# inner CV: R2(test, mean): 0.450, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.624, R2(test):0.477
# inner CV: R2(test, mean): 0.473, params: {'lasso__alpha': 0.1}, outer CV R2(train):0.641, R2(test):0.487
# [Lasso] total result: R2(train) 0.643, R2(test) 0.475
# ---------- Ridge ----------
# params, R2(train), R2(test)
# inner CV: R2(test, mean): 0.394, params: {'ridge__alpha': 100}, outer CV R2(train):0.645, R2(test):0.555
# inner CV: R2(test, mean): 0.478, params: {'ridge__alpha': 10}, outer CV R2(train):0.743, R2(test):0.516
# inner CV: R2(test, mean): 0.407, params: {'ridge__alpha': 100}, outer CV R2(train):0.682, R2(test):0.447
# inner CV: R2(test, mean): 0.361, params: {'ridge__alpha': 100}, outer CV R2(train):0.645, R2(test):0.526
# inner CV: R2(test, mean): 0.491, params: {'ridge__alpha': 10}, outer CV R2(train):0.741, R2(test):0.527
# inner CV: R2(test, mean): 0.483, params: {'ridge__alpha': 10}, outer CV R2(train):0.749, R2(test):0.490
# inner CV: R2(test, mean): 0.293, params: {'ridge__alpha': 100}, outer CV R2(train):0.604, R2(test):0.632
# inner CV: R2(test, mean): 0.442, params: {'ridge__alpha': 10}, outer CV R2(train):0.753, R2(test):0.508
# inner CV: R2(test, mean): 0.456, params: {'ridge__alpha': 10}, outer CV R2(train):0.752, R2(test):0.496
# inner CV: R2(test, mean): 0.338, params: {'ridge__alpha': 10}, outer CV R2(train):0.702, R2(test):0.593
# inner CV: R2(test, mean): 0.393, params: {'ridge__alpha': 10}, outer CV R2(train):0.735, R2(test):0.529
# inner CV: R2(test, mean): 0.499, params: {'ridge__alpha': 100}, outer CV R2(train):0.725, R2(test):0.445
# inner CV: R2(test, mean): 0.490, params: {'ridge__alpha': 10}, outer CV R2(train):0.750, R2(test):0.520
# inner CV: R2(test, mean): 0.387, params: {'ridge__alpha': 100}, outer CV R2(train):0.646, R2(test):0.467
# inner CV: R2(test, mean): 0.473, params: {'ridge__alpha': 100}, outer CV R2(train):0.707, R2(test):0.264
# inner CV: R2(test, mean): 0.289, params: {'ridge__alpha': 100}, outer CV R2(train):0.595, R2(test):0.513
# inner CV: R2(test, mean): 0.480, params: {'ridge__alpha': 100}, outer CV R2(train):0.684, R2(test):0.458
# inner CV: R2(test, mean): 0.511, params: {'ridge__alpha': 10}, outer CV R2(train):0.777, R2(test):0.333
# inner CV: R2(test, mean): 0.418, params: {'ridge__alpha': 10}, outer CV R2(train):0.782, R2(test):0.389
# inner CV: R2(test, mean): 0.398, params: {'ridge__alpha': 100}, outer CV R2(train):0.649, R2(test):0.451
# inner CV: R2(test, mean): 0.460, params: {'ridge__alpha': 100}, outer CV R2(train):0.679, R2(test):0.406
# inner CV: R2(test, mean): 0.430, params: {'ridge__alpha': 10}, outer CV R2(train):0.738, R2(test):0.548
# inner CV: R2(test, mean): 0.381, params: {'ridge__alpha': 100}, outer CV R2(train):0.649, R2(test):0.568
# inner CV: R2(test, mean): 0.434, params: {'ridge__alpha': 100}, outer CV R2(train):0.681, R2(test):0.480
# inner CV: R2(test, mean): 0.382, params: {'ridge__alpha': 10}, outer CV R2(train):0.736, R2(test):0.543
# inner CV: R2(test, mean): 0.456, params: {'ridge__alpha': 100}, outer CV R2(train):0.691, R2(test):0.372
# inner CV: R2(test, mean): 0.427, params: {'ridge__alpha': 100}, outer CV R2(train):0.675, R2(test):0.454
# inner CV: R2(test, mean): 0.310, params: {'ridge__alpha': 100}, outer CV R2(train):0.628, R2(test):0.585
# inner CV: R2(test, mean): 0.415, params: {'ridge__alpha': 100}, outer CV R2(train):0.667, R2(test):0.507
# inner CV: R2(test, mean): 0.473, params: {'ridge__alpha': 100}, outer CV R2(train):0.683, R2(test):0.476
# [Ridge] total result: R2(train) 0.697, R2(test) 0.487
# ---------- ElasticNet ----------
# params, R2(train), R2(test)
# inner CV: R2(test, mean): 0.414, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.4}, outer CV R2(train):0.666, R2(test):0.586
# inner CV: R2(test, mean): 0.480, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.2}, outer CV R2(train):0.718, R2(test):0.517
# inner CV: R2(test, mean): 0.454, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train):0.688, R2(test):0.469
# inner CV: R2(test, mean): 0.381, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train):0.619, R2(test):0.556
# inner CV: R2(test, mean): 0.520, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train):0.684, R2(test):0.485
# inner CV: R2(test, mean): 0.491, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.2}, outer CV R2(train):0.726, R2(test):0.485
# inner CV: R2(test, mean): 0.327, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train):0.604, R2(test):0.627
# inner CV: R2(test, mean): 0.462, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.2}, outer CV R2(train):0.732, R2(test):0.515
# inner CV: R2(test, mean): 0.471, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.2}, outer CV R2(train):0.734, R2(test):0.503
# inner CV: R2(test, mean): 0.374, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train):0.619, R2(test):0.505
# inner CV: R2(test, mean): 0.427, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train):0.615, R2(test):0.462
# inner CV: R2(test, mean): 0.539, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train):0.692, R2(test):0.427
# inner CV: R2(test, mean): 0.504, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.2}, outer CV R2(train):0.730, R2(test):0.512
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.796e+01, tolerance: 1.644e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# inner CV: R2(test, mean): 0.389, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train):0.635, R2(test):0.456
# inner CV: R2(test, mean): 0.529, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train):0.681, R2(test):0.221
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.022e+01, tolerance: 1.529e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# inner CV: R2(test, mean): 0.290, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train):0.582, R2(test):0.501
# inner CV: R2(test, mean): 0.514, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train):0.681, R2(test):0.477
# inner CV: R2(test, mean): 0.533, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.2}, outer CV R2(train):0.754, R2(test):0.351
# inner CV: R2(test, mean): 0.452, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.2}, outer CV R2(train):0.761, R2(test):0.408
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.472e+01, tolerance: 2.008e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# inner CV: R2(test, mean): 0.397, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train):0.640, R2(test):0.433
# inner CV: R2(test, mean): 0.473, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train):0.671, R2(test):0.487
# inner CV: R2(test, mean): 0.439, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train):0.657, R2(test):0.536
# inner CV: R2(test, mean): 0.419, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train):0.651, R2(test):0.584
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.845e+01, tolerance: 1.819e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# inner CV: R2(test, mean): 0.437, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train):0.671, R2(test):0.468
# inner CV: R2(test, mean): 0.411, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train):0.667, R2(test):0.500
# inner CV: R2(test, mean): 0.477, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.4}, outer CV R2(train):0.717, R2(test):0.345
# inner CV: R2(test, mean): 0.447, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.4}, outer CV R2(train):0.696, R2(test):0.464
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.354e+01, tolerance: 1.796e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# inner CV: R2(test, mean): 0.310, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train):0.617, R2(test):0.575
# inner CV: R2(test, mean): 0.450, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train):0.624, R2(test):0.477
# inner CV: R2(test, mean): 0.495, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train):0.692, R2(test):0.507
# [ElasticNet] total result: R2(train) 0.674, R2(test) 0.481
# ---------- PolyRidge ----------
# params, R2(train), R2(test)
# inner CV: R2(test, mean): 0.304, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.874, R2(test):0.507
# inner CV: R2(test, mean): 0.310, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.883, R2(test):0.318
# inner CV: R2(test, mean): 0.332, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.883, R2(test):0.122
# inner CV: R2(test, mean): 0.287, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.871, R2(test):0.312
# inner CV: R2(test, mean): 0.328, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.857, R2(test):0.410
# inner CV: R2(test, mean): 0.365, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.900, R2(test):0.347
# inner CV: R2(test, mean): 0.232, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.862, R2(test):0.509
# inner CV: R2(test, mean): 0.309, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.876, R2(test):0.482
# inner CV: R2(test, mean): 0.359, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.888, R2(test):0.126
# inner CV: R2(test, mean): 0.268, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.869, R2(test):0.364
# inner CV: R2(test, mean): 0.310, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.877, R2(test):0.404
# inner CV: R2(test, mean): 0.309, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.893, R2(test):0.313
# inner CV: R2(test, mean): 0.328, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.888, R2(test):0.447
# inner CV: R2(test, mean): 0.297, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.881, R2(test):0.187
# inner CV: R2(test, mean): 0.395, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.892, R2(test):0.105
# inner CV: R2(test, mean): 0.160, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.837, R2(test):0.260
# inner CV: R2(test, mean): 0.360, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.881, R2(test):0.405
# inner CV: R2(test, mean): 0.349, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.876, R2(test):0.307
# inner CV: R2(test, mean): 0.270, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.864, R2(test):0.226
# inner CV: R2(test, mean): 0.288, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.895, R2(test):0.444
# inner CV: R2(test, mean): 0.343, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.875, R2(test):0.423
# inner CV: R2(test, mean): 0.329, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.894, R2(test):0.318
# inner CV: R2(test, mean): 0.287, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.865, R2(test):0.430
# inner CV: R2(test, mean): 0.270, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.888, R2(test):0.383
# inner CV: R2(test, mean): 0.335, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.881, R2(test):0.314
# inner CV: R2(test, mean): 0.330, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.883, R2(test):0.139
# inner CV: R2(test, mean): 0.374, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.899, R2(test):0.412
# inner CV: R2(test, mean): 0.218, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.868, R2(test):0.463
# inner CV: R2(test, mean): 0.316, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.891, R2(test):0.261
# inner CV: R2(test, mean): 0.312, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train):0.875, R2(test):0.377
# [PolyRidge] total result: R2(train) 0.879, R2(test) 0.337
# ---------- RandomForest ----------
# params, R2(train), R2(test)
# inner CV: R2(test, mean): 0.428, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.786, R2(test):0.590
# inner CV: R2(test, mean): 0.411, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.825, R2(test):0.516
# inner CV: R2(test, mean): 0.452, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train):0.908, R2(test):0.171
# inner CV: R2(test, mean): 0.460, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train):0.842, R2(test):0.471
# inner CV: R2(test, mean): 0.489, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.814, R2(test):0.448
# inner CV: R2(test, mean): 0.469, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.923, R2(test):0.271
# inner CV: R2(test, mean): 0.398, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.916, R2(test):0.580
# inner CV: R2(test, mean): 0.441, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.810, R2(test):0.451
# inner CV: R2(test, mean): 0.436, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.935, R2(test):0.472
# inner CV: R2(test, mean): 0.359, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.803, R2(test):0.505
# inner CV: R2(test, mean): 0.385, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.815, R2(test):0.571
# inner CV: R2(test, mean): 0.504, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.938, R2(test):0.424
# inner CV: R2(test, mean): 0.478, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.927, R2(test):0.433
# inner CV: R2(test, mean): 0.363, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.922, R2(test):0.550
# inner CV: R2(test, mean): 0.535, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train):0.914, R2(test):0.292
# inner CV: R2(test, mean): 0.285, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.766, R2(test):0.505
# inner CV: R2(test, mean): 0.472, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.925, R2(test):0.510
# inner CV: R2(test, mean): 0.529, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.845, R2(test):0.382
# inner CV: R2(test, mean): 0.430, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.824, R2(test):0.387
# inner CV: R2(test, mean): 0.417, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.933, R2(test):0.477
# inner CV: R2(test, mean): 0.453, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 50}, outer CV R2(train):0.817, R2(test):0.490
# inner CV: R2(test, mean): 0.439, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.841, R2(test):0.480
# inner CV: R2(test, mean): 0.362, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.906, R2(test):0.627
# inner CV: R2(test, mean): 0.419, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.818, R2(test):0.529
# inner CV: R2(test, mean): 0.417, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.923, R2(test):0.430
# inner CV: R2(test, mean): 0.454, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.814, R2(test):0.373
# inner CV: R2(test, mean): 0.459, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.927, R2(test):0.485
# inner CV: R2(test, mean): 0.345, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train):0.898, R2(test):0.591
# inner CV: R2(test, mean): 0.460, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train):0.921, R2(test):0.486
# inner CV: R2(test, mean): 0.438, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train):0.817, R2(test):0.560
# [RandomForest] total result: R2(train) 0.868, R2(test) 0.469
# ---------- SVR ----------
# params, R2(train), R2(test)
# inner CV: R2(test, mean): 0.380, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.798, R2(test):0.640
# inner CV: R2(test, mean): 0.470, params: {'svr__C': 0.1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'linear'}, outer CV R2(train):0.730, R2(test):0.459
# inner CV: R2(test, mean): 0.480, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.857, R2(test):0.392
# inner CV: R2(test, mean): 0.431, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.823, R2(test):0.548
# inner CV: R2(test, mean): 0.507, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.803, R2(test):0.512
# inner CV: R2(test, mean): 0.464, params: {'svr__C': 0.1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'linear'}, outer CV R2(train):0.730, R2(test):0.481
# inner CV: R2(test, mean): 0.334, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.809, R2(test):0.619
# inner CV: R2(test, mean): 0.422, params: {'svr__C': 0.1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'linear'}, outer CV R2(train):0.739, R2(test):0.493
# inner CV: R2(test, mean): 0.485, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.842, R2(test):0.452
# inner CV: R2(test, mean): 0.344, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.780, R2(test):0.612
# inner CV: R2(test, mean): 0.424, params: {'svr__C': 100, 'svr__epsilon': 1.0, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.725, R2(test):0.430
# inner CV: R2(test, mean): 0.528, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.855, R2(test):0.383
# inner CV: R2(test, mean): 0.512, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.834, R2(test):0.457
# inner CV: R2(test, mean): 0.406, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.872, R2(test):0.446
# inner CV: R2(test, mean): 0.539, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.849, R2(test):0.179
# inner CV: R2(test, mean): 0.302, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.753, R2(test):0.467
# inner CV: R2(test, mean): 0.507, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.826, R2(test):0.468
# inner CV: R2(test, mean): 0.503, params: {'svr__C': 0.1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'linear'}, outer CV R2(train):0.754, R2(test):0.279
# inner CV: R2(test, mean): 0.414, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.829, R2(test):0.474
# inner CV: R2(test, mean): 0.391, params: {'svr__C': 0.01, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'linear'}, outer CV R2(train):0.619, R2(test):0.390
# inner CV: R2(test, mean): 0.490, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.816, R2(test):0.336
# inner CV: R2(test, mean): 0.431, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.882, R2(test):0.482
# inner CV: R2(test, mean): 0.368, params: {'svr__C': 0.1, 'svr__epsilon': 1.0, 'svr__gamma': 'scale', 'svr__kernel': 'linear'}, outer CV R2(train):0.683, R2(test):0.552
# inner CV: R2(test, mean): 0.458, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.833, R2(test):0.515
# inner CV: R2(test, mean): 0.482, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.825, R2(test):0.496
# inner CV: R2(test, mean): 0.459, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.830, R2(test):0.394
# inner CV: R2(test, mean): 0.443, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.884, R2(test):0.335
# inner CV: R2(test, mean): 0.335, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.803, R2(test):0.640
# inner CV: R2(test, mean): 0.442, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train):0.823, R2(test):0.482
# inner CV: R2(test, mean): 0.458, params: {'svr__C': 0.01, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'linear'}, outer CV R2(train):0.634, R2(test):0.378
# [SVR] total result: R2(train) 0.795, R2(test) 0.460
# ---------- XGBoost ----------
# params, R2(train), R2(test)
# inner CV: R2(test, mean): 0.481, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 1.0}, outer CV R2(train):0.817, R2(test):0.580
# inner CV: R2(test, mean): 0.446, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.741, R2(test):0.524
# inner CV: R2(test, mean): 0.477, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.776, R2(test):0.468
# inner CV: R2(test, mean): 0.461, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.8}, outer CV R2(train):0.767, R2(test):0.529
# inner CV: R2(test, mean): 0.552, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train):0.838, R2(test):0.460
# inner CV: R2(test, mean): 0.507, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.835, R2(test):0.434
# inner CV: R2(test, mean): 0.394, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train):0.733, R2(test):0.632
# inner CV: R2(test, mean): 0.487, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.776, R2(test):0.468
# inner CV: R2(test, mean): 0.498, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train):0.887, R2(test):0.465
# inner CV: R2(test, mean): 0.389, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.709, R2(test):0.541
# inner CV: R2(test, mean): 0.430, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.755, R2(test):0.525
# inner CV: R2(test, mean): 0.560, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.855, R2(test):0.417
# inner CV: R2(test, mean): 0.522, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.841, R2(test):0.493
# inner CV: R2(test, mean): 0.391, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.934, R2(test):0.569
# inner CV: R2(test, mean): 0.559, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.790, R2(test):0.323
# inner CV: R2(test, mean): 0.305, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.696, R2(test):0.532
# inner CV: R2(test, mean): 0.508, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.770, R2(test):0.507
# inner CV: R2(test, mean): 0.606, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 1.0}, outer CV R2(train):0.857, R2(test):0.240
# inner CV: R2(test, mean): 0.517, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 1.0}, outer CV R2(train):0.849, R2(test):0.459
# inner CV: R2(test, mean): 0.422, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.751, R2(test):0.484
# inner CV: R2(test, mean): 0.504, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.764, R2(test):0.535
# inner CV: R2(test, mean): 0.465, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.758, R2(test):0.527
# inner CV: R2(test, mean): 0.438, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.811, R2(test):0.612
# inner CV: R2(test, mean): 0.464, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train):0.767, R2(test):0.538
# inner CV: R2(test, mean): 0.448, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.936, R2(test):0.462
# inner CV: R2(test, mean): 0.499, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.769, R2(test):0.407
# inner CV: R2(test, mean): 0.503, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.766, R2(test):0.513
# inner CV: R2(test, mean): 0.379, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.728, R2(test):0.619
# inner CV: R2(test, mean): 0.485, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.935, R2(test):0.459
# inner CV: R2(test, mean): 0.506, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train):0.778, R2(test):0.559
# [XGBoost] total result: R2(train) 0.800, R2(test) 0.496
# ---------- LightGBM ----------
# params, R2(train), R2(test)
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.178, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.725, R2(test):0.565
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.268, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.760, R2(test):0.535
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.143, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.704, R2(test):0.376
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.207, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.767, R2(test):0.573
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.164, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.762, R2(test):0.517
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.298, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.790, R2(test):0.362
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.065, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.755, R2(test):0.628
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.202, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.751, R2(test):0.421
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.177, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.701, R2(test):0.435
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.217, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.713, R2(test):0.412
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.203, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.669, R2(test):0.591
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.236, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.675, R2(test):0.282
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\akila\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# inner CV: R2(test, mean): 0.185, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train):0.687, R2(test):0.392
# ...
# inner CV: R2(test, mean): 0.116, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train):0.532, R2(test):0.336
# inner CV: R2(test, mean): 0.207, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train):0.512, R2(test):0.232
# inner CV: R2(test, mean): 0.153, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train):0.673, R2(test):0.469
# inner CV: R2(test, mean): 0.149, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train):0.504, R2(test):0.491
# inner CV: R2(test, mean): 0.160, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train):0.683, R2(test):0.374
# inner CV: R2(test, mean): 0.131, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train):0.365, R2(test):0.422
# inner CV: R2(test, mean): 0.198, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train):0.586, R2(test):0.426
# inner CV: R2(test, mean): 0.157, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train):0.692, R2(test):0.469
# [HistGB] total result: R2(train) 0.566, R2(test) 0.361
# ---------- KNN ----------
# params, R2(train), R2(test)
# inner CV: R2(test, mean): 0.073, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train):0.326, R2(test):0.246
# inner CV: R2(test, mean): 0.162, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train):0.303, R2(test):0.034
# inner CV: R2(test, mean): 0.186, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.971, R2(test):-0.228
# inner CV: R2(test, mean): 0.106, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.983, R2(test):0.189
# inner CV: R2(test, mean): 0.194, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.973, R2(test):0.047
# inner CV: R2(test, mean): 0.113, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.982, R2(test):0.167
# inner CV: R2(test, mean): 0.094, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.983, R2(test):0.329
# inner CV: R2(test, mean): 0.098, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train):0.341, R2(test):-0.006
# inner CV: R2(test, mean): 0.211, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.993, R2(test):-0.138
# inner CV: R2(test, mean): -0.002, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.987, R2(test):0.177
# inner CV: R2(test, mean): 0.170, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train):0.352, R2(test):0.109
# inner CV: R2(test, mean): 0.163, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.993, R2(test):0.227
# inner CV: R2(test, mean): 0.195, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.987, R2(test):0.123
# inner CV: R2(test, mean): 0.108, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.990, R2(test):0.197
# inner CV: R2(test, mean): 0.133, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.967, R2(test):-0.254
# inner CV: R2(test, mean): -0.024, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train):0.436, R2(test):0.117
# inner CV: R2(test, mean): 0.240, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.995, R2(test):0.084
# inner CV: R2(test, mean): 0.142, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.984, R2(test):0.155
# inner CV: R2(test, mean): 0.082, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.965, R2(test):-0.006
# inner CV: R2(test, mean): 0.137, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train):0.325, R2(test):-0.049
# inner CV: R2(test, mean): 0.193, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train):0.652, R2(test):0.055
# inner CV: R2(test, mean): 0.123, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.993, R2(test):0.003
# inner CV: R2(test, mean): 0.041, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train):0.232, R2(test):0.306
# inner CV: R2(test, mean): 0.245, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.989, R2(test):-0.116
# inner CV: R2(test, mean): 0.118, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.982, R2(test):0.104
# inner CV: R2(test, mean): 0.104, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.982, R2(test):0.052
# inner CV: R2(test, mean): 0.132, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.986, R2(test):0.374
# inner CV: R2(test, mean): 0.072, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train):0.285, R2(test):0.239
# inner CV: R2(test, mean): 0.104, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.981, R2(test):0.055
# inner CV: R2(test, mean): 0.157, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train):0.990, R2(test):0.078
# [KNN] total result: R2(train) 0.797, R2(test) 0.089
# ---------- MLP ----------
# params, R2(train), R2(test)
# inner CV: R2(test, mean): 0.037, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.528, R2(test):0.171
# inner CV: R2(test, mean): 0.113, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.651, R2(test):0.186
# inner CV: R2(test, mean): 0.190, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train):0.172, R2(test):-0.123
# inner CV: R2(test, mean): 0.097, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.646, R2(test):0.199
# inner CV: R2(test, mean): 0.244, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train):0.758, R2(test):0.345
# inner CV: R2(test, mean): 0.196, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.790, R2(test):0.369
# inner CV: R2(test, mean): -0.031, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.547, R2(test):0.430
# inner CV: R2(test, mean): 0.126, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.666, R2(test):0.233
# inner CV: R2(test, mean): 0.222, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.784, R2(test):0.044
# inner CV: R2(test, mean): -0.046, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.733, R2(test):0.484
# inner CV: R2(test, mean): 0.154, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.853, R2(test):0.178
# inner CV: R2(test, mean): 0.206, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train):0.926, R2(test):0.395
# inner CV: R2(test, mean): 0.199, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.064, R2(test):-2.115
# inner CV: R2(test, mean): 0.070, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.879, R2(test):0.174
# inner CV: R2(test, mean): 0.230, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.808, R2(test):-0.067
# inner CV: R2(test, mean): -0.112, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train):0.288, R2(test):0.301
# inner CV: R2(test, mean): 0.201, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train):0.241, R2(test):0.016
# inner CV: R2(test, mean): 0.097, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train):0.530, R2(test):-0.059
# inner CV: R2(test, mean): 0.036, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train):0.825, R2(test):0.291
# inner CV: R2(test, mean): 0.137, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.685, R2(test):0.204
# inner CV: R2(test, mean): 0.239, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.663, R2(test):0.243
# inner CV: R2(test, mean): 0.036, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.512, R2(test):0.417
# inner CV: R2(test, mean): 0.090, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.429, R2(test):0.098
# inner CV: R2(test, mean): 0.222, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.648, R2(test):0.139
# inner CV: R2(test, mean): 0.072, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.707, R2(test):0.264
# inner CV: R2(test, mean): 0.155, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.726, R2(test):0.164
# inner CV: R2(test, mean): 0.138, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.842, R2(test):0.390
# inner CV: R2(test, mean): -0.067, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.702, R2(test):0.353
# inner CV: R2(test, mean): 0.138, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.749, R2(test):0.232
# inner CV: R2(test, mean): 0.186, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train):0.633, R2(test):0.159
# [MLP] total result: R2(train) 0.633, R2(test) 0.137

# %%
import pandas as pd
df = pd.read_csv('Mordred_descriptors_revise.csv')
df2 = df.iloc[:,13:].dropna()
y = df2.iloc[:,0]
X = df2.iloc[:,1:]

import numpy as np
from sklearn.model_selection import cross_val_score, GridSearchCV, RepeatedKFold
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=Warning)

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0, 0.2, 0.4, 0.5, 0.6, 0.8, 1],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },    
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10, 15],
        'randomforestregressor__min_samples_leaf': [1, 2, 5],
    },
    "SVR": {
        'svr__C': [0.01, 0.1, 1, 10, 100],
        'svr__epsilon': [0.5, 1.0, 2.0],
        'svr__kernel': ['rbf', 'linear'],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [2, 5, 10],
        'xgbregressor__n_estimators': [50, 100, 200],
        'xgbregressor__subsample': [0.6, 0.8, 1.0],
        'xgbregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "LightGBM": {
        'lgbmregressor__n_estimators': [50, 100, 200],
        'lgbmregressor__max_depth': [3, 5, 7],
        'lgbmregressor__learning_rate': [0.01, 0.05, 0.1],
        'lgbmregressor__subsample': [0.6, 0.8, 1.0],
        'lgbmregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1, 0.2],
        "histgradientboostingregressor__max_depth": [1, 3, 5, 7],
        "histgradientboostingregressor__max_iter": [100, 200],
        "histgradientboostingregressor__l2_regularization": [0.0, 0.1, 1.0],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7, 10],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__metric': ['euclidean', 'manhattan'],
        'kneighborsregressor__p': [1, 2]
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,), (50, 20)],
        'mlpregressor__alpha': [1e-4, 1e-3, 1e-2],
        'mlpregressor__learning_rate_init': [0.0001, 0.001, 0.01],
    }
}

# モデルの設定
models = {
    "Linear": LinearRegression(),
    "Lasso": Lasso(max_iter=10000),
    "Ridge": Ridge(max_iter=10000),
    "ElasticNet": ElasticNet(max_iter=50000),
    "PolyRidge": make_pipeline( PCA(n_components=20), PolynomialFeatures(), StandardScaler(), Ridge()),
    "RandomForest": RandomForestRegressor(),
    "SVR": SVR(),
    "XGBoost": XGBRegressor(verbosity=0, n_jobs=-1),
    "LightGBM": LGBMRegressor(verbose=-1, n_jobs=-1),
    "HistGB": HistGradientBoostingRegressor(early_stopping=True),
    "KNN": KNeighborsRegressor(),
    "MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1)
}

n_repeats = 10
outer_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    print( '----------', name, '----------\nparams, R2(train), R2(test)')
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)

    tot_train = []
    tot_test = []
    
    for train_idx, test_idx in outer_cv.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        if name in param_grids:
            grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
            grid.fit(X_train, y_train)
            
            y_train_pred = grid.predict(X_train)
            y_test_pred  = grid.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"inner CV: R2(test): {grid.best_score_:.3f}, params: {grid.best_params_}, outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
        
        else:
            pipeline.fit(X_train, y_train)
            y_train_pred = pipeline.predict(X_train)
            y_test_pred  = pipeline.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
            
        tot_train.append(train_r2)
        tot_test.append(test_r2)
    
    print(f"[{name}] total result = R2(train): {np.mean(tot_train):.3f}, R2(test): {np.mean(tot_test):.3f}")
# Out:
# ---------- Linear ----------
# params, R2(train), R2(test)
# outer CV R2(train): 0.792, R2(test): 0.532
# outer CV R2(train): 0.814, R2(test): 0.438
# outer CV R2(train): 0.770, R2(test): 0.631
# outer CV R2(train): 0.747, R2(test): 0.679
# outer CV R2(train): 0.805, R2(test): 0.534
# outer CV R2(train): 0.805, R2(test): 0.522
# outer CV R2(train): 0.767, R2(test): 0.591
# outer CV R2(train): 0.795, R2(test): 0.536
# outer CV R2(train): 0.809, R2(test): 0.444
# outer CV R2(train): 0.766, R2(test): 0.530
# outer CV R2(train): 0.795, R2(test): 0.478
# outer CV R2(train): 0.826, R2(test): 0.474
# outer CV R2(train): 0.816, R2(test): 0.453
# outer CV R2(train): 0.794, R2(test): 0.464
# outer CV R2(train): 0.803, R2(test): 0.232
# outer CV R2(train): 0.779, R2(test): 0.515
# outer CV R2(train): 0.784, R2(test): 0.475
# outer CV R2(train): 0.809, R2(test): 0.449
# outer CV R2(train): 0.819, R2(test): 0.435
# outer CV R2(train): 0.766, R2(test): 0.569
# outer CV R2(train): 0.792, R2(test): 0.503
# outer CV R2(train): 0.776, R2(test): 0.609
# outer CV R2(train): 0.794, R2(test): 0.549
# outer CV R2(train): 0.790, R2(test): 0.574
# outer CV R2(train): 0.815, R2(test): 0.494
# outer CV R2(train): 0.821, R2(test): 0.260
# outer CV R2(train): 0.773, R2(test): 0.548
# outer CV R2(train): 0.748, R2(test): 0.688
# outer CV R2(train): 0.767, R2(test): 0.689
# outer CV R2(train): 0.825, R2(test): 0.513
# [Linear] total result = R2(train): 0.792, R2(test): 0.514
# ---------- Lasso ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.536, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.729, R2(test): 0.637
# inner CV: R2(test): 0.509, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.736, R2(test): 0.520
# inner CV: R2(test): 0.482, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.720, R2(test): 0.551
# inner CV: R2(test): 0.460, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.690, R2(test): 0.635
# inner CV: R2(test): 0.567, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.737, R2(test): 0.543
# inner CV: R2(test): 0.569, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.754, R2(test): 0.563
# inner CV: R2(test): 0.412, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.675, R2(test): 0.698
# inner CV: R2(test): 0.479, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.742, R2(test): 0.581
# inner CV: R2(test): 0.531, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.752, R2(test): 0.540
# inner CV: R2(test): 0.470, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.714, R2(test): 0.551
# inner CV: R2(test): 0.496, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.730, R2(test): 0.635
# inner CV: R2(test): 0.591, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.770, R2(test): 0.490
# inner CV: R2(test): 0.563, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.753, R2(test): 0.543
# inner CV: R2(test): 0.468, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.718, R2(test): 0.588
# inner CV: R2(test): 0.566, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.755, R2(test): 0.250
# inner CV: R2(test): 0.436, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.707, R2(test): 0.533
# inner CV: R2(test): 0.532, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.722, R2(test): 0.544
# inner CV: R2(test): 0.541, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.757, R2(test): 0.457
# inner CV: R2(test): 0.517, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.745, R2(test): 0.400
# inner CV: R2(test): 0.439, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.713, R2(test): 0.625
# inner CV: R2(test): 0.528, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.735, R2(test): 0.540
# inner CV: R2(test): 0.510, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.724, R2(test): 0.607
# inner CV: R2(test): 0.466, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.723, R2(test): 0.650
# inner CV: R2(test): 0.493, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.730, R2(test): 0.595
# inner CV: R2(test): 0.470, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.722, R2(test): 0.571
# inner CV: R2(test): 0.572, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.757, R2(test): 0.515
# inner CV: R2(test): 0.511, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.723, R2(test): 0.580
# inner CV: R2(test): 0.366, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.682, R2(test): 0.715
# inner CV: R2(test): 0.508, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.720, R2(test): 0.624
# inner CV: R2(test): 0.559, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.766, R2(test): 0.535
# [Lasso] total result = R2(train): 0.730, R2(test): 0.561
# ---------- Ridge ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.495, params: {'ridge__alpha': 100}, outer CV R2(train): 0.787, R2(test): 0.576
# inner CV: R2(test): 0.435, params: {'ridge__alpha': 100}, outer CV R2(train): 0.809, R2(test): 0.496
# inner CV: R2(test): 0.399, params: {'ridge__alpha': 100}, outer CV R2(train): 0.766, R2(test): 0.647
# inner CV: R2(test): 0.313, params: {'ridge__alpha': 100}, outer CV R2(train): 0.746, R2(test): 0.669
# inner CV: R2(test): 0.488, params: {'ridge__alpha': 100}, outer CV R2(train): 0.802, R2(test): 0.549
# inner CV: R2(test): 0.522, params: {'ridge__alpha': 100}, outer CV R2(train): 0.802, R2(test): 0.530
# inner CV: R2(test): 0.277, params: {'ridge__alpha': 100}, outer CV R2(train): 0.752, R2(test): 0.674
# inner CV: R2(test): 0.375, params: {'ridge__alpha': 100}, outer CV R2(train): 0.792, R2(test): 0.560
# inner CV: R2(test): 0.451, params: {'ridge__alpha': 100}, outer CV R2(train): 0.806, R2(test): 0.488
# inner CV: R2(test): 0.361, params: {'ridge__alpha': 100}, outer CV R2(train): 0.761, R2(test): 0.582
# inner CV: R2(test): 0.445, params: {'ridge__alpha': 100}, outer CV R2(train): 0.788, R2(test): 0.570
# inner CV: R2(test): 0.463, params: {'ridge__alpha': 100}, outer CV R2(train): 0.824, R2(test): 0.475
# inner CV: R2(test): 0.541, params: {'ridge__alpha': 100}, outer CV R2(train): 0.814, R2(test): 0.477
# inner CV: R2(test): 0.463, params: {'ridge__alpha': 100}, outer CV R2(train): 0.788, R2(test): 0.512
# inner CV: R2(test): 0.464, params: {'ridge__alpha': 100}, outer CV R2(train): 0.799, R2(test): 0.260
# inner CV: R2(test): 0.341, params: {'ridge__alpha': 100}, outer CV R2(train): 0.776, R2(test): 0.534
# inner CV: R2(test): 0.444, params: {'ridge__alpha': 100}, outer CV R2(train): 0.773, R2(test): 0.559
# inner CV: R2(test): 0.483, params: {'ridge__alpha': 100}, outer CV R2(train): 0.807, R2(test): 0.460
# inner CV: R2(test): 0.375, params: {'ridge__alpha': 100}, outer CV R2(train): 0.816, R2(test): 0.443
# inner CV: R2(test): 0.344, params: {'ridge__alpha': 100}, outer CV R2(train): 0.762, R2(test): 0.614
# inner CV: R2(test): 0.420, params: {'ridge__alpha': 100}, outer CV R2(train): 0.785, R2(test): 0.542
# inner CV: R2(test): 0.435, params: {'ridge__alpha': 100}, outer CV R2(train): 0.773, R2(test): 0.616
# inner CV: R2(test): 0.381, params: {'ridge__alpha': 100}, outer CV R2(train): 0.789, R2(test): 0.575
# inner CV: R2(test): 0.377, params: {'ridge__alpha': 100}, outer CV R2(train): 0.788, R2(test): 0.597
# inner CV: R2(test): 0.387, params: {'ridge__alpha': 100}, outer CV R2(train): 0.809, R2(test): 0.552
# inner CV: R2(test): 0.511, params: {'ridge__alpha': 100}, outer CV R2(train): 0.818, R2(test): 0.313
# inner CV: R2(test): 0.424, params: {'ridge__alpha': 100}, outer CV R2(train): 0.771, R2(test): 0.559
# inner CV: R2(test): 0.269, params: {'ridge__alpha': 100}, outer CV R2(train): 0.745, R2(test): 0.705
# inner CV: R2(test): 0.364, params: {'ridge__alpha': 100}, outer CV R2(train): 0.765, R2(test): 0.681
# inner CV: R2(test): 0.542, params: {'ridge__alpha': 100}, outer CV R2(train): 0.823, R2(test): 0.525
# [Ridge] total result = R2(train): 0.788, R2(test): 0.545
# ---------- ElasticNet ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.545, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.744, R2(test): 0.637
# inner CV: R2(test): 0.511, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.757, R2(test): 0.555
# inner CV: R2(test): 0.482, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.720, R2(test): 0.551
# inner CV: R2(test): 0.460, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.690, R2(test): 0.635
# inner CV: R2(test): 0.576, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.772, R2(test): 0.559
# inner CV: R2(test): 0.577, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.778, R2(test): 0.553
# inner CV: R2(test): 0.412, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.675, R2(test): 0.698
# inner CV: R2(test): 0.479, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.742, R2(test): 0.581
# inner CV: R2(test): 0.531, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.752, R2(test): 0.540
# inner CV: R2(test): 0.471, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.728, R2(test): 0.570
# inner CV: R2(test): 0.503, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.757, R2(test): 0.634
# inner CV: R2(test): 0.598, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.785, R2(test): 0.498
# inner CV: R2(test): 0.579, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.783, R2(test): 0.531
# inner CV: R2(test): 0.489, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.4}, outer CV R2(train): 0.770, R2(test): 0.577
# inner CV: R2(test): 0.566, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.755, R2(test): 0.250
# inner CV: R2(test): 0.442, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.725, R2(test): 0.543
# inner CV: R2(test): 0.536, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.742, R2(test): 0.529
# inner CV: R2(test): 0.545, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.769, R2(test): 0.466
# inner CV: R2(test): 0.527, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.762, R2(test): 0.424
# inner CV: R2(test): 0.440, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.726, R2(test): 0.623
# inner CV: R2(test): 0.528, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.735, R2(test): 0.540
# inner CV: R2(test): 0.513, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.737, R2(test): 0.615
# inner CV: R2(test): 0.471, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.739, R2(test): 0.649
# inner CV: R2(test): 0.493, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.730, R2(test): 0.595
# inner CV: R2(test): 0.476, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.750, R2(test): 0.586
# inner CV: R2(test): 0.575, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.769, R2(test): 0.509
# inner CV: R2(test): 0.511, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.723, R2(test): 0.580
# inner CV: R2(test): 0.368, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.697, R2(test): 0.722
# inner CV: R2(test): 0.508, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.720, R2(test): 0.624
# inner CV: R2(test): 0.571, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.774, R2(test): 0.516
# [ElasticNet] total result = R2(train): 0.744, R2(test): 0.563
# ---------- PolyRidge ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.345, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.870, R2(test): 0.460
# inner CV: R2(test): 0.145, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.844, R2(test): 0.492
# inner CV: R2(test): 0.198, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.893, R2(test): 0.404
# inner CV: R2(test): 0.162, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.853, R2(test): 0.462
# inner CV: R2(test): 0.376, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.892, R2(test): 0.500
# inner CV: R2(test): 0.314, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.872, R2(test): 0.359
# inner CV: R2(test): 0.156, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.849, R2(test): 0.422
# inner CV: R2(test): 0.282, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.871, R2(test): 0.494
# inner CV: R2(test): 0.382, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.910, R2(test): 0.266
# inner CV: R2(test): 0.117, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.881, R2(test): 0.524
# inner CV: R2(test): 0.367, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.883, R2(test): 0.375
# inner CV: R2(test): 0.306, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.865, R2(test): 0.469
# inner CV: R2(test): 0.498, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.907, R2(test): 0.375
# inner CV: R2(test): 0.288, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.864, R2(test): 0.111
# inner CV: R2(test): 0.291, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.875, R2(test): 0.020
# inner CV: R2(test): 0.361, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.865, R2(test): 0.271
# inner CV: R2(test): 0.253, params: {'polynomialfeatures__degree': 3, 'ridge__alpha': 100}, outer CV R2(train): 0.988, R2(test): 0.303
# inner CV: R2(test): 0.363, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.881, R2(test): 0.459
# inner CV: R2(test): 0.313, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.877, R2(test): 0.614
# inner CV: R2(test): 0.266, params: {'polynomialfeatures__degree': 3, 'ridge__alpha': 100}, outer CV R2(train): 0.979, R2(test): 0.138
# inner CV: R2(test): 0.295, params: {'polynomialfeatures__degree': 3, 'ridge__alpha': 100}, outer CV R2(train): 0.986, R2(test): 0.320
# inner CV: R2(test): 0.259, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.841, R2(test): 0.409
# inner CV: R2(test): 0.219, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.867, R2(test): 0.480
# inner CV: R2(test): 0.284, params: {'polynomialfeatures__degree': 3, 'ridge__alpha': 100}, outer CV R2(train): 0.991, R2(test): 0.399
# inner CV: R2(test): 0.413, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.903, R2(test): 0.304
# inner CV: R2(test): 0.361, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.896, R2(test): 0.398
# inner CV: R2(test): 0.258, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.863, R2(test): 0.547
# inner CV: R2(test): 0.194, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.885, R2(test): 0.531
# inner CV: R2(test): 0.256, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.857, R2(test): 0.344
# inner CV: R2(test): 0.467, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.894, R2(test): 0.358
# [PolyRidge] total result = R2(train): 0.890, R2(test): 0.387
# ---------- RandomForest ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.538, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.870, R2(test): 0.650
# inner CV: R2(test): 0.569, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.942, R2(test): 0.510
# inner CV: R2(test): 0.498, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.934, R2(test): 0.559
# inner CV: R2(test): 0.472, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 5, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.758, R2(test): 0.688
# inner CV: R2(test): 0.602, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.954, R2(test): 0.506
# inner CV: R2(test): 0.557, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.909, R2(test): 0.572
# inner CV: R2(test): 0.480, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.936, R2(test): 0.639
# inner CV: R2(test): 0.548, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.897, R2(test): 0.540
# inner CV: R2(test): 0.559, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 5, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.831, R2(test): 0.439
# inner CV: R2(test): 0.505, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.950, R2(test): 0.554
# inner CV: R2(test): 0.483, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.896, R2(test): 0.617
# inner CV: R2(test): 0.573, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.944, R2(test): 0.544
# inner CV: R2(test): 0.617, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.895, R2(test): 0.541
# inner CV: R2(test): 0.472, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.862, R2(test): 0.548
# inner CV: R2(test): 0.571, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.883, R2(test): 0.530
# inner CV: R2(test): 0.444, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.868, R2(test): 0.569
# inner CV: R2(test): 0.518, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.895, R2(test): 0.589
# inner CV: R2(test): 0.580, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.912, R2(test): 0.515
# inner CV: R2(test): 0.480, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.887, R2(test): 0.539
# inner CV: R2(test): 0.488, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 5, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.784, R2(test): 0.615
# inner CV: R2(test): 0.596, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 5, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.832, R2(test): 0.454
# inner CV: R2(test): 0.512, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.938, R2(test): 0.637
# inner CV: R2(test): 0.501, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.896, R2(test): 0.703
# inner CV: R2(test): 0.564, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 5, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.817, R2(test): 0.485
# inner CV: R2(test): 0.533, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.951, R2(test): 0.564
# inner CV: R2(test): 0.577, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.913, R2(test): 0.342
# inner CV: R2(test): 0.508, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.885, R2(test): 0.697
# inner CV: R2(test): 0.454, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 5, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.775, R2(test): 0.683
# inner CV: R2(test): 0.489, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.930, R2(test): 0.647
# inner CV: R2(test): 0.602, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.948, R2(test): 0.528
# [RandomForest] total result = R2(train): 0.890, R2(test): 0.567
# ---------- SVR ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.494, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.889, R2(test): 0.686
# inner CV: R2(test): 0.539, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.888, R2(test): 0.581
# inner CV: R2(test): 0.586, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.906, R2(test): 0.520
# inner CV: R2(test): 0.534, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.891, R2(test): 0.609
# inner CV: R2(test): 0.605, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.896, R2(test): 0.589
# inner CV: R2(test): 0.527, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.911, R2(test): 0.495
# inner CV: R2(test): 0.493, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.889, R2(test): 0.615
# inner CV: R2(test): 0.534, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.887, R2(test): 0.617
# inner CV: R2(test): 0.586, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.910, R2(test): 0.560
# inner CV: R2(test): 0.480, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.888, R2(test): 0.671
# inner CV: R2(test): 0.497, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.893, R2(test): 0.692
# inner CV: R2(test): 0.619, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.899, R2(test): 0.535
# inner CV: R2(test): 0.603, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.906, R2(test): 0.545
# inner CV: R2(test): 0.504, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.885, R2(test): 0.668
# inner CV: R2(test): 0.587, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.902, R2(test): 0.391
# inner CV: R2(test): 0.468, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.885, R2(test): 0.593
# inner CV: R2(test): 0.553, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.900, R2(test): 0.634
# inner CV: R2(test): 0.594, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.897, R2(test): 0.479
# inner CV: R2(test): 0.568, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.884, R2(test): 0.507
# inner CV: R2(test): 0.515, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.901, R2(test): 0.642
# inner CV: R2(test): 0.553, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.901, R2(test): 0.606
# inner CV: R2(test): 0.548, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.897, R2(test): 0.643
# inner CV: R2(test): 0.509, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.882, R2(test): 0.628
# inner CV: R2(test): 0.570, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.903, R2(test): 0.641
# inner CV: R2(test): 0.565, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.890, R2(test): 0.573
# inner CV: R2(test): 0.568, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.901, R2(test): 0.529
# inner CV: R2(test): 0.546, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.895, R2(test): 0.542
# inner CV: R2(test): 0.490, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.896, R2(test): 0.675
# inner CV: R2(test): 0.527, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.892, R2(test): 0.613
# inner CV: R2(test): 0.592, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.903, R2(test): 0.627
# [SVR] total result = R2(train): 0.896, R2(test): 0.590
# ---------- XGBoost ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.571, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.855, R2(test): 0.665
# inner CV: R2(test): 0.573, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.890, R2(test): 0.558
# inner CV: R2(test): 0.511, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.782, R2(test): 0.629
# inner CV: R2(test): 0.483, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.744, R2(test): 0.696
# inner CV: R2(test): 0.620, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.931, R2(test): 0.557
# inner CV: R2(test): 0.590, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.874, R2(test): 0.526
# inner CV: R2(test): 0.487, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.830, R2(test): 0.688
# inner CV: R2(test): 0.562, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.891, R2(test): 0.505
# inner CV: R2(test): 0.581, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.877, R2(test): 0.528
# inner CV: R2(test): 0.505, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.788, R2(test): 0.561
# inner CV: R2(test): 0.512, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.866, R2(test): 0.636
# inner CV: R2(test): 0.603, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.883, R2(test): 0.523
# inner CV: R2(test): 0.644, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.883, R2(test): 0.574
# inner CV: R2(test): 0.513, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.850, R2(test): 0.549
# inner CV: R2(test): 0.584, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.871, R2(test): 0.461
# inner CV: R2(test): 0.483, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.779, R2(test): 0.555
# inner CV: R2(test): 0.532, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.858, R2(test): 0.620
# inner CV: R2(test): 0.595, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.882, R2(test): 0.530
# inner CV: R2(test): 0.534, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.865, R2(test): 0.579
# inner CV: R2(test): 0.502, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.863, R2(test): 0.606
# inner CV: R2(test): 0.582, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.803, R2(test): 0.499
# inner CV: R2(test): 0.520, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.863, R2(test): 0.667
# inner CV: R2(test): 0.538, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.851, R2(test): 0.689
# inner CV: R2(test): 0.554, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.873, R2(test): 0.603
# inner CV: R2(test): 0.579, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.934, R2(test): 0.582
# inner CV: R2(test): 0.583, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.807, R2(test): 0.439
# inner CV: R2(test): 0.531, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.853, R2(test): 0.648
# inner CV: R2(test): 0.453, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.841, R2(test): 0.723
# inner CV: R2(test): 0.502, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.778, R2(test): 0.656
# inner CV: R2(test): 0.632, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.899, R2(test): 0.554
# [XGBoost] total result = R2(train): 0.852, R2(test): 0.587
# ---------- LightGBM ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.568, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.895, R2(test): 0.664
# inner CV: R2(test): 0.560, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.815, R2(test): 0.581
# inner CV: R2(test): 0.544, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.815, R2(test): 0.612
# inner CV: R2(test): 0.497, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 50, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.778, R2(test): 0.788
# inner CV: R2(test): 0.617, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.958, R2(test): 0.539
# inner CV: R2(test): 0.573, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 50, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.837, R2(test): 0.608
# inner CV: R2(test): 0.474, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.872, R2(test): 0.717
# inner CV: R2(test): 0.517, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 50, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.838, R2(test): 0.611
# inner CV: R2(test): 0.606, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.851, R2(test): 0.464
# inner CV: R2(test): 0.501, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 50, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.822, R2(test): 0.563
# inner CV: R2(test): 0.529, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.901, R2(test): 0.606
# inner CV: R2(test): 0.607, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.893, R2(test): 0.519
# inner CV: R2(test): 0.643, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.963, R2(test): 0.458
# inner CV: R2(test): 0.536, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.879, R2(test): 0.624
# inner CV: R2(test): 0.597, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.837, R2(test): 0.496
# inner CV: R2(test): 0.461, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.876, R2(test): 0.594
# inner CV: R2(test): 0.528, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.822, R2(test): 0.600
# inner CV: R2(test): 0.581, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 50, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.843, R2(test): 0.508
# inner CV: R2(test): 0.508, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.942, R2(test): 0.528
# inner CV: R2(test): 0.520, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 50, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.813, R2(test): 0.614
# inner CV: R2(test): 0.619, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.838, R2(test): 0.471
# inner CV: R2(test): 0.535, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 50, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.807, R2(test): 0.660
# inner CV: R2(test): 0.509, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.887, R2(test): 0.681
# inner CV: R2(test): 0.553, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.834, R2(test): 0.591
# inner CV: R2(test): 0.594, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.902, R2(test): 0.562
# inner CV: R2(test): 0.579, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 50, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.832, R2(test): 0.384
# inner CV: R2(test): 0.506, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.809, R2(test): 0.698
# inner CV: R2(test): 0.465, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 50, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.809, R2(test): 0.684
# inner CV: R2(test): 0.486, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.811, R2(test): 0.663
# inner CV: R2(test): 0.635, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.901, R2(test): 0.568
# [LightGBM] total result = R2(train): 0.856, R2(test): 0.589
# ---------- HistGB ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.523, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.786, R2(test): 0.642
# inner CV: R2(test): 0.554, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.698, R2(test): 0.506
# inner CV: R2(test): 0.525, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.821, R2(test): 0.536
# inner CV: R2(test): 0.476, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.626, R2(test): 0.631
# inner CV: R2(test): 0.595, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.816, R2(test): 0.567
# inner CV: R2(test): 0.584, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.766, R2(test): 0.540
# inner CV: R2(test): 0.464, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.688, R2(test): 0.680
# inner CV: R2(test): 0.510, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.767, R2(test): 0.521
# inner CV: R2(test): 0.592, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.820, R2(test): 0.477
# inner CV: R2(test): 0.466, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.780, R2(test): 0.593
# inner CV: R2(test): 0.530, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.910, R2(test): 0.618
# inner CV: R2(test): 0.582, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.809, R2(test): 0.567
# inner CV: R2(test): 0.612, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.789, R2(test): 0.507
# inner CV: R2(test): 0.517, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.746, R2(test): 0.549
# inner CV: R2(test): 0.584, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.777, R2(test): 0.341
# inner CV: R2(test): 0.411, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.733, R2(test): 0.550
# inner CV: R2(test): 0.539, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.730, R2(test): 0.558
# inner CV: R2(test): 0.567, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.889, R2(test): 0.451
# ...
# inner CV: R2(test): 0.524, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.746, R2(test): 0.632
# inner CV: R2(test): 0.481, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.848, R2(test): 0.688
# inner CV: R2(test): 0.539, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.753, R2(test): 0.531
# inner CV: R2(test): 0.576, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.835, R2(test): 0.563
# inner CV: R2(test): 0.555, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.829, R2(test): 0.395
# inner CV: R2(test): 0.499, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.767, R2(test): 0.676
# inner CV: R2(test): 0.452, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.705, R2(test): 0.674
# inner CV: R2(test): 0.500, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.615, R2(test): 0.608
# inner CV: R2(test): 0.614, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.870, R2(test): 0.540
# [HistGB] total result = R2(train): 0.775, R2(test): 0.559
# ---------- KNN ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.307, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.524
# inner CV: R2(test): 0.320, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.346
# inner CV: R2(test): 0.377, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.133
# inner CV: R2(test): 0.353, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.219
# inner CV: R2(test): 0.398, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.329
# inner CV: R2(test): 0.296, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.414
# inner CV: R2(test): 0.313, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.414
# inner CV: R2(test): 0.329, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train): 0.674, R2(test): 0.190
# inner CV: R2(test): 0.379, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.357
# inner CV: R2(test): 0.247, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.333
# inner CV: R2(test): 0.291, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.381
# inner CV: R2(test): 0.367, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.395
# inner CV: R2(test): 0.394, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.459
# inner CV: R2(test): 0.288, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.356
# inner CV: R2(test): 0.401, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): -0.066
# inner CV: R2(test): 0.213, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.350
# inner CV: R2(test): 0.338, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.381
# inner CV: R2(test): 0.442, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.453
# inner CV: R2(test): 0.366, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.222
# inner CV: R2(test): 0.270, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.447
# inner CV: R2(test): 0.345, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.447
# inner CV: R2(test): 0.325, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.387
# inner CV: R2(test): 0.264, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.495
# inner CV: R2(test): 0.347, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.396
# inner CV: R2(test): 0.307, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.206
# inner CV: R2(test): 0.369, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.316
# inner CV: R2(test): 0.330, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.492
# inner CV: R2(test): 0.240, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.433
# inner CV: R2(test): 0.301, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.490
# inner CV: R2(test): 0.349, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.333
# [KNN] total result = R2(train): 0.989, R2(test): 0.354
# ---------- MLP ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.109, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.781, R2(test): 0.467
# inner CV: R2(test): 0.060, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.715, R2(test): 0.504
# inner CV: R2(test): 0.177, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.832, R2(test): 0.477
# inner CV: R2(test): 0.134, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.466, R2(test): 0.132
# inner CV: R2(test): 0.132, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.909, R2(test): 0.341
# inner CV: R2(test): 0.121, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.880, R2(test): 0.547
# inner CV: R2(test): 0.053, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.721, R2(test): 0.286
# inner CV: R2(test): 0.076, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.879, R2(test): 0.431
# inner CV: R2(test): 0.157, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.938, R2(test): -0.563
# inner CV: R2(test): -0.063, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.811, R2(test): 0.369
# inner CV: R2(test): 0.092, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.934, R2(test): 0.425
# inner CV: R2(test): 0.116, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.898, R2(test): 0.087
# inner CV: R2(test): 0.138, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.574, R2(test): -0.269
# inner CV: R2(test): -0.023, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.925, R2(test): 0.343
# inner CV: R2(test): 0.227, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.801, R2(test): -0.112
# inner CV: R2(test): -0.105, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): -0.530, R2(test): -1.613
# inner CV: R2(test): 0.144, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.714, R2(test): 0.332
# inner CV: R2(test): 0.221, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.917, R2(test): 0.179
# inner CV: R2(test): 0.059, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.950, R2(test): 0.101
# inner CV: R2(test): 0.016, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.524, R2(test): 0.408
# inner CV: R2(test): 0.115, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.706, R2(test): 0.169
# inner CV: R2(test): 0.091, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.922, R2(test): 0.360
# inner CV: R2(test): -0.055, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.718, R2(test): 0.216
# inner CV: R2(test): 0.154, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.958, R2(test): 0.380
# inner CV: R2(test): 0.085, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.766, R2(test): 0.260
# inner CV: R2(test): 0.192, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.949, R2(test): -0.050
# inner CV: R2(test): 0.041, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.971, R2(test): 0.327
# inner CV: R2(test): -0.126, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.821, R2(test): 0.195
# inner CV: R2(test): 0.073, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.916, R2(test): 0.558
# inner CV: R2(test): 0.111, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.692, R2(test): 0.323
# [MLP] total result = R2(train): 0.769, R2(test): 0.187

# %%
import pandas as pd
df = pd.read_csv('Morgan_descriptors_revise.csv')
df2 = df.iloc[:,13:].dropna()
y = df2.iloc[:,0]
X = df2.iloc[:,1:]

import numpy as np
from sklearn.model_selection import cross_val_score, GridSearchCV, RepeatedKFold
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=Warning)

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0, 0.2, 0.4, 0.5, 0.6, 0.8, 1],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },    
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10, 15],
        'randomforestregressor__min_samples_leaf': [1, 2, 5],
    },
    "SVR": {
        'svr__C': [0.01, 0.1, 1, 10, 100],
        'svr__epsilon': [0.5, 1.0, 2.0],
        'svr__kernel': ['rbf', 'linear'],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [2, 5, 10],
        'xgbregressor__n_estimators': [50, 100, 200],
        'xgbregressor__subsample': [0.6, 0.8, 1.0],
        'xgbregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "LightGBM": {
        'lgbmregressor__n_estimators': [50, 100, 200],
        'lgbmregressor__max_depth': [3, 5, 7],
        'lgbmregressor__learning_rate': [0.01, 0.05, 0.1],
        'lgbmregressor__subsample': [0.6, 0.8, 1.0],
        'lgbmregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1, 0.2],
        "histgradientboostingregressor__max_depth": [1, 3, 5, 7],
        "histgradientboostingregressor__max_iter": [100, 200],
        "histgradientboostingregressor__l2_regularization": [0.0, 0.1, 1.0],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7, 10],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__metric': ['euclidean', 'manhattan'],
        'kneighborsregressor__p': [1, 2]
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,), (50, 20)],
        'mlpregressor__alpha': [1e-4, 1e-3, 1e-2],
        'mlpregressor__learning_rate_init': [0.0001, 0.001, 0.01],
    }
}

# モデルの設定
models = {
    "Linear": LinearRegression(),
    "Lasso": Lasso(max_iter=10000),
    "Ridge": Ridge(max_iter=10000),
    "ElasticNet": ElasticNet(max_iter=50000),
    "PolyRidge": make_pipeline( PCA(n_components=20), PolynomialFeatures(), StandardScaler(), Ridge()),
    "RandomForest": RandomForestRegressor(),
    "SVR": SVR(),
    "XGBoost": XGBRegressor(verbosity=0, n_jobs=-1),
    "LightGBM": LGBMRegressor(verbose=-1, n_jobs=-1),
    "HistGB": HistGradientBoostingRegressor(early_stopping=True),
    "KNN": KNeighborsRegressor(),
    "MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1)
}

n_repeats = 10
outer_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    print( '----------', name, '----------\nparams, R2(train), R2(test)')
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)

    tot_train = []
    tot_test = []
    
    for train_idx, test_idx in outer_cv.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        if name in param_grids:
            grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
            grid.fit(X_train, y_train)
            
            y_train_pred = grid.predict(X_train)
            y_test_pred  = grid.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"inner CV: R2(test): {grid.best_score_:.3f}, params: {grid.best_params_}, outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
        
        else:
            pipeline.fit(X_train, y_train)
            y_train_pred = pipeline.predict(X_train)
            y_test_pred  = pipeline.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
            
        tot_train.append(train_r2)
        tot_test.append(test_r2)
    
    print(f"[{name}] total result = R2(train): {np.mean(tot_train):.3f}, R2(test): {np.mean(tot_test):.3f}")
# Out:
# ---------- Linear ----------
# params, R2(train), R2(test)
# outer CV R2(train): 0.790, R2(test): 0.544
# outer CV R2(train): 0.814, R2(test): 0.438
# outer CV R2(train): 0.768, R2(test): 0.633
# outer CV R2(train): 0.747, R2(test): 0.679
# outer CV R2(train): 0.804, R2(test): 0.536
# outer CV R2(train): 0.804, R2(test): 0.523
# outer CV R2(train): 0.759, R2(test): 0.631
# outer CV R2(train): 0.794, R2(test): 0.538
# outer CV R2(train): 0.809, R2(test): 0.445
# outer CV R2(train): 0.763, R2(test): 0.565
# outer CV R2(train): 0.792, R2(test): 0.503
# outer CV R2(train): 0.826, R2(test): 0.473
# outer CV R2(train): 0.815, R2(test): 0.460
# outer CV R2(train): 0.792, R2(test): 0.475
# outer CV R2(train): 0.803, R2(test): 0.237
# outer CV R2(train): 0.779, R2(test): 0.515
# outer CV R2(train): 0.780, R2(test): 0.511
# outer CV R2(train): 0.809, R2(test): 0.452
# outer CV R2(train): 0.819, R2(test): 0.439
# outer CV R2(train): 0.765, R2(test): 0.584
# outer CV R2(train): 0.787, R2(test): 0.522
# outer CV R2(train): 0.774, R2(test): 0.614
# outer CV R2(train): 0.794, R2(test): 0.553
# outer CV R2(train): 0.790, R2(test): 0.573
# outer CV R2(train): 0.814, R2(test): 0.495
# outer CV R2(train): 0.821, R2(test): 0.310
# outer CV R2(train): 0.772, R2(test): 0.554
# outer CV R2(train): 0.746, R2(test): 0.695
# outer CV R2(train): 0.766, R2(test): 0.688
# outer CV R2(train): 0.825, R2(test): 0.513
# [Linear] total result = R2(train): 0.791, R2(test): 0.523
# ---------- Lasso ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.538, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.714, R2(test): 0.594
# inner CV: R2(test): 0.549, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.731, R2(test): 0.424
# inner CV: R2(test): 0.472, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.705, R2(test): 0.521
# inner CV: R2(test): 0.399, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.672, R2(test): 0.712
# inner CV: R2(test): 0.550, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.727, R2(test): 0.510
# inner CV: R2(test): 0.593, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.741, R2(test): 0.469
# inner CV: R2(test): 0.417, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.664, R2(test): 0.693
# inner CV: R2(test): 0.486, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.724, R2(test): 0.573
# inner CV: R2(test): 0.518, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.739, R2(test): 0.519
# inner CV: R2(test): 0.436, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.681, R2(test): 0.532
# inner CV: R2(test): 0.511, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.717, R2(test): 0.579
# inner CV: R2(test): 0.562, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.754, R2(test): 0.542
# inner CV: R2(test): 0.565, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.731, R2(test): 0.555
# inner CV: R2(test): 0.481, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.704, R2(test): 0.520
# inner CV: R2(test): 0.557, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.740, R2(test): 0.349
# inner CV: R2(test): 0.428, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.687, R2(test): 0.503
# inner CV: R2(test): 0.524, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.712, R2(test): 0.566
# inner CV: R2(test): 0.532, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.737, R2(test): 0.514
# inner CV: R2(test): 0.505, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.723, R2(test): 0.497
# inner CV: R2(test): 0.452, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.696, R2(test): 0.575
# inner CV: R2(test): 0.509, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.710, R2(test): 0.554
# inner CV: R2(test): 0.509, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.714, R2(test): 0.594
# inner CV: R2(test): 0.481, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.705, R2(test): 0.630
# inner CV: R2(test): 0.472, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.720, R2(test): 0.575
# inner CV: R2(test): 0.485, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.722, R2(test): 0.490
# inner CV: R2(test): 0.546, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.741, R2(test): 0.551
# inner CV: R2(test): 0.500, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.708, R2(test): 0.627
# inner CV: R2(test): 0.391, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.672, R2(test): 0.689
# inner CV: R2(test): 0.519, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.705, R2(test): 0.603
# inner CV: R2(test): 0.530, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.750, R2(test): 0.526
# [Lasso] total result = R2(train): 0.715, R2(test): 0.553
# ---------- Ridge ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.550, params: {'ridge__alpha': 100}, outer CV R2(train): 0.775, R2(test): 0.602
# inner CV: R2(test): 0.541, params: {'ridge__alpha': 100}, outer CV R2(train): 0.797, R2(test): 0.500
# inner CV: R2(test): 0.451, params: {'ridge__alpha': 100}, outer CV R2(train): 0.757, R2(test): 0.665
# inner CV: R2(test): 0.414, params: {'ridge__alpha': 100}, outer CV R2(train): 0.733, R2(test): 0.733
# inner CV: R2(test): 0.556, params: {'ridge__alpha': 100}, outer CV R2(train): 0.791, R2(test): 0.568
# inner CV: R2(test): 0.585, params: {'ridge__alpha': 100}, outer CV R2(train): 0.793, R2(test): 0.532
# inner CV: R2(test): 0.423, params: {'ridge__alpha': 100}, outer CV R2(train): 0.740, R2(test): 0.700
# inner CV: R2(test): 0.463, params: {'ridge__alpha': 100}, outer CV R2(train): 0.783, R2(test): 0.573
# inner CV: R2(test): 0.547, params: {'ridge__alpha': 100}, outer CV R2(train): 0.795, R2(test): 0.505
# inner CV: R2(test): 0.443, params: {'ridge__alpha': 100}, outer CV R2(train): 0.750, R2(test): 0.562
# inner CV: R2(test): 0.531, params: {'ridge__alpha': 100}, outer CV R2(train): 0.779, R2(test): 0.567
# inner CV: R2(test): 0.574, params: {'ridge__alpha': 100}, outer CV R2(train): 0.812, R2(test): 0.515
# inner CV: R2(test): 0.579, params: {'ridge__alpha': 100}, outer CV R2(train): 0.799, R2(test): 0.527
# inner CV: R2(test): 0.522, params: {'ridge__alpha': 100}, outer CV R2(train): 0.777, R2(test): 0.516
# inner CV: R2(test): 0.575, params: {'ridge__alpha': 100}, outer CV R2(train): 0.794, R2(test): 0.309
# inner CV: R2(test): 0.428, params: {'ridge__alpha': 100}, outer CV R2(train): 0.760, R2(test): 0.566
# inner CV: R2(test): 0.514, params: {'ridge__alpha': 100}, outer CV R2(train): 0.766, R2(test): 0.553
# inner CV: R2(test): 0.551, params: {'ridge__alpha': 100}, outer CV R2(train): 0.797, R2(test): 0.513
# inner CV: R2(test): 0.503, params: {'ridge__alpha': 100}, outer CV R2(train): 0.800, R2(test): 0.546
# inner CV: R2(test): 0.428, params: {'ridge__alpha': 100}, outer CV R2(train): 0.755, R2(test): 0.592
# inner CV: R2(test): 0.505, params: {'ridge__alpha': 100}, outer CV R2(train): 0.773, R2(test): 0.544
# inner CV: R2(test): 0.494, params: {'ridge__alpha': 100}, outer CV R2(train): 0.761, R2(test): 0.634
# inner CV: R2(test): 0.503, params: {'ridge__alpha': 100}, outer CV R2(train): 0.776, R2(test): 0.624
# inner CV: R2(test): 0.481, params: {'ridge__alpha': 100}, outer CV R2(train): 0.780, R2(test): 0.584
# inner CV: R2(test): 0.513, params: {'ridge__alpha': 100}, outer CV R2(train): 0.802, R2(test): 0.537
# inner CV: R2(test): 0.587, params: {'ridge__alpha': 100}, outer CV R2(train): 0.805, R2(test): 0.420
# inner CV: R2(test): 0.497, params: {'ridge__alpha': 100}, outer CV R2(train): 0.757, R2(test): 0.630
# inner CV: R2(test): 0.380, params: {'ridge__alpha': 100}, outer CV R2(train): 0.734, R2(test): 0.716
# inner CV: R2(test): 0.471, params: {'ridge__alpha': 100}, outer CV R2(train): 0.758, R2(test): 0.668
# inner CV: R2(test): 0.583, params: {'ridge__alpha': 100}, outer CV R2(train): 0.809, R2(test): 0.542
# [Ridge] total result = R2(train): 0.777, R2(test): 0.568
# ---------- ElasticNet ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.561, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.761, R2(test): 0.610
# inner CV: R2(test): 0.565, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.769, R2(test): 0.470
# inner CV: R2(test): 0.472, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.724, R2(test): 0.609
# inner CV: R2(test): 0.401, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.693, R2(test): 0.723
# inner CV: R2(test): 0.575, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.766, R2(test): 0.546
# inner CV: R2(test): 0.602, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.772, R2(test): 0.504
# inner CV: R2(test): 0.430, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.710, R2(test): 0.712
# inner CV: R2(test): 0.486, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.724, R2(test): 0.573
# inner CV: R2(test): 0.539, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.772, R2(test): 0.534
# inner CV: R2(test): 0.446, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.703, R2(test): 0.556
# inner CV: R2(test): 0.524, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.775, R2(test): 0.573
# inner CV: R2(test): 0.580, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.791, R2(test): 0.550
# inner CV: R2(test): 0.587, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.783, R2(test): 0.560
# inner CV: R2(test): 0.516, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.773, R2(test): 0.516
# inner CV: R2(test): 0.575, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.772, R2(test): 0.357
# inner CV: R2(test): 0.428, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.687, R2(test): 0.503
# inner CV: R2(test): 0.532, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.729, R2(test): 0.577
# inner CV: R2(test): 0.561, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.785, R2(test): 0.532
# inner CV: R2(test): 0.510, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.767, R2(test): 0.552
# inner CV: R2(test): 0.455, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.716, R2(test): 0.600
# inner CV: R2(test): 0.509, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.710, R2(test): 0.554
# inner CV: R2(test): 0.515, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.744, R2(test): 0.616
# inner CV: R2(test): 0.499, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.772, R2(test): 0.628
# inner CV: R2(test): 0.477, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.738, R2(test): 0.589
# inner CV: R2(test): 0.508, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.782, R2(test): 0.534
# inner CV: R2(test): 0.581, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.802, R2(test): 0.429
# inner CV: R2(test): 0.502, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.727, R2(test): 0.633
# inner CV: R2(test): 0.396, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.691, R2(test): 0.706
# inner CV: R2(test): 0.520, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.722, R2(test): 0.626
# inner CV: R2(test): 0.578, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.805, R2(test): 0.541
# [ElasticNet] total result = R2(train): 0.749, R2(test): 0.567
# ---------- PolyRidge ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.394, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.881, R2(test): 0.605
# inner CV: R2(test): 0.472, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.902, R2(test): 0.323
# inner CV: R2(test): 0.381, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.866, R2(test): 0.377
# inner CV: R2(test): 0.360, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.862, R2(test): 0.521
# inner CV: R2(test): 0.396, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.886, R2(test): 0.443
# inner CV: R2(test): 0.427, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.891, R2(test): 0.495
# inner CV: R2(test): 0.277, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.835, R2(test): 0.570
# inner CV: R2(test): 0.385, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.901, R2(test): 0.491
# inner CV: R2(test): 0.448, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.893, R2(test): 0.304
# inner CV: R2(test): 0.325, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.873, R2(test): 0.400
# inner CV: R2(test): 0.378, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.886, R2(test): 0.425
# inner CV: R2(test): 0.420, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.911, R2(test): 0.404
# inner CV: R2(test): 0.419, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.887, R2(test): 0.518
# inner CV: R2(test): 0.399, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.872, R2(test): 0.252
# inner CV: R2(test): 0.428, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.900, R2(test): 0.354
# inner CV: R2(test): 0.278, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.832, R2(test): 0.417
# inner CV: R2(test): 0.386, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.903, R2(test): 0.526
# inner CV: R2(test): 0.421, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.893, R2(test): 0.574
# inner CV: R2(test): 0.339, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.892, R2(test): 0.398
# inner CV: R2(test): 0.362, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.873, R2(test): 0.497
# inner CV: R2(test): 0.428, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.902, R2(test): 0.361
# inner CV: R2(test): 0.359, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.878, R2(test): 0.355
# inner CV: R2(test): 0.363, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.866, R2(test): 0.689
# inner CV: R2(test): 0.403, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.895, R2(test): 0.466
# inner CV: R2(test): 0.345, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.903, R2(test): 0.379
# inner CV: R2(test): 0.520, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.911, R2(test): 0.305
# inner CV: R2(test): 0.399, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.873, R2(test): 0.519
# inner CV: R2(test): 0.355, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.890, R2(test): 0.535
# inner CV: R2(test): 0.376, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.889, R2(test): 0.530
# inner CV: R2(test): 0.430, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.879, R2(test): 0.432
# [PolyRidge] total result = R2(train): 0.884, R2(test): 0.449
# ---------- RandomForest ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.540, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.942, R2(test): 0.663
# inner CV: R2(test): 0.530, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.943, R2(test): 0.516
# inner CV: R2(test): 0.482, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.867, R2(test): 0.434
# inner CV: R2(test): 0.434, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.925, R2(test): 0.744
# inner CV: R2(test): 0.571, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.953, R2(test): 0.494
# inner CV: R2(test): 0.587, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.945, R2(test): 0.502
# inner CV: R2(test): 0.439, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.937, R2(test): 0.685
# inner CV: R2(test): 0.495, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.856, R2(test): 0.582
# inner CV: R2(test): 0.510, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.944, R2(test): 0.501
# inner CV: R2(test): 0.456, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.935, R2(test): 0.532
# inner CV: R2(test): 0.438, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.923, R2(test): 0.697
# inner CV: R2(test): 0.574, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.946, R2(test): 0.530
# inner CV: R2(test): 0.589, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.950, R2(test): 0.526
# inner CV: R2(test): 0.470, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.936, R2(test): 0.540
# inner CV: R2(test): 0.558, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.939, R2(test): 0.519
# inner CV: R2(test): 0.396, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.917, R2(test): 0.585
# inner CV: R2(test): 0.485, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.929, R2(test): 0.654
# inner CV: R2(test): 0.564, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.940, R2(test): 0.573
# inner CV: R2(test): 0.452, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.937, R2(test): 0.546
# inner CV: R2(test): 0.506, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.932, R2(test): 0.539
# inner CV: R2(test): 0.531, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.944, R2(test): 0.546
# inner CV: R2(test): 0.488, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.936, R2(test): 0.622
# inner CV: R2(test): 0.464, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.931, R2(test): 0.708
# inner CV: R2(test): 0.511, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.943, R2(test): 0.548
# inner CV: R2(test): 0.521, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.940, R2(test): 0.509
# inner CV: R2(test): 0.555, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.944, R2(test): 0.449
# inner CV: R2(test): 0.514, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.926, R2(test): 0.667
# inner CV: R2(test): 0.437, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.939, R2(test): 0.696
# inner CV: R2(test): 0.481, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.936, R2(test): 0.602
# inner CV: R2(test): 0.528, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.948, R2(test): 0.582
# [RandomForest] total result = R2(train): 0.933, R2(test): 0.576
# ---------- SVR ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.530, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.818, R2(test): 0.678
# inner CV: R2(test): 0.555, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.852, R2(test): 0.545
# inner CV: R2(test): 0.538, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.896, R2(test): 0.663
# inner CV: R2(test): 0.500, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.890, R2(test): 0.732
# inner CV: R2(test): 0.609, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.893, R2(test): 0.590
# inner CV: R2(test): 0.592, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.844, R2(test): 0.505
# inner CV: R2(test): 0.467, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.879, R2(test): 0.669
# inner CV: R2(test): 0.511, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.851, R2(test): 0.660
# inner CV: R2(test): 0.585, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.847, R2(test): 0.514
# inner CV: R2(test): 0.467, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.806, R2(test): 0.549
# inner CV: R2(test): 0.557, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.827, R2(test): 0.633
# inner CV: R2(test): 0.625, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.861, R2(test): 0.517
# inner CV: R2(test): 0.619, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.899, R2(test): 0.533
# inner CV: R2(test): 0.530, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.822, R2(test): 0.539
# inner CV: R2(test): 0.582, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.847, R2(test): 0.458
# inner CV: R2(test): 0.481, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.884, R2(test): 0.589
# inner CV: R2(test): 0.533, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.824, R2(test): 0.639
# inner CV: R2(test): 0.624, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.856, R2(test): 0.530
# inner CV: R2(test): 0.528, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.887, R2(test): 0.608
# inner CV: R2(test): 0.507, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.899, R2(test): 0.557
# inner CV: R2(test): 0.543, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.835, R2(test): 0.563
# inner CV: R2(test): 0.558, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.830, R2(test): 0.660
# inner CV: R2(test): 0.499, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.885, R2(test): 0.668
# inner CV: R2(test): 0.541, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.894, R2(test): 0.599
# inner CV: R2(test): 0.579, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.857, R2(test): 0.597
# inner CV: R2(test): 0.589, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.909, R2(test): 0.347
# inner CV: R2(test): 0.502, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.817, R2(test): 0.633
# inner CV: R2(test): 0.485, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.888, R2(test): 0.644
# inner CV: R2(test): 0.522, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.897, R2(test): 0.645
# inner CV: R2(test): 0.602, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.845, R2(test): 0.591
# [SVR] total result = R2(train): 0.861, R2(test): 0.588
# ---------- XGBoost ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.585, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.867, R2(test): 0.677
# inner CV: R2(test): 0.586, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.890, R2(test): 0.436
# inner CV: R2(test): 0.526, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.798, R2(test): 0.574
# inner CV: R2(test): 0.482, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.776, R2(test): 0.734
# inner CV: R2(test): 0.595, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.966, R2(test): 0.526
# inner CV: R2(test): 0.630, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.880, R2(test): 0.436
# inner CV: R2(test): 0.470, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.849, R2(test): 0.761
# inner CV: R2(test): 0.556, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.865, R2(test): 0.606
# inner CV: R2(test): 0.556, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.815, R2(test): 0.528
# inner CV: R2(test): 0.483, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.949, R2(test): 0.599
# inner CV: R2(test): 0.501, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.792, R2(test): 0.666
# inner CV: R2(test): 0.624, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.889, R2(test): 0.519
# inner CV: R2(test): 0.622, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.953, R2(test): 0.548
# inner CV: R2(test): 0.547, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.875, R2(test): 0.609
# inner CV: R2(test): 0.583, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.816, R2(test): 0.496
# inner CV: R2(test): 0.445, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.856, R2(test): 0.550
# inner CV: R2(test): 0.533, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.798, R2(test): 0.622
# inner CV: R2(test): 0.611, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.887, R2(test): 0.525
# inner CV: R2(test): 0.509, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.871, R2(test): 0.569
# inner CV: R2(test): 0.525, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 10, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.983, R2(test): 0.561
# inner CV: R2(test): 0.572, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.827, R2(test): 0.613
# inner CV: R2(test): 0.545, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.862, R2(test): 0.643
# inner CV: R2(test): 0.515, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.869, R2(test): 0.636
# inner CV: R2(test): 0.555, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.887, R2(test): 0.622
# inner CV: R2(test): 0.580, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 10, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 1.000, R2(test): 0.606
# inner CV: R2(test): 0.588, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.876, R2(test): 0.563
# inner CV: R2(test): 0.563, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.868, R2(test): 0.630
# inner CV: R2(test): 0.458, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.945, R2(test): 0.686
# inner CV: R2(test): 0.520, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.799, R2(test): 0.617
# inner CV: R2(test): 0.590, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.907, R2(test): 0.598
# [XGBoost] total result = R2(train): 0.874, R2(test): 0.592
# ---------- LightGBM ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.357, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.812, R2(test): 0.545
# inner CV: R2(test): 0.390, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.799, R2(test): 0.575
# inner CV: R2(test): 0.475, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.818, R2(test): 0.436
# inner CV: R2(test): 0.278, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.769, R2(test): 0.684
# inner CV: R2(test): 0.465, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.825, R2(test): 0.453
# inner CV: R2(test): 0.469, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.817, R2(test): 0.431
# inner CV: R2(test): 0.247, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.776, R2(test): 0.627
# inner CV: R2(test): 0.429, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.827, R2(test): 0.377
# inner CV: R2(test): 0.463, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.813, R2(test): 0.526
# inner CV: R2(test): 0.366, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.715, R2(test): 0.551
# inner CV: R2(test): 0.326, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.732, R2(test): 0.577
# inner CV: R2(test): 0.433, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.831, R2(test): 0.462
# inner CV: R2(test): 0.455, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.832, R2(test): 0.417
# inner CV: R2(test): 0.412, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.825, R2(test): 0.427
# inner CV: R2(test): 0.336, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.809, R2(test): 0.499
# inner CV: R2(test): 0.240, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.749, R2(test): 0.548
# inner CV: R2(test): 0.419, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.797, R2(test): 0.534
# inner CV: R2(test): 0.397, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.847, R2(test): 0.341
# inner CV: R2(test): 0.295, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.820, R2(test): 0.382
# inner CV: R2(test): 0.392, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.793, R2(test): 0.441
# inner CV: R2(test): 0.404, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.831, R2(test): 0.519
# inner CV: R2(test): 0.374, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.784, R2(test): 0.473
# inner CV: R2(test): 0.319, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.796, R2(test): 0.605
# inner CV: R2(test): 0.408, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.803, R2(test): 0.569
# inner CV: R2(test): 0.436, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.824, R2(test): 0.507
# inner CV: R2(test): 0.378, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.817, R2(test): 0.474
# inner CV: R2(test): 0.402, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.799, R2(test): 0.566
# inner CV: R2(test): 0.368, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.800, R2(test): 0.671
# inner CV: R2(test): 0.341, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.763, R2(test): 0.583
# inner CV: R2(test): 0.426, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.837, R2(test): 0.488
# [LightGBM] total result = R2(train): 0.802, R2(test): 0.510
# ---------- HistGB ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.306, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.595, R2(test): 0.559
# inner CV: R2(test): 0.354, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.653, R2(test): 0.436
# inner CV: R2(test): 0.407, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.652, R2(test): 0.398
# inner CV: R2(test): 0.212, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.589, R2(test): 0.669
# inner CV: R2(test): 0.390, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.781, R2(test): 0.462
# inner CV: R2(test): 0.433, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.723, R2(test): 0.404
# inner CV: R2(test): 0.181, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.391, R2(test): 0.469
# inner CV: R2(test): 0.364, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.757, R2(test): 0.467
# inner CV: R2(test): 0.406, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.691, R2(test): 0.493
# inner CV: R2(test): 0.314, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.591, R2(test): 0.455
# inner CV: R2(test): 0.314, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.552, R2(test): 0.309
# inner CV: R2(test): 0.361, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.341, R2(test): 0.383
# inner CV: R2(test): 0.392, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.760, R2(test): 0.435
# inner CV: R2(test): 0.351, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.669, R2(test): 0.401
# inner CV: R2(test): 0.268, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.656, R2(test): 0.568
# inner CV: R2(test): 0.245, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.497, R2(test): 0.366
# inner CV: R2(test): 0.381, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.641, R2(test): 0.457
# inner CV: R2(test): 0.339, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.713, R2(test): 0.355
# ...
# inner CV: R2(test): 0.360, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.614, R2(test): 0.418
# inner CV: R2(test): 0.265, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.569, R2(test): 0.536
# inner CV: R2(test): 0.354, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.726, R2(test): 0.419
# inner CV: R2(test): 0.388, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.693, R2(test): 0.454
# inner CV: R2(test): 0.360, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.405, R2(test): 0.294
# inner CV: R2(test): 0.341, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.662, R2(test): 0.580
# inner CV: R2(test): 0.304, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.616, R2(test): 0.591
# inner CV: R2(test): 0.337, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.572, R2(test): 0.463
# inner CV: R2(test): 0.340, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.718, R2(test): 0.399
# [HistGB] total result = R2(train): 0.609, R2(test): 0.442
# ---------- KNN ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.376, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.503
# inner CV: R2(test): 0.400, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.378
# inner CV: R2(test): 0.434, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.396
# inner CV: R2(test): 0.388, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.455
# inner CV: R2(test): 0.501, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.333
# inner CV: R2(test): 0.405, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.544
# inner CV: R2(test): 0.354, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.549
# inner CV: R2(test): 0.329, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.465
# inner CV: R2(test): 0.519, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.055
# inner CV: R2(test): 0.318, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.411
# inner CV: R2(test): 0.439, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.282
# inner CV: R2(test): 0.423, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.496
# inner CV: R2(test): 0.490, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.361
# inner CV: R2(test): 0.419, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.339
# inner CV: R2(test): 0.407, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.399
# inner CV: R2(test): 0.282, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.416
# inner CV: R2(test): 0.430, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.437
# inner CV: R2(test): 0.444, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.534
# inner CV: R2(test): 0.376, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.404
# inner CV: R2(test): 0.401, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.497
# inner CV: R2(test): 0.408, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.298
# inner CV: R2(test): 0.396, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.423
# inner CV: R2(test): 0.352, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.602
# inner CV: R2(test): 0.460, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.322
# inner CV: R2(test): 0.381, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.294
# inner CV: R2(test): 0.501, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.339
# inner CV: R2(test): 0.336, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.606
# inner CV: R2(test): 0.342, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.548
# inner CV: R2(test): 0.377, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.551
# inner CV: R2(test): 0.491, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.257
# [KNN] total result = R2(train): 1.000, R2(test): 0.416
# ---------- MLP ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.130, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.834, R2(test): 0.556
# inner CV: R2(test): 0.239, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.931, R2(test): 0.210
# inner CV: R2(test): 0.207, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.877, R2(test): 0.468
# inner CV: R2(test): 0.172, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.774, R2(test): 0.513
# inner CV: R2(test): 0.307, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.890, R2(test): 0.338
# inner CV: R2(test): 0.243, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.684, R2(test): 0.285
# inner CV: R2(test): 0.033, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.747, R2(test): 0.607
# inner CV: R2(test): 0.134, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.631, R2(test): 0.333
# inner CV: R2(test): 0.357, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.904, R2(test): 0.157
# inner CV: R2(test): 0.131, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.654, R2(test): 0.215
# inner CV: R2(test): 0.282, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.850, R2(test): 0.426
# inner CV: R2(test): 0.219, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.897, R2(test): 0.013
# inner CV: R2(test): 0.291, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.550, R2(test): 0.341
# inner CV: R2(test): 0.175, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.784, R2(test): 0.510
# inner CV: R2(test): 0.288, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.910, R2(test): -0.053
# inner CV: R2(test): -0.006, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.446, R2(test): -1.167
# inner CV: R2(test): 0.174, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.559, R2(test): 0.057
# inner CV: R2(test): 0.246, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.630, R2(test): 0.167
# inner CV: R2(test): 0.202, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.867, R2(test): 0.334
# inner CV: R2(test): 0.189, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.937, R2(test): 0.354
# inner CV: R2(test): 0.165, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.708, R2(test): 0.110
# inner CV: R2(test): 0.165, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.762, R2(test): 0.368
# inner CV: R2(test): 0.161, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.01}, outer CV R2(train): 0.800, R2(test): -0.122
# inner CV: R2(test): 0.244, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.911, R2(test): 0.328
# inner CV: R2(test): 0.136, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.729, R2(test): 0.373
# inner CV: R2(test): 0.360, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.740, R2(test): 0.228
# inner CV: R2(test): 0.196, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.510, R2(test): 0.316
# inner CV: R2(test): 0.068, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.709, R2(test): 0.355
# inner CV: R2(test): 0.137, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.764, R2(test): 0.457
# inner CV: R2(test): 0.307, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.756, R2(test): 0.261
# [MLP] total result = R2(train): 0.758, R2(test): 0.245

# %%
import pandas as pd
df = pd.read_csv('RDKit_descriptors_revise.csv')
df2 = df.iloc[:,13:].dropna()
y = df2.iloc[:,0]
X = df2.iloc[:,1:]

import numpy as np
from sklearn.model_selection import cross_val_score, GridSearchCV, RepeatedKFold
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=Warning)

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0, 0.2, 0.4, 0.5, 0.6, 0.8, 1],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },    
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10, 15],
        'randomforestregressor__min_samples_leaf': [1, 2, 5],
    },
    "SVR": {
        'svr__C': [0.01, 0.1, 1, 10, 100],
        'svr__epsilon': [0.5, 1.0, 2.0],
        'svr__kernel': ['rbf', 'linear'],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [2, 5, 10],
        'xgbregressor__n_estimators': [50, 100, 200],
        'xgbregressor__subsample': [0.6, 0.8, 1.0],
        'xgbregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "LightGBM": {
        'lgbmregressor__n_estimators': [50, 100, 200],
        'lgbmregressor__max_depth': [3, 5, 7],
        'lgbmregressor__learning_rate': [0.01, 0.05, 0.1],
        'lgbmregressor__subsample': [0.6, 0.8, 1.0],
        'lgbmregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1, 0.2],
        "histgradientboostingregressor__max_depth": [1, 3, 5, 7],
        "histgradientboostingregressor__max_iter": [100, 200],
        "histgradientboostingregressor__l2_regularization": [0.0, 0.1, 1.0],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7, 10],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__metric': ['euclidean', 'manhattan'],
        'kneighborsregressor__p': [1, 2]
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,), (50, 20)],
        'mlpregressor__alpha': [1e-4, 1e-3, 1e-2],
        'mlpregressor__learning_rate_init': [0.0001, 0.001, 0.01],
    }
}

# モデルの設定
models = {
    "Linear": LinearRegression(),
    "Lasso": Lasso(max_iter=10000),
    "Ridge": Ridge(max_iter=10000),
    "ElasticNet": ElasticNet(max_iter=50000),
    "PolyRidge": make_pipeline( PCA(n_components=20), PolynomialFeatures(), StandardScaler(), Ridge()),
    "RandomForest": RandomForestRegressor(),
    "SVR": SVR(),
    "XGBoost": XGBRegressor(verbosity=0, n_jobs=-1),
    "LightGBM": LGBMRegressor(verbose=-1, n_jobs=-1),
    "HistGB": HistGradientBoostingRegressor(early_stopping=True),
    "KNN": KNeighborsRegressor(),
    "MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1)
}

n_repeats = 10
outer_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    print( '----------', name, '----------\nparams, R2(train), R2(test)')
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)

    tot_train = []
    tot_test = []
    
    for train_idx, test_idx in outer_cv.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        if name in param_grids:
            grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
            grid.fit(X_train, y_train)
            
            y_train_pred = grid.predict(X_train)
            y_test_pred  = grid.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"inner CV: R2(test): {grid.best_score_:.3f}, params: {grid.best_params_}, outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
        
        else:
            pipeline.fit(X_train, y_train)
            y_train_pred = pipeline.predict(X_train)
            y_test_pred  = pipeline.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
            
        tot_train.append(train_r2)
        tot_test.append(test_r2)
    
    print(f"[{name}] total result = R2(train): {np.mean(tot_train):.3f}, R2(test): {np.mean(tot_test):.3f}")
# Out:
# ---------- Linear ----------
# params, R2(train), R2(test)
# outer CV R2(train): 0.783, R2(test): 0.572
# outer CV R2(train): 0.798, R2(test): 0.498
# outer CV R2(train): 0.766, R2(test): 0.660
# outer CV R2(train): 0.740, R2(test): 0.698
# outer CV R2(train): 0.799, R2(test): 0.550
# outer CV R2(train): 0.800, R2(test): 0.527
# outer CV R2(train): 0.748, R2(test): 0.659
# outer CV R2(train): 0.787, R2(test): 0.572
# outer CV R2(train): 0.800, R2(test): 0.500
# outer CV R2(train): 0.749, R2(test): 0.605
# outer CV R2(train): 0.788, R2(test): 0.500
# outer CV R2(train): 0.821, R2(test): 0.500
# outer CV R2(train): 0.808, R2(test): 0.463
# outer CV R2(train): 0.781, R2(test): 0.511
# outer CV R2(train): 0.797, R2(test): 0.303
# outer CV R2(train): 0.773, R2(test): 0.515
# outer CV R2(train): 0.766, R2(test): 0.587
# outer CV R2(train): 0.808, R2(test): 0.458
# outer CV R2(train): 0.813, R2(test): 0.475
# outer CV R2(train): 0.760, R2(test): 0.601
# outer CV R2(train): 0.776, R2(test): 0.575
# outer CV R2(train): 0.768, R2(test): 0.629
# outer CV R2(train): 0.782, R2(test): 0.589
# outer CV R2(train): 0.786, R2(test): 0.590
# outer CV R2(train): 0.810, R2(test): 0.499
# outer CV R2(train): 0.812, R2(test): 0.358
# outer CV R2(train): 0.768, R2(test): 0.563
# outer CV R2(train): 0.739, R2(test): 0.716
# outer CV R2(train): 0.764, R2(test): 0.683
# outer CV R2(train): 0.817, R2(test): 0.528
# [Linear] total result = R2(train): 0.784, R2(test): 0.549
# ---------- Lasso ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.514, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.780, R2(test): 0.590
# inner CV: R2(test): 0.508, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.693, R2(test): 0.426
# inner CV: R2(test): 0.463, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.695, R2(test): 0.550
# inner CV: R2(test): 0.404, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.637, R2(test): 0.638
# inner CV: R2(test): 0.555, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.716, R2(test): 0.461
# inner CV: R2(test): 0.551, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.798, R2(test): 0.535
# inner CV: R2(test): 0.398, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.629, R2(test): 0.663
# inner CV: R2(test): 0.463, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.682, R2(test): 0.525
# inner CV: R2(test): 0.525, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.725, R2(test): 0.436
# inner CV: R2(test): 0.415, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.654, R2(test): 0.508
# inner CV: R2(test): 0.469, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.692, R2(test): 0.554
# inner CV: R2(test): 0.539, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.734, R2(test): 0.456
# inner CV: R2(test): 0.536, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.805, R2(test): 0.481
# inner CV: R2(test): 0.496, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.703, R2(test): 0.515
# inner CV: R2(test): 0.568, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.734, R2(test): 0.318
# inner CV: R2(test): 0.452, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.666, R2(test): 0.430
# inner CV: R2(test): 0.517, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.707, R2(test): 0.491
# inner CV: R2(test): 0.509, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.684, R2(test): 0.453
# inner CV: R2(test): 0.414, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.676, R2(test): 0.571
# inner CV: R2(test): 0.463, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.680, R2(test): 0.555
# inner CV: R2(test): 0.482, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.693, R2(test): 0.471
# inner CV: R2(test): 0.483, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.679, R2(test): 0.593
# inner CV: R2(test): 0.449, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.674, R2(test): 0.627
# inner CV: R2(test): 0.448, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.694, R2(test): 0.536
# inner CV: R2(test): 0.448, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.691, R2(test): 0.558
# inner CV: R2(test): 0.563, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.723, R2(test): 0.414
# inner CV: R2(test): 0.479, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.671, R2(test): 0.567
# inner CV: R2(test): 0.366, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.635, R2(test): 0.651
# inner CV: R2(test): 0.461, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.670, R2(test): 0.584
# inner CV: R2(test): 0.544, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.730, R2(test): 0.464
# [Lasso] total result = R2(train): 0.698, R2(test): 0.521
# ---------- Ridge ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.540, params: {'ridge__alpha': 100}, outer CV R2(train): 0.781, R2(test): 0.584
# inner CV: R2(test): 0.484, params: {'ridge__alpha': 100}, outer CV R2(train): 0.795, R2(test): 0.507
# inner CV: R2(test): 0.424, params: {'ridge__alpha': 100}, outer CV R2(train): 0.763, R2(test): 0.658
# inner CV: R2(test): 0.344, params: {'ridge__alpha': 100}, outer CV R2(train): 0.738, R2(test): 0.710
# inner CV: R2(test): 0.536, params: {'ridge__alpha': 100}, outer CV R2(train): 0.797, R2(test): 0.550
# inner CV: R2(test): 0.571, params: {'ridge__alpha': 100}, outer CV R2(train): 0.797, R2(test): 0.554
# inner CV: R2(test): 0.370, params: {'ridge__alpha': 100}, outer CV R2(train): 0.745, R2(test): 0.685
# inner CV: R2(test): 0.420, params: {'ridge__alpha': 100}, outer CV R2(train): 0.785, R2(test): 0.587
# inner CV: R2(test): 0.506, params: {'ridge__alpha': 100}, outer CV R2(train): 0.799, R2(test): 0.499
# inner CV: R2(test): 0.366, params: {'ridge__alpha': 100}, outer CV R2(train): 0.747, R2(test): 0.599
# inner CV: R2(test): 0.509, params: {'ridge__alpha': 100}, outer CV R2(train): 0.785, R2(test): 0.526
# inner CV: R2(test): 0.529, params: {'ridge__alpha': 100}, outer CV R2(train): 0.819, R2(test): 0.518
# inner CV: R2(test): 0.563, params: {'ridge__alpha': 100}, outer CV R2(train): 0.805, R2(test): 0.479
# inner CV: R2(test): 0.485, params: {'ridge__alpha': 100}, outer CV R2(train): 0.778, R2(test): 0.537
# inner CV: R2(test): 0.533, params: {'ridge__alpha': 100}, outer CV R2(train): 0.795, R2(test): 0.315
# inner CV: R2(test): 0.400, params: {'ridge__alpha': 100}, outer CV R2(train): 0.770, R2(test): 0.538
# inner CV: R2(test): 0.479, params: {'ridge__alpha': 100}, outer CV R2(train): 0.764, R2(test): 0.580
# inner CV: R2(test): 0.548, params: {'ridge__alpha': 100}, outer CV R2(train): 0.805, R2(test): 0.489
# inner CV: R2(test): 0.441, params: {'ridge__alpha': 100}, outer CV R2(train): 0.810, R2(test): 0.512
# inner CV: R2(test): 0.399, params: {'ridge__alpha': 100}, outer CV R2(train): 0.758, R2(test): 0.606
# inner CV: R2(test): 0.449, params: {'ridge__alpha': 100}, outer CV R2(train): 0.774, R2(test): 0.564
# inner CV: R2(test): 0.475, params: {'ridge__alpha': 100}, outer CV R2(train): 0.765, R2(test): 0.648
# inner CV: R2(test): 0.478, params: {'ridge__alpha': 100}, outer CV R2(train): 0.780, R2(test): 0.604
# inner CV: R2(test): 0.420, params: {'ridge__alpha': 100}, outer CV R2(train): 0.784, R2(test): 0.591
# inner CV: R2(test): 0.438, params: {'ridge__alpha': 100}, outer CV R2(train): 0.805, R2(test): 0.543
# inner CV: R2(test): 0.548, params: {'ridge__alpha': 100}, outer CV R2(train): 0.810, R2(test): 0.386
# inner CV: R2(test): 0.486, params: {'ridge__alpha': 100}, outer CV R2(train): 0.765, R2(test): 0.590
# inner CV: R2(test): 0.306, params: {'ridge__alpha': 100}, outer CV R2(train): 0.737, R2(test): 0.724
# inner CV: R2(test): 0.441, params: {'ridge__alpha': 100}, outer CV R2(train): 0.762, R2(test): 0.696
# inner CV: R2(test): 0.575, params: {'ridge__alpha': 100}, outer CV R2(train): 0.815, R2(test): 0.530
# [Ridge] total result = R2(train): 0.781, R2(test): 0.564
# ---------- ElasticNet ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.534, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.780, R2(test): 0.585
# inner CV: R2(test): 0.517, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.725, R2(test): 0.512
# inner CV: R2(test): 0.467, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.713, R2(test): 0.557
# inner CV: R2(test): 0.428, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.669, R2(test): 0.701
# inner CV: R2(test): 0.574, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.739, R2(test): 0.502
# inner CV: R2(test): 0.575, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.4}, outer CV R2(train): 0.773, R2(test): 0.529
# inner CV: R2(test): 0.408, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.680, R2(test): 0.681
# inner CV: R2(test): 0.483, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.709, R2(test): 0.581
# inner CV: R2(test): 0.563, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.744, R2(test): 0.439
# inner CV: R2(test): 0.437, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.683, R2(test): 0.519
# inner CV: R2(test): 0.522, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.709, R2(test): 0.513
# inner CV: R2(test): 0.563, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.746, R2(test): 0.519
# inner CV: R2(test): 0.579, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.733, R2(test): 0.499
# inner CV: R2(test): 0.522, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.750, R2(test): 0.488
# inner CV: R2(test): 0.574, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.750, R2(test): 0.301
# inner CV: R2(test): 0.459, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.690, R2(test): 0.451
# inner CV: R2(test): 0.524, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.723, R2(test): 0.500
# inner CV: R2(test): 0.541, params: {'elasticnet__alpha': 1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.803, R2(test): 0.493
# inner CV: R2(test): 0.454, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.4}, outer CV R2(train): 0.780, R2(test): 0.553
# inner CV: R2(test): 0.463, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.680, R2(test): 0.555
# inner CV: R2(test): 0.513, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.715, R2(test): 0.461
# inner CV: R2(test): 0.500, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.726, R2(test): 0.591
# inner CV: R2(test): 0.498, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.708, R2(test): 0.634
# inner CV: R2(test): 0.491, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.725, R2(test): 0.515
# inner CV: R2(test): 0.501, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.4}, outer CV R2(train): 0.768, R2(test): 0.530
# inner CV: R2(test): 0.597, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.752, R2(test): 0.440
# inner CV: R2(test): 0.516, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.687, R2(test): 0.588
# inner CV: R2(test): 0.370, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.661, R2(test): 0.687
# inner CV: R2(test): 0.475, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.692, R2(test): 0.663
# inner CV: R2(test): 0.600, params: {'elasticnet__alpha': 10, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.750, R2(test): 0.459
# [ElasticNet] total result = R2(train): 0.725, R2(test): 0.535
# ---------- PolyRidge ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.410, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.823, R2(test): 0.532
# inner CV: R2(test): 0.401, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.865, R2(test): 0.487
# inner CV: R2(test): 0.194, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.831, R2(test): 0.407
# inner CV: R2(test): 0.293, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.847, R2(test): 0.548
# inner CV: R2(test): 0.512, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.883, R2(test): 0.195
# inner CV: R2(test): 0.373, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.839, R2(test): 0.441
# inner CV: R2(test): 0.269, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.829, R2(test): 0.643
# inner CV: R2(test): 0.361, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.864, R2(test): 0.524
# inner CV: R2(test): 0.498, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.891, R2(test): 0.099
# inner CV: R2(test): 0.245, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.821, R2(test): 0.450
# inner CV: R2(test): 0.376, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.855, R2(test): 0.245
# inner CV: R2(test): 0.474, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.880, R2(test): 0.364
# inner CV: R2(test): 0.468, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.866, R2(test): 0.393
# inner CV: R2(test): 0.431, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.858, R2(test): 0.266
# inner CV: R2(test): 0.490, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.881, R2(test): -0.406
# inner CV: R2(test): 0.318, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.840, R2(test): 0.383
# inner CV: R2(test): 0.356, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.851, R2(test): 0.207
# inner CV: R2(test): 0.397, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.837, R2(test): 0.263
# inner CV: R2(test): 0.350, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.859, R2(test): 0.435
# inner CV: R2(test): 0.288, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.855, R2(test): 0.198
# inner CV: R2(test): 0.326, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.838, R2(test): 0.480
# inner CV: R2(test): 0.302, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.807, R2(test): 0.555
# inner CV: R2(test): 0.341, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.818, R2(test): 0.477
# inner CV: R2(test): 0.377, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.868, R2(test): 0.480
# inner CV: R2(test): 0.272, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.820, R2(test): 0.391
# inner CV: R2(test): 0.524, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.891, R2(test): -0.114
# inner CV: R2(test): 0.404, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.856, R2(test): 0.525
# inner CV: R2(test): 0.262, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.869, R2(test): 0.447
# inner CV: R2(test): 0.318, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.831, R2(test): 0.573
# inner CV: R2(test): 0.415, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.847, R2(test): 0.365
# [PolyRidge] total result = R2(train): 0.851, R2(test): 0.362
# ---------- RandomForest ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.549, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.908, R2(test): 0.611
# inner CV: R2(test): 0.507, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.858, R2(test): 0.456
# inner CV: R2(test): 0.523, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.926, R2(test): 0.397
# inner CV: R2(test): 0.449, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.898, R2(test): 0.621
# inner CV: R2(test): 0.637, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.951, R2(test): 0.439
# inner CV: R2(test): 0.526, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.929, R2(test): 0.614
# inner CV: R2(test): 0.451, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.915, R2(test): 0.641
# inner CV: R2(test): 0.494, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.908, R2(test): 0.603
# inner CV: R2(test): 0.570, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.932, R2(test): 0.328
# inner CV: R2(test): 0.454, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.919, R2(test): 0.576
# inner CV: R2(test): 0.469, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.851, R2(test): 0.634
# inner CV: R2(test): 0.556, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.937, R2(test): 0.467
# inner CV: R2(test): 0.622, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.947, R2(test): 0.494
# inner CV: R2(test): 0.499, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.922, R2(test): 0.506
# inner CV: R2(test): 0.569, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.921, R2(test): 0.512
# inner CV: R2(test): 0.453, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.893, R2(test): 0.549
# inner CV: R2(test): 0.495, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.865, R2(test): 0.568
# inner CV: R2(test): 0.590, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.937, R2(test): 0.526
# inner CV: R2(test): 0.457, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.910, R2(test): 0.583
# inner CV: R2(test): 0.519, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.926, R2(test): 0.608
# inner CV: R2(test): 0.522, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.857, R2(test): 0.537
# inner CV: R2(test): 0.500, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.919, R2(test): 0.610
# inner CV: R2(test): 0.489, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.906, R2(test): 0.701
# inner CV: R2(test): 0.523, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.930, R2(test): 0.545
# inner CV: R2(test): 0.474, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.933, R2(test): 0.530
# inner CV: R2(test): 0.590, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.930, R2(test): 0.353
# inner CV: R2(test): 0.504, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.912, R2(test): 0.701
# inner CV: R2(test): 0.433, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.913, R2(test): 0.698
# inner CV: R2(test): 0.499, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.858, R2(test): 0.566
# inner CV: R2(test): 0.553, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.922, R2(test): 0.559
# [RandomForest] total result = R2(train): 0.911, R2(test): 0.551
# ---------- SVR ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.532, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.792, R2(test): 0.640
# inner CV: R2(test): 0.523, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.862, R2(test): 0.607
# inner CV: R2(test): 0.566, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.889, R2(test): 0.695
# inner CV: R2(test): 0.531, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.870, R2(test): 0.690
# inner CV: R2(test): 0.641, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.893, R2(test): 0.531
# inner CV: R2(test): 0.578, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.867, R2(test): 0.527
# inner CV: R2(test): 0.495, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.850, R2(test): 0.700
# inner CV: R2(test): 0.524, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.874, R2(test): 0.665
# inner CV: R2(test): 0.634, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.906, R2(test): 0.414
# inner CV: R2(test): 0.461, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.863, R2(test): 0.630
# inner CV: R2(test): 0.542, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.806, R2(test): 0.610
# inner CV: R2(test): 0.644, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.892, R2(test): 0.342
# inner CV: R2(test): 0.657, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.895, R2(test): 0.486
# inner CV: R2(test): 0.508, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.871, R2(test): 0.610
# inner CV: R2(test): 0.595, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.830, R2(test): 0.341
# inner CV: R2(test): 0.505, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.867, R2(test): 0.560
# inner CV: R2(test): 0.523, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.796, R2(test): 0.617
# inner CV: R2(test): 0.632, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.883, R2(test): 0.514
# inner CV: R2(test): 0.547, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.877, R2(test): 0.587
# inner CV: R2(test): 0.534, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.884, R2(test): 0.532
# inner CV: R2(test): 0.539, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.812, R2(test): 0.502
# inner CV: R2(test): 0.554, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.806, R2(test): 0.659
# inner CV: R2(test): 0.519, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.852, R2(test): 0.690
# inner CV: R2(test): 0.570, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.891, R2(test): 0.564
# inner CV: R2(test): 0.574, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.882, R2(test): 0.568
# inner CV: R2(test): 0.619, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.892, R2(test): 0.491
# inner CV: R2(test): 0.536, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.864, R2(test): 0.635
# inner CV: R2(test): 0.480, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.876, R2(test): 0.685
# inner CV: R2(test): 0.538, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.867, R2(test): 0.680
# inner CV: R2(test): 0.616, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.834, R2(test): 0.554
# [SVR] total result = R2(train): 0.861, R2(test): 0.578
# ---------- XGBoost ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.559, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.854, R2(test): 0.630
# inner CV: R2(test): 0.515, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.786, R2(test): 0.443
# inner CV: R2(test): 0.559, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.949, R2(test): 0.415
# inner CV: R2(test): 0.467, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.923, R2(test): 0.694
# inner CV: R2(test): 0.654, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.954, R2(test): 0.521
# inner CV: R2(test): 0.584, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.864, R2(test): 0.536
# inner CV: R2(test): 0.475, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.843, R2(test): 0.708
# inner CV: R2(test): 0.514, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.799, R2(test): 0.566
# inner CV: R2(test): 0.585, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.956, R2(test): 0.325
# inner CV: R2(test): 0.483, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.923, R2(test): 0.595
# inner CV: R2(test): 0.482, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.784, R2(test): 0.629
# inner CV: R2(test): 0.605, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.888, R2(test): 0.384
# inner CV: R2(test): 0.639, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.965, R2(test): 0.462
# inner CV: R2(test): 0.551, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.881, R2(test): 0.547
# inner CV: R2(test): 0.586, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.812, R2(test): 0.461
# inner CV: R2(test): 0.457, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.841, R2(test): 0.534
# inner CV: R2(test): 0.527, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.794, R2(test): 0.552
# inner CV: R2(test): 0.611, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.950, R2(test): 0.522
# inner CV: R2(test): 0.504, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.922, R2(test): 0.560
# inner CV: R2(test): 0.528, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.945, R2(test): 0.577
# inner CV: R2(test): 0.532, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.810, R2(test): 0.534
# inner CV: R2(test): 0.522, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.862, R2(test): 0.634
# inner CV: R2(test): 0.515, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.839, R2(test): 0.669
# inner CV: R2(test): 0.555, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.940, R2(test): 0.564
# inner CV: R2(test): 0.517, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.892, R2(test): 0.524
# inner CV: R2(test): 0.614, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.877, R2(test): 0.402
# inner CV: R2(test): 0.534, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.851, R2(test): 0.604
# inner CV: R2(test): 0.425, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.927, R2(test): 0.714
# inner CV: R2(test): 0.503, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.789, R2(test): 0.586
# inner CV: R2(test): 0.601, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.824, R2(test): 0.536
# [XGBoost] total result = R2(train): 0.875, R2(test): 0.547
# ---------- LightGBM ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.506, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.821, R2(test): 0.621
# inner CV: R2(test): 0.529, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.793, R2(test): 0.518
# inner CV: R2(test): 0.498, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.838, R2(test): 0.493
# inner CV: R2(test): 0.445, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.699, R2(test): 0.703
# inner CV: R2(test): 0.488, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.850, R2(test): 0.553
# inner CV: R2(test): 0.536, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.822, R2(test): 0.402
# inner CV: R2(test): 0.404, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.794, R2(test): 0.665
# inner CV: R2(test): 0.508, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.828, R2(test): 0.515
# inner CV: R2(test): 0.509, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.836, R2(test): 0.523
# inner CV: R2(test): 0.432, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.790, R2(test): 0.489
# inner CV: R2(test): 0.487, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.800, R2(test): 0.642
# inner CV: R2(test): 0.493, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.868, R2(test): 0.404
# inner CV: R2(test): 0.535, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.833, R2(test): 0.474
# inner CV: R2(test): 0.487, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.816, R2(test): 0.573
# inner CV: R2(test): 0.572, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.842, R2(test): 0.272
# inner CV: R2(test): 0.322, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.800, R2(test): 0.543
# inner CV: R2(test): 0.501, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.800, R2(test): 0.503
# inner CV: R2(test): 0.566, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.849, R2(test): 0.453
# inner CV: R2(test): 0.426, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.808, R2(test): 0.608
# inner CV: R2(test): 0.459, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.822, R2(test): 0.581
# inner CV: R2(test): 0.519, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.817, R2(test): 0.542
# inner CV: R2(test): 0.469, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.820, R2(test): 0.461
# inner CV: R2(test): 0.491, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.800, R2(test): 0.635
# inner CV: R2(test): 0.482, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.826, R2(test): 0.609
# inner CV: R2(test): 0.507, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.852, R2(test): 0.544
# inner CV: R2(test): 0.503, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.823, R2(test): 0.522
# inner CV: R2(test): 0.477, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.817, R2(test): 0.641
# inner CV: R2(test): 0.352, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.783, R2(test): 0.707
# inner CV: R2(test): 0.477, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 100, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.761, R2(test): 0.613
# inner CV: R2(test): 0.584, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.837, R2(test): 0.516
# [LightGBM] total result = R2(train): 0.815, R2(test): 0.544
# ---------- HistGB ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.356, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.740, R2(test): 0.601
# inner CV: R2(test): 0.417, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.651, R2(test): 0.441
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 119
#     117 if name in param_grids:
#     118     grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
# --> 119     grid.fit(X_train, y_train)
#     121     y_train_pred = grid.predict(X_train)
#     122     y_test_pred  = grid.predict(X_test)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1571, in GridSearchCV._run_search(self, evaluate_candidates)
#    1569 def _run_search(self, evaluate_candidates):
#    1570     """Search all candidates in param_grid"""
# -> 1571     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
import pandas as pd
df = pd.read_csv('RDKit_descriptors_revise.csv')
df2 = df.iloc[:,13:].dropna()
y = df2.iloc[:,0]
X = df2.iloc[:,1:]

import numpy as np
from sklearn.model_selection import cross_val_score, GridSearchCV, RepeatedKFold
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.decomposition import PCA
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=Warning)

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0, 0.2, 0.4, 0.5, 0.6, 0.8, 1],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },    
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10, 15],
        'randomforestregressor__min_samples_leaf': [1, 2, 5],
    },
    "SVR": {
        'svr__C': [0.01, 0.1, 1, 10, 100],
        'svr__epsilon': [0.5, 1.0, 2.0],
        'svr__kernel': ['rbf', 'linear'],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [2, 5, 10],
        'xgbregressor__n_estimators': [50, 100, 200],
        'xgbregressor__subsample': [0.6, 0.8, 1.0],
        'xgbregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "LightGBM": {
        'lgbmregressor__n_estimators': [50, 100, 200],
        'lgbmregressor__max_depth': [3, 5, 7],
        'lgbmregressor__learning_rate': [0.01, 0.05, 0.1],
        'lgbmregressor__subsample': [0.6, 0.8, 1.0],
        'lgbmregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1, 0.2],
        "histgradientboostingregressor__max_depth": [1, 3, 5, 7],
        "histgradientboostingregressor__max_iter": [100, 200],
        "histgradientboostingregressor__l2_regularization": [0.0, 0.1, 1.0],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7, 10],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__metric': ['euclidean', 'manhattan'],
        'kneighborsregressor__p': [1, 2]
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,), (50, 20)],
        'mlpregressor__alpha': [1e-4, 1e-3, 1e-2],
        'mlpregressor__learning_rate_init': [0.0001, 0.001, 0.01],
    }
}

# モデルの設定
models = {
    #"Linear": LinearRegression(),
    #"Lasso": Lasso(max_iter=10000),
    #"Ridge": Ridge(max_iter=10000),
    #"ElasticNet": ElasticNet(max_iter=50000),
    #"PolyRidge": make_pipeline( PCA(n_components=20), StandardScaler(), PolynomialFeatures(), Ridge()),
    #"RandomForest": RandomForestRegressor(),
    #"SVR": SVR(),
    #"XGBoost": XGBRegressor(verbosity=0, n_jobs=-1),
    #"LightGBM": LGBMRegressor(verbose=-1, n_jobs=-1),
    #"HistGB": HistGradientBoostingRegressor(early_stopping=True),
    "KNN": KNeighborsRegressor(),
    "MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1)
}

n_repeats = 10
outer_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    print( '----------', name, '----------\nparams, R2(train), R2(test)')
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)

    tot_train = []
    tot_test = []
    
    for train_idx, test_idx in outer_cv.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        if name in param_grids:
            grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
            grid.fit(X_train, y_train)
            
            y_train_pred = grid.predict(X_train)
            y_test_pred  = grid.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"inner CV: R2(test): {grid.best_score_:.3f}, params: {grid.best_params_}, outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
        
        else:
            pipeline.fit(X_train, y_train)
            y_train_pred = pipeline.predict(X_train)
            y_test_pred  = pipeline.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
            
        tot_train.append(train_r2)
        tot_test.append(test_r2)
    
    print(f"[{name}] total result = R2(train): {np.mean(tot_train):.3f}, R2(test): {np.mean(tot_test):.3f}")
# Out:
# ---------- KNN ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.324, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.949, R2(test): 0.545
# inner CV: R2(test): 0.315, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train): 0.697, R2(test): 0.468
# inner CV: R2(test): 0.365, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.975, R2(test): 0.287
# inner CV: R2(test): 0.283, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.964, R2(test): 0.466
# inner CV: R2(test): 0.506, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.984, R2(test): 0.200
# inner CV: R2(test): 0.312, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.976, R2(test): 0.457
# inner CV: R2(test): 0.240, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train): 0.702, R2(test): 0.523
# inner CV: R2(test): 0.229, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'uniform'}, outer CV R2(train): 0.672, R2(test): 0.386
# inner CV: R2(test): 0.511, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.982, R2(test): 0.035
# inner CV: R2(test): 0.211, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.961, R2(test): 0.366
# inner CV: R2(test): 0.381, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.951, R2(test): 0.296
# inner CV: R2(test): 0.414, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.987, R2(test): 0.445
# inner CV: R2(test): 0.508, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.985, R2(test): 0.257
# inner CV: R2(test): 0.366, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.975, R2(test): 0.123
# inner CV: R2(test): 0.343, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.961, R2(test): 0.354
# inner CV: R2(test): 0.234, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.954, R2(test): 0.288
# inner CV: R2(test): 0.350, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.982, R2(test): 0.390
# inner CV: R2(test): 0.415, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.982, R2(test): 0.353
# inner CV: R2(test): 0.309, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.971, R2(test): 0.359
# inner CV: R2(test): 0.345, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.985, R2(test): 0.305
# inner CV: R2(test): 0.355, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.966, R2(test): 0.333
# inner CV: R2(test): 0.336, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.970, R2(test): 0.397
# inner CV: R2(test): 0.259, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.946, R2(test): 0.673
# inner CV: R2(test): 0.416, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.978, R2(test): 0.280
# inner CV: R2(test): 0.332, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.992, R2(test): 0.300
# inner CV: R2(test): 0.474, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.976, R2(test): 0.018
# inner CV: R2(test): 0.277, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.960, R2(test): 0.688
# inner CV: R2(test): 0.238, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.970, R2(test): 0.589
# inner CV: R2(test): 0.284, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.959, R2(test): 0.568
# inner CV: R2(test): 0.422, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 0.971, R2(test): 0.300
# [KNN] total result = R2(train): 0.943, R2(test): 0.368
# ---------- MLP ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.199, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.843, R2(test): 0.549
# inner CV: R2(test): 0.305, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.881, R2(test): 0.146
# inner CV: R2(test): 0.210, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.039, R2(test): -0.476
# inner CV: R2(test): 0.152, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.841, R2(test): 0.614
# inner CV: R2(test): 0.344, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.906, R2(test): 0.195
# inner CV: R2(test): 0.360, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.803, R2(test): 0.498
# inner CV: R2(test): 0.043, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.864, R2(test): 0.663
# inner CV: R2(test): 0.228, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.903, R2(test): 0.577
# inner CV: R2(test): 0.380, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.898, R2(test): 0.396
# inner CV: R2(test): 0.133, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.797, R2(test): 0.539
# inner CV: R2(test): 0.338, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.832, R2(test): 0.004
# inner CV: R2(test): 0.283, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.788, R2(test): 0.395
# inner CV: R2(test): 0.392, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.836, R2(test): 0.318
# inner CV: R2(test): 0.238, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.644, R2(test): 0.439
# inner CV: R2(test): 0.283, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.171, R2(test): -0.624
# inner CV: R2(test): 0.070, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.802, R2(test): 0.419
# inner CV: R2(test): 0.283, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.795, R2(test): 0.505
# inner CV: R2(test): 0.326, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.877, R2(test): 0.433
# inner CV: R2(test): 0.239, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.836, R2(test): 0.256
# inner CV: R2(test): 0.249, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.805, R2(test): 0.517
# inner CV: R2(test): 0.347, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.713, R2(test): 0.459
# inner CV: R2(test): 0.240, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.825, R2(test): 0.611
# inner CV: R2(test): 0.251, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.677, R2(test): 0.416
# inner CV: R2(test): 0.294, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.930, R2(test): 0.436
# inner CV: R2(test): -0.008, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.493, R2(test): 0.434
# inner CV: R2(test): 0.470, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.834, R2(test): 0.281
# inner CV: R2(test): 0.237, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.755, R2(test): 0.644
# inner CV: R2(test): 0.037, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.357, R2(test): 0.101
# inner CV: R2(test): 0.157, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.841, R2(test): 0.522
# inner CV: R2(test): 0.391, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,), 'mlpregressor__learning_rate_init': 0.0001}, outer CV R2(train): 0.902, R2(test): 0.450
# [MLP] total result = R2(train): 0.750, R2(test): 0.357

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0, 0.2, 0.4, 0.5, 0.6, 0.8, 1],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },
    "GPR": {
        'pca__n_components': [10, 20, 30],
        'gaussianprocessregressor__alpha': [1e-6, 1e-5, 1e-4],
        'gaussianprocessregressor__kernel': [RBF(length_scale=l) for l in [0.1, 1.0, 10.0]]
    },
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10, 15],
        'randomforestregressor__min_samples_leaf': [1, 2, 5],
    },
    "SVR": {
        'svr__C': [0.01, 0.1, 1, 10, 100],
        'svr__epsilon': [0.5, 1.0, 2.0],
        'svr__kernel': ['rbf', 'linear'],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [2, 5, 10],
        'xgbregressor__n_estimators': [50, 100, 200],
        'xgbregressor__subsample': [0.6, 0.8, 1.0],
        'xgbregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "LightGBM": {
        'lgbmregressor__n_estimators': [50, 100, 200],
        'lgbmregressor__max_depth': [3, 5, 7],
        'lgbmregressor__learning_rate': [0.01, 0.05, 0.1],
        'lgbmregressor__subsample': [0.6, 0.8, 1.0],
        'lgbmregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1, 0.2],
        "histgradientboostingregressor__max_depth": [1, 3, 5, 7],
        "histgradientboostingregressor__max_iter": [100, 200],
        "histgradientboostingregressor__l2_regularization": [0.0, 0.1, 1.0],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7, 10],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__metric': ['euclidean', 'manhattan'],
        'kneighborsregressor__p': [1, 2]
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,), (50, 20)],
        'mlpregressor__alpha': [1e-4, 1e-3, 1e-2],
        'mlpregressor__learning_rate_init': [0.0001, 0.001, 0.01],
    }
}

# モデルの設定
models = {
    #"Linear": LinearRegression(),
    #"Lasso": Lasso(max_iter=10000),
    #"Ridge": Ridge(max_iter=10000),
    #"ElasticNet": ElasticNet(max_iter=50000),
    #"PolyRidge": make_pipeline(PCA(n_components=20), StandardScaler(), PolynomialFeatures(), Ridge()),
    "GPR": make_pipeline(PCA(), StandardScaler(), GaussianProcessRegressor(n_restarts_optimizer=5)),
    #"RandomForest": RandomForestRegressor(),
    #"SVR": SVR(),
    #"XGBoost": XGBRegressor(verbosity=0, n_jobs=-1),
    #"LightGBM": LGBMRegressor(verbose=-1, n_jobs=-1),
    #"HistGB": HistGradientBoostingRegressor(early_stopping=True),
    #"KNN": KNeighborsRegressor(),
    #"MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1)
}

n_repeats = 10
outer_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    print( '----------', name, '----------\nparams, R2(train), R2(test)')
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)

    tot_train = []
    tot_test = []
    
    for train_idx, test_idx in outer_cv.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        if name in param_grids:
            grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
            grid.fit(X_train, y_train)
            
            y_train_pred = grid.predict(X_train)
            y_test_pred  = grid.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"inner CV: R2(test): {grid.best_score_:.3f}, params: {grid.best_params_}, outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
        
        else:
            pipeline.fit(X_train, y_train)
            y_train_pred = pipeline.predict(X_train)
            y_test_pred  = pipeline.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
            
        tot_train.append(train_r2)
        tot_test.append(test_r2)
    
    print(f"[{name}] total result = R2(train): {np.mean(tot_train):.3f}, R2(test): {np.mean(tot_test):.3f}")
# Out:
# ---------- GPR ----------
# params, R2(train), R2(test)
# inner CV: R2(test): -0.122, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.949, R2(test): 0.337
# inner CV: R2(test): 0.152, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.960, R2(test): 0.153
# inner CV: R2(test): 0.034, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.975, R2(test): 0.199
# inner CV: R2(test): 0.016, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.964, R2(test): 0.229
# inner CV: R2(test): 0.223, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.984, R2(test): -0.122
# inner CV: R2(test): -0.450, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.976, R2(test): -0.330
# inner CV: R2(test): -0.213, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.965, R2(test): 0.212
# inner CV: R2(test): 0.116, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.953, R2(test): 0.086
# inner CV: R2(test): 0.294, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.982, R2(test): -0.162
# inner CV: R2(test): -0.102, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.961, R2(test): -0.062
# inner CV: R2(test): 0.008, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.951, R2(test): 0.265
# inner CV: R2(test): 0.231, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.987, R2(test): 0.241
# inner CV: R2(test): 0.402, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.985, R2(test): -0.071
# inner CV: R2(test): -0.157, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.975, R2(test): 0.084
# inner CV: R2(test): 0.265, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.961, R2(test): 0.333
# inner CV: R2(test): -0.253, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.954, R2(test): -0.228
# inner CV: R2(test): 0.031, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.982, R2(test): -0.094
# inner CV: R2(test): 0.009, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.982, R2(test): 0.163
# inner CV: R2(test): 0.129, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.971, R2(test): -0.094
# inner CV: R2(test): -0.060, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.985, R2(test): -0.056
# inner CV: R2(test): -0.151, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.966, R2(test): 0.495
# inner CV: R2(test): -0.103, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.970, R2(test): 0.016
# inner CV: R2(test): 0.058, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.946, R2(test): -0.137
# inner CV: R2(test): -0.104, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.978, R2(test): 0.243
# inner CV: R2(test): 0.021, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.992, R2(test): 0.025
# inner CV: R2(test): 0.058, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.976, R2(test): -0.141
# inner CV: R2(test): -0.054, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.960, R2(test): 0.296
# inner CV: R2(test): 0.006, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.970, R2(test): 0.235
# inner CV: R2(test): -0.036, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.959, R2(test): 0.210
# inner CV: R2(test): 0.088, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 0.971, R2(test): 0.081
# [GPR] total result = R2(train): 0.970, R2(test): 0.080

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

import pandas as pd
df = pd.read_csv('Mordred_descriptors_revise.csv')
df2 = df.iloc[:,13:].dropna()
y = df2.iloc[:,0]
X = df2.iloc[:,1:]

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0.2, 0.5, 0.8,],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },
    "GPR": {
        'pca__n_components': [10, 20, 30],
        'gaussianprocessregressor__alpha': [1e-6, 1e-5, 1e-4],
        'gaussianprocessregressor__kernel': [RBF(length_scale=l) for l in [0.1, 1.0, 10.0]]
    },
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10],
    },
    "SVR": {
        'svr__C': [0.1, 1, 10],
        'svr__epsilon': [0.5, 1.0],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [5, 10],
        'xgbregressor__n_estimators': [100, 200],
    },
    "LightGBM": {
        'lgbmregressor__learning_rate': [0.05, 0.1],
        'lgbmregressor__max_depth': [5, 10],
        'lgbmregressor__n_estimators': [100, 200],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1],
        "histgradientboostingregressor__max_depth": [5, 10],
        "histgradientboostingregressor__max_iter": [100, 200],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7],
        'kneighborsregressor__weights': ['uniform', 'distance']
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,)],
        'mlpregressor__alpha': [1e-4, 1e-3],
    }
}

# モデルの設定
models = {
    #"Linear": LinearRegression(),
    #"Lasso": Lasso(max_iter=10000),
    #"Ridge": Ridge(max_iter=10000),
    #"ElasticNet": ElasticNet(max_iter=50000),
    #"PolyRidge": make_pipeline(PCA(n_components=20), StandardScaler(), PolynomialFeatures(), Ridge()),
    #"GPR": make_pipeline(PCA(), StandardScaler(), GaussianProcessRegressor(n_restarts_optimizer=5)),
    #"RandomForest": RandomForestRegressor(),
    #"SVR": SVR(),
    #"XGBoost": XGBRegressor(verbosity=0, colsample_bytree=0.8, subsample=0.6, n_jobs=-1),
    #"LightGBM": LGBMRegressor(verbose=-1, colsample_bytree=0.8, subsample=0.6, n_jobs=-1),
    #"HistGB": HistGradientBoostingRegressor(early_stopping=True),
    "KNN": KNeighborsRegressor(),
    "MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1)
}

n_repeats = 10
outer_n_splits = 3
inner_n_splits = 3
outer_cv = RepeatedKFold(n_splits=outer_n_splits, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=inner_n_splits, n_repeats=n_repeats, random_state=1)

exe = True

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)

    print( '----------', name, '----------' )
    total_combi = 1
    for params, p_range in param_grids[name].items():
        print('#', params.split('__')[1], p_range)
        total_combi *= len(p_range)
    print( 'total points =', total_combi, '(grid search) x', n_repeats, '(n_repeats) x', inner_n_splits, '(inner-CV) x', outer_n_splits, '(outer-CV) =', total_combi * n_repeats * outer_n_splits * inner_n_splits, '(points)' )
    
    print( '----- params, R2(train), R2(test)')
    tot_train = []
    tot_test = []
    i = 1
    if exe == True:
        for train_idx, test_idx in outer_cv.split(X, y):
            X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
            y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        
            if name in param_grids:
                grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
                grid.fit(X_train, y_train)
                
                y_train_pred = grid.predict(X_train)
                y_test_pred  = grid.predict(X_test)
                train_r2 = r2_score(y_train, y_train_pred)
                test_r2  = r2_score(y_test, y_test_pred)
                print( f"{i}, inner CV R2(test): {grid.best_score_:.3f}, params: {grid.best_params_}, outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
                i += 1
            
            else:
                pipeline.fit(X_train, y_train)
                y_train_pred = pipeline.predict(X_train)
                y_test_pred  = pipeline.predict(X_test)
                train_r2 = r2_score(y_train, y_train_pred)
                test_r2  = r2_score(y_test, y_test_pred)
                print( f"outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
                
            tot_train.append(train_r2)
            tot_test.append(test_r2)
    
    print(f"[{name}] total result = R2(train): {np.mean(tot_train):.3f}, R2(test): {np.mean(tot_test):.3f}\n")

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

import pandas as pd
df = pd.read_csv('Morgan_descriptors_revise.csv')
df2 = df.iloc[:,13:].dropna()
y = df2.iloc[:,0]
X = df2.iloc[:,1:]

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0, 0.2, 0.4, 0.5, 0.6, 0.8, 1],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },
    "GPR": {
        'pca__n_components': [5, 10, 20, 30],
        'gaussianprocessregressor__alpha': [1e-6, 1e-5, 1e-4],
        'gaussianprocessregressor__kernel': [RBF(length_scale=l) for l in [0.1, 1.0, 10.0]]
    },
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10, 15],
        'randomforestregressor__min_samples_leaf': [1, 2, 5],
    },
    "SVR": {
        'svr__C': [0.01, 0.1, 1, 10, 100],
        'svr__epsilon': [0.5, 1.0, 2.0],
        'svr__kernel': ['rbf', 'linear'],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [2, 5, 10],
        'xgbregressor__n_estimators': [50, 100, 200],
        'xgbregressor__subsample': [0.6, 0.8, 1.0],
        'xgbregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "LightGBM": {
        'lgbmregressor__n_estimators': [50, 100, 200],
        'lgbmregressor__max_depth': [3, 5, 7],
        'lgbmregressor__learning_rate': [0.01, 0.05, 0.1],
        'lgbmregressor__subsample': [0.6, 0.8, 1.0],
        'lgbmregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1, 0.2],
        "histgradientboostingregressor__max_depth": [1, 3, 5, 7],
        "histgradientboostingregressor__max_iter": [100, 200],
        "histgradientboostingregressor__l2_regularization": [0.0, 0.1, 1.0],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7, 10],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__metric': ['euclidean', 'manhattan'],
        'kneighborsregressor__p': [1, 2]
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,), (50, 20)],
        'mlpregressor__alpha': [1e-4, 1e-3, 1e-2],
        'mlpregressor__learning_rate_init': [0.0001, 0.001, 0.01],
    }
}

# モデルの設定
models = {
    #"Linear": LinearRegression(),
    #"Lasso": Lasso(max_iter=10000),
    #"Ridge": Ridge(max_iter=10000),
    #"ElasticNet": ElasticNet(max_iter=50000),
    #"PolyRidge": make_pipeline(PCA(n_components=20), StandardScaler(), PolynomialFeatures(), Ridge()),
    #"GPR": make_pipeline(PCA(), StandardScaler(), GaussianProcessRegressor(n_restarts_optimizer=5)),
    "GPR": make_pipeline(StandardScaler(), PCA(), GaussianProcessRegressor(n_restarts_optimizer=5)),
    #"RandomForest": RandomForestRegressor(),
    #"SVR": SVR(),
    #"XGBoost": XGBRegressor(verbosity=0, n_jobs=-1),
    #"LightGBM": LGBMRegressor(verbose=-1, n_jobs=-1),
    #"HistGB": HistGradientBoostingRegressor(early_stopping=True),
    #"KNN": KNeighborsRegressor(),
    #"MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1)
}

n_repeats = 10
outer_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    print( '----------', name, '----------\nparams, R2(train), R2(test)')
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)

    tot_train = []
    tot_test = []
    
    for train_idx, test_idx in outer_cv.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        if name in param_grids:
            grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
            grid.fit(X_train, y_train)
            
            y_train_pred = grid.predict(X_train)
            y_test_pred  = grid.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"inner CV: R2(test): {grid.best_score_:.3f}, params: {grid.best_params_}, outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
        
        else:
            pipeline.fit(X_train, y_train)
            y_train_pred = pipeline.predict(X_train)
            y_test_pred  = pipeline.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
            
        tot_train.append(train_r2)
        tot_test.append(test_r2)
    
    print(f"[{name}] total result = R2(train): {np.mean(tot_train):.3f}, R2(test): {np.mean(tot_test):.3f}")
# Out:
# ---------- GPR ----------
# params, R2(train), R2(test)
# inner CV: R2(test): -0.211, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.352
# inner CV: R2(test): 0.042, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.216
# inner CV: R2(test): 0.145, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.077
# inner CV: R2(test): -0.126, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.056
# inner CV: R2(test): 0.219, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.255
# inner CV: R2(test): 0.204, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.397
# inner CV: R2(test): -0.043, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.293
# inner CV: R2(test): -0.200, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.026
# inner CV: R2(test): 0.332, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.240
# inner CV: R2(test): -0.100, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.057
# inner CV: R2(test): -0.045, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.233
# inner CV: R2(test): 0.298, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.007
# inner CV: R2(test): 0.292, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.283
# inner CV: R2(test): -0.116, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.355
# inner CV: R2(test): 0.049, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.001
# inner CV: R2(test): 0.046, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.031
# inner CV: R2(test): 0.130, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.131
# inner CV: R2(test): -0.023, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.247
# inner CV: R2(test): 0.014, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.714
# inner CV: R2(test): 0.147, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.152
# inner CV: R2(test): 0.158, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.358
# inner CV: R2(test): 0.018, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.169
# inner CV: R2(test): -0.006, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.342
# inner CV: R2(test): 0.141, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.256
# inner CV: R2(test): 0.169, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.186
# inner CV: R2(test): 0.246, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.111
# inner CV: R2(test): -0.146, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.363
# inner CV: R2(test): -0.015, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.144
# inner CV: R2(test): -0.103, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): 0.118
# inner CV: R2(test): 0.201, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10), 'pca__n_components': 30}, outer CV R2(train): 1.000, R2(test): -0.006
# [GPR] total result = R2(train): 1.000, R2(test): 0.016

# %%
import pandas as pd
df = pd.read_csv('Morgan_descriptors_revise.csv')
df2 = df.iloc[:,5:].dropna()
X = df2.iloc[:,:8]
y = df2.iloc[:,8]

# モデルとハイパーパラメータの設定
param_grids = {
    "Lasso": {
        'lasso__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "Ridge": {
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
    },
    "ElasticNet": {
        'elasticnet__alpha': [0.001, 0.01, 0.1, 1, 10],
        'elasticnet__l1_ratio': [0, 0.2, 0.4, 0.5, 0.6, 0.8, 1],
    },
    "PolyRidge": {
        'polynomialfeatures__degree': [2, 3],
        'ridge__alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    },
    "GPR": {
        #'pca__n_components': [5, 10, 20, 30],
        'gaussianprocessregressor__alpha': [1e-6, 1e-5, 1e-4],
        'gaussianprocessregressor__kernel': [RBF(length_scale=l) for l in [0.1, 1.0, 10.0]]
    },
    "RandomForest": {
        'randomforestregressor__n_estimators': [50, 75, 100],
        'randomforestregressor__max_depth': [5, 10, 15],
        'randomforestregressor__min_samples_leaf': [1, 2, 5],
    },
    "SVR": {
        'svr__C': [0.01, 0.1, 1, 10, 100],
        'svr__epsilon': [0.5, 1.0, 2.0],
        'svr__kernel': ['rbf', 'linear'],
        'svr__gamma': ['scale','auto']
    },
    "XGBoost": {
        'xgbregressor__learning_rate': [0.05, 0.1],
        'xgbregressor__max_depth': [2, 5, 10],
        'xgbregressor__n_estimators': [50, 100, 200],
        'xgbregressor__subsample': [0.6, 0.8, 1.0],
        'xgbregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "LightGBM": {
        'lgbmregressor__n_estimators': [50, 100, 200],
        'lgbmregressor__max_depth': [3, 5, 7],
        'lgbmregressor__learning_rate': [0.01, 0.05, 0.1],
        'lgbmregressor__subsample': [0.6, 0.8, 1.0],
        'lgbmregressor__colsample_bytree': [0.6, 0.8, 1.0],
    },
    "HistGB": {
        "histgradientboostingregressor__learning_rate": [0.05, 0.1, 0.2],
        "histgradientboostingregressor__max_depth": [1, 3, 5, 7],
        "histgradientboostingregressor__max_iter": [100, 200],
        "histgradientboostingregressor__l2_regularization": [0.0, 0.1, 1.0],
    },
    "KNN": {
        'kneighborsregressor__n_neighbors': [3, 5, 7, 10],
        'kneighborsregressor__weights': ['uniform', 'distance'],
        'kneighborsregressor__metric': ['euclidean', 'manhattan'],
        'kneighborsregressor__p': [1, 2]
    },
    "MLP": {
        'mlpregressor__hidden_layer_sizes': [(50,), (100,), (50, 20)],
        'mlpregressor__alpha': [1e-4, 1e-3, 1e-2],
        'mlpregressor__learning_rate_init': [0.0001, 0.001, 0.01],
    }
}

# モデルの設定
models = {
    "Linear": LinearRegression(),
    "Lasso": Lasso(max_iter=10000),
    "Ridge": Ridge(max_iter=10000),
    "ElasticNet": ElasticNet(max_iter=50000),
    "PolyRidge": make_pipeline(PolynomialFeatures(), Ridge()),
    "GPR": make_pipeline(GaussianProcessRegressor(n_restarts_optimizer=5)),
    #"GPR": make_pipeline(StandardScaler(), PCA(), GaussianProcessRegressor(n_restarts_optimizer=5)),
    "RandomForest": RandomForestRegressor(),
    "SVR": SVR(),
    "XGBoost": XGBRegressor(verbosity=0, n_jobs=-1),
    "LightGBM": LGBMRegressor(verbose=-1, n_jobs=-1),
    "HistGB": HistGradientBoostingRegressor(early_stopping=True),
    "KNN": KNeighborsRegressor(),
    "MLP": MLPRegressor(max_iter=200, early_stopping=True, validation_fraction=0.1)
}

n_repeats = 10
outer_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)
inner_cv = RepeatedKFold(n_splits=3, n_repeats=n_repeats, random_state=1)

# ネストされた交差検証を使ってモデルを評価
for name, model in models.items():
    print( '----------', name, '----------\nparams, R2(train), R2(test)')
    pipeline = model if isinstance(model, Pipeline) else make_pipeline(StandardScaler(), model)

    tot_train = []
    tot_test = []
    
    for train_idx, test_idx in outer_cv.split(X, y):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        if name in param_grids:
            grid = GridSearchCV(pipeline, param_grids[name], cv=inner_cv, scoring='r2', n_jobs=-1)
            grid.fit(X_train, y_train)
            
            y_train_pred = grid.predict(X_train)
            y_test_pred  = grid.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"inner CV: R2(test): {grid.best_score_:.3f}, params: {grid.best_params_}, outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
        
        else:
            pipeline.fit(X_train, y_train)
            y_train_pred = pipeline.predict(X_train)
            y_test_pred  = pipeline.predict(X_test)
            train_r2 = r2_score(y_train, y_train_pred)
            test_r2  = r2_score(y_test, y_test_pred)
            print( f"outer CV R2(train): {train_r2:.3f}, R2(test): {test_r2:.3f}" )
            
        tot_train.append(train_r2)
        tot_test.append(test_r2)
    
    print(f"[{name}] total result = R2(train): {np.mean(tot_train):.3f}, R2(test): {np.mean(tot_test):.3f}")
# Out:
# ---------- Linear ----------
# params, R2(train), R2(test)
# outer CV R2(train): 0.399, R2(test): 0.166
# outer CV R2(train): 0.425, R2(test): 0.102
# outer CV R2(train): 0.357, R2(test): 0.268
# outer CV R2(train): 0.297, R2(test): 0.453
# outer CV R2(train): 0.322, R2(test): 0.330
# outer CV R2(train): 0.502, R2(test): -0.140
# outer CV R2(train): 0.273, R2(test): 0.461
# outer CV R2(train): 0.474, R2(test): 0.067
# outer CV R2(train): 0.357, R2(test): 0.337
# outer CV R2(train): 0.442, R2(test): 0.120
# outer CV R2(train): 0.408, R2(test): 0.090
# outer CV R2(train): 0.327, R2(test): 0.364
# outer CV R2(train): 0.364, R2(test): 0.279
# outer CV R2(train): 0.412, R2(test): 0.225
# outer CV R2(train): 0.369, R2(test): 0.251
# outer CV R2(train): 0.390, R2(test): 0.066
# outer CV R2(train): 0.400, R2(test): 0.212
# outer CV R2(train): 0.363, R2(test): 0.186
# outer CV R2(train): 0.274, R2(test): 0.389
# outer CV R2(train): 0.410, R2(test): 0.142
# outer CV R2(train): 0.400, R2(test): 0.205
# outer CV R2(train): 0.391, R2(test): 0.184
# outer CV R2(train): 0.337, R2(test): 0.296
# outer CV R2(train): 0.435, R2(test): 0.162
# outer CV R2(train): 0.365, R2(test): 0.314
# outer CV R2(train): 0.312, R2(test): 0.454
# outer CV R2(train): 0.433, R2(test): 0.122
# outer CV R2(train): 0.332, R2(test): 0.369
# outer CV R2(train): 0.456, R2(test): 0.054
# outer CV R2(train): 0.344, R2(test): 0.343
# [Linear] total result = R2(train): 0.379, R2(test): 0.229
# ---------- Lasso ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.212, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.398, R2(test): 0.184
# inner CV: R2(test): 0.281, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.424, R2(test): 0.117
# inner CV: R2(test): 0.132, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.313, R2(test): 0.290
# inner CV: R2(test): 0.094, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.238, R2(test): 0.393
# inner CV: R2(test): 0.135, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.266, R2(test): 0.218
# inner CV: R2(test): 0.357, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.502, R2(test): -0.122
# inner CV: R2(test): 0.034, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.271, R2(test): 0.457
# inner CV: R2(test): 0.283, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.410, R2(test): 0.075
# inner CV: R2(test): 0.134, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.304, R2(test): 0.279
# inner CV: R2(test): 0.281, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.442, R2(test): 0.125
# inner CV: R2(test): 0.212, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.353, R2(test): 0.150
# inner CV: R2(test): 0.133, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.285, R2(test): 0.263
# inner CV: R2(test): 0.204, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.310, R2(test): 0.288
# inner CV: R2(test): 0.215, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.411, R2(test): 0.231
# inner CV: R2(test): 0.158, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.319, R2(test): 0.252
# inner CV: R2(test): 0.173, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.389, R2(test): 0.071
# inner CV: R2(test): 0.235, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.342, R2(test): 0.208
# inner CV: R2(test): 0.213, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.320, R2(test): 0.098
# inner CV: R2(test): 0.053, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.209, R2(test): 0.197
# inner CV: R2(test): 0.214, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.365, R2(test): 0.141
# inner CV: R2(test): 0.223, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.399, R2(test): 0.219
# inner CV: R2(test): 0.214, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.390, R2(test): 0.196
# inner CV: R2(test): 0.109, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.273, R2(test): 0.297
# inner CV: R2(test): 0.200, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.434, R2(test): 0.173
# inner CV: R2(test): 0.172, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.364, R2(test): 0.314
# inner CV: R2(test): 0.131, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.270, R2(test): 0.343
# inner CV: R2(test): 0.244, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.366, R2(test): 0.173
# inner CV: R2(test): 0.103, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.271, R2(test): 0.313
# inner CV: R2(test): 0.313, params: {'lasso__alpha': 0.01}, outer CV R2(train): 0.455, R2(test): 0.069
# inner CV: R2(test): 0.164, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.291, R2(test): 0.295
# [Lasso] total result = R2(train): 0.346, R2(test): 0.210
# ---------- Ridge ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.224, params: {'ridge__alpha': 10}, outer CV R2(train): 0.393, R2(test): 0.187
# inner CV: R2(test): 0.288, params: {'ridge__alpha': 10}, outer CV R2(train): 0.420, R2(test): 0.130
# inner CV: R2(test): 0.140, params: {'ridge__alpha': 10}, outer CV R2(train): 0.353, R2(test): 0.265
# inner CV: R2(test): 0.073, params: {'ridge__alpha': 10}, outer CV R2(train): 0.292, R2(test): 0.452
# inner CV: R2(test): 0.148, params: {'ridge__alpha': 10}, outer CV R2(train): 0.319, R2(test): 0.306
# inner CV: R2(test): 0.367, params: {'ridge__alpha': 10}, outer CV R2(train): 0.496, R2(test): -0.082
# inner CV: R2(test): 0.048, params: {'ridge__alpha': 10}, outer CV R2(train): 0.268, R2(test): 0.448
# inner CV: R2(test): 0.288, params: {'ridge__alpha': 10}, outer CV R2(train): 0.469, R2(test): 0.099
# inner CV: R2(test): 0.130, params: {'ridge__alpha': 10}, outer CV R2(train): 0.354, R2(test): 0.324
# inner CV: R2(test): 0.284, params: {'ridge__alpha': 10}, outer CV R2(train): 0.436, R2(test): 0.152
# inner CV: R2(test): 0.227, params: {'ridge__alpha': 10}, outer CV R2(train): 0.403, R2(test): 0.121
# inner CV: R2(test): 0.117, params: {'ridge__alpha': 10}, outer CV R2(train): 0.324, R2(test): 0.344
# inner CV: R2(test): 0.220, params: {'ridge__alpha': 10}, outer CV R2(train): 0.360, R2(test): 0.275
# inner CV: R2(test): 0.219, params: {'ridge__alpha': 10}, outer CV R2(train): 0.405, R2(test): 0.239
# inner CV: R2(test): 0.166, params: {'ridge__alpha': 10}, outer CV R2(train): 0.365, R2(test): 0.255
# inner CV: R2(test): 0.190, params: {'ridge__alpha': 10}, outer CV R2(train): 0.384, R2(test): 0.083
# inner CV: R2(test): 0.236, params: {'ridge__alpha': 10}, outer CV R2(train): 0.395, R2(test): 0.226
# inner CV: R2(test): 0.209, params: {'ridge__alpha': 10}, outer CV R2(train): 0.359, R2(test): 0.177
# inner CV: R2(test): 0.058, params: {'ridge__alpha': 10}, outer CV R2(train): 0.268, R2(test): 0.356
# inner CV: R2(test): 0.218, params: {'ridge__alpha': 10}, outer CV R2(train): 0.407, R2(test): 0.146
# inner CV: R2(test): 0.245, params: {'ridge__alpha': 10}, outer CV R2(train): 0.395, R2(test): 0.220
# inner CV: R2(test): 0.225, params: {'ridge__alpha': 10}, outer CV R2(train): 0.386, R2(test): 0.215
# inner CV: R2(test): 0.113, params: {'ridge__alpha': 10}, outer CV R2(train): 0.332, R2(test): 0.307
# inner CV: R2(test): 0.215, params: {'ridge__alpha': 10}, outer CV R2(train): 0.431, R2(test): 0.181
# inner CV: R2(test): 0.182, params: {'ridge__alpha': 10}, outer CV R2(train): 0.360, R2(test): 0.307
# inner CV: R2(test): 0.106, params: {'ridge__alpha': 10}, outer CV R2(train): 0.308, R2(test): 0.435
# inner CV: R2(test): 0.262, params: {'ridge__alpha': 10}, outer CV R2(train): 0.428, R2(test): 0.148
# inner CV: R2(test): 0.102, params: {'ridge__alpha': 10}, outer CV R2(train): 0.328, R2(test): 0.362
# inner CV: R2(test): 0.326, params: {'ridge__alpha': 10}, outer CV R2(train): 0.450, R2(test): 0.089
# inner CV: R2(test): 0.167, params: {'ridge__alpha': 10}, outer CV R2(train): 0.341, R2(test): 0.333
# [Ridge] total result = R2(train): 0.374, R2(test): 0.237
# ---------- ElasticNet ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.224, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.391, R2(test): 0.189
# inner CV: R2(test): 0.288, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.418, R2(test): 0.134
# inner CV: R2(test): 0.138, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.4}, outer CV R2(train): 0.339, R2(test): 0.266
# inner CV: R2(test): 0.094, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.238, R2(test): 0.393
# inner CV: R2(test): 0.144, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.318, R2(test): 0.301
# inner CV: R2(test): 0.368, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.494, R2(test): -0.074
# inner CV: R2(test): 0.046, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.2}, outer CV R2(train): 0.258, R2(test): 0.430
# inner CV: R2(test): 0.284, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.467, R2(test): 0.103
# inner CV: R2(test): 0.134, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.304, R2(test): 0.279
# inner CV: R2(test): 0.286, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.2}, outer CV R2(train): 0.428, R2(test): 0.155
# inner CV: R2(test): 0.225, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.401, R2(test): 0.125
# inner CV: R2(test): 0.133, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.285, R2(test): 0.263
# inner CV: R2(test): 0.217, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.359, R2(test): 0.273
# inner CV: R2(test): 0.220, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.403, R2(test): 0.240
# inner CV: R2(test): 0.163, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.364, R2(test): 0.256
# inner CV: R2(test): 0.188, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.382, R2(test): 0.084
# inner CV: R2(test): 0.241, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.372, R2(test): 0.218
# inner CV: R2(test): 0.217, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.336, R2(test): 0.120
# inner CV: R2(test): 0.055, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.267, R2(test): 0.350
# inner CV: R2(test): 0.220, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.389, R2(test): 0.137
# inner CV: R2(test): 0.243, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.394, R2(test): 0.222
# inner CV: R2(test): 0.224, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.384, R2(test): 0.218
# inner CV: R2(test): 0.110, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.331, R2(test): 0.308
# inner CV: R2(test): 0.214, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.429, R2(test): 0.183
# inner CV: R2(test): 0.181, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.358, R2(test): 0.305
# inner CV: R2(test): 0.131, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 1}, outer CV R2(train): 0.270, R2(test): 0.343
# inner CV: R2(test): 0.260, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.426, R2(test): 0.151
# inner CV: R2(test): 0.105, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.301, R2(test): 0.336
# inner CV: R2(test): 0.326, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0}, outer CV R2(train): 0.448, R2(test): 0.093
# inner CV: R2(test): 0.170, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.6}, outer CV R2(train): 0.314, R2(test): 0.311
# [ElasticNet] total result = R2(train): 0.362, R2(test): 0.224
# ---------- PolyRidge ----------
# params, R2(train), R2(test)
# inner CV: R2(test): -0.361, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.734, R2(test): -0.183
# inner CV: R2(test): -1.173, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.704, R2(test): 0.140
# inner CV: R2(test): -0.581, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.741, R2(test): -0.150
# inner CV: R2(test): -1.432, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.675, R2(test): 0.071
# inner CV: R2(test): -0.928, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.729, R2(test): 0.099
# inner CV: R2(test): -0.508, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.743, R2(test): -0.336
# inner CV: R2(test): -0.690, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.696, R2(test): 0.208
# inner CV: R2(test): -1.269, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.703, R2(test): -0.027
# inner CV: R2(test): -0.656, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.726, R2(test): 0.098
# inner CV: R2(test): -0.607, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.686, R2(test): 0.387
# inner CV: R2(test): -2.228, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.707, R2(test): 0.198
# inner CV: R2(test): -0.599, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.745, R2(test): -0.206
# inner CV: R2(test): -0.518, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.725, R2(test): -0.026
# inner CV: R2(test): -0.993, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.730, R2(test): 0.059
# inner CV: R2(test): -1.777, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.699, R2(test): 0.018
# inner CV: R2(test): -0.375, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.769, R2(test): -0.075
# inner CV: R2(test): -1.862, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.708, R2(test): 0.057
# inner CV: R2(test): -1.159, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 0.001}, outer CV R2(train): 0.836, R2(test): 0.213
# inner CV: R2(test): -1.610, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.724, R2(test): -0.004
# inner CV: R2(test): -0.933, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.724, R2(test): 0.059
# inner CV: R2(test): -0.876, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.663, R2(test): 0.425
# inner CV: R2(test): -0.389, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.738, R2(test): -0.302
# inner CV: R2(test): -3.263, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.678, R2(test): 0.186
# inner CV: R2(test): -0.803, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.745, R2(test): 0.288
# inner CV: R2(test): -1.343, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.684, R2(test): 0.318
# inner CV: R2(test): -0.698, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.754, R2(test): -0.038
# inner CV: R2(test): -0.892, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.712, R2(test): -0.225
# inner CV: R2(test): -1.601, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.707, R2(test): 0.262
# inner CV: R2(test): -1.163, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.684, R2(test): -0.322
# inner CV: R2(test): -0.162, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.763, R2(test): 0.048
# [PolyRidge] total result = R2(train): 0.721, R2(test): 0.041
# ---------- GPR ----------
# params, R2(train), R2(test)
# inner CV: R2(test): -1.830, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10)}, outer CV R2(train): 1.000, R2(test): -0.630
# inner CV: R2(test): -1.636, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.532
# inner CV: R2(test): -1.545, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.297
# inner CV: R2(test): -1.882, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -2.036
# inner CV: R2(test): -1.749, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.333
# inner CV: R2(test): -1.395, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -0.946
# inner CV: R2(test): -1.770, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10)}, outer CV R2(train): 1.000, R2(test): -0.465
# inner CV: R2(test): -1.733, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.676
# inner CV: R2(test): -1.373, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.141
# inner CV: R2(test): -1.431, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10)}, outer CV R2(train): 1.000, R2(test): -1.291
# inner CV: R2(test): -1.665, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -0.979
# inner CV: R2(test): -1.699, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.111
# inner CV: R2(test): -1.263, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10)}, outer CV R2(train): 1.000, R2(test): -0.620
# inner CV: R2(test): -1.631, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.685
# inner CV: R2(test): -1.800, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.949
# inner CV: R2(test): -1.342, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10)}, outer CV R2(train): 1.000, R2(test): -1.564
# inner CV: R2(test): -1.707, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.151
# inner CV: R2(test): -1.823, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -0.956
# inner CV: R2(test): -1.614, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.843
# inner CV: R2(test): -1.733, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -0.957
# inner CV: R2(test): -1.479, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10)}, outer CV R2(train): 1.000, R2(test): -1.422
# inner CV: R2(test): -1.305, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10)}, outer CV R2(train): 1.000, R2(test): -0.959
# inner CV: R2(test): -1.612, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10)}, outer CV R2(train): 1.000, R2(test): -1.387
# inner CV: R2(test): -1.579, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.556
# inner CV: R2(test): -1.883, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.233
# inner CV: R2(test): -1.458, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.534
# inner CV: R2(test): -1.681, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.535
# inner CV: R2(test): -1.877, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -1.210
# inner CV: R2(test): -1.404, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1)}, outer CV R2(train): 1.000, R2(test): -2.118
# inner CV: R2(test): -1.287, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=10)}, outer CV R2(train): 1.000, R2(test): -0.811
# [GPR] total result = R2(train): 1.000, R2(test): -1.298
# ---------- RandomForest ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.578, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.869, R2(test): 0.581
# inner CV: R2(test): 0.506, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.935, R2(test): 0.600
# inner CV: R2(test): 0.488, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.930, R2(test): 0.601
# inner CV: R2(test): 0.427, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.826, R2(test): 0.782
# inner CV: R2(test): 0.593, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.949, R2(test): 0.577
# inner CV: R2(test): 0.588, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.941, R2(test): 0.497
# inner CV: R2(test): 0.497, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.939, R2(test): 0.650
# inner CV: R2(test): 0.504, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.934, R2(test): 0.631
# inner CV: R2(test): 0.548, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.945, R2(test): 0.493
# inner CV: R2(test): 0.501, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.938, R2(test): 0.546
# inner CV: R2(test): 0.508, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.939, R2(test): 0.545
# inner CV: R2(test): 0.588, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.951, R2(test): 0.520
# inner CV: R2(test): 0.618, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.951, R2(test): 0.525
# inner CV: R2(test): 0.496, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.858, R2(test): 0.496
# inner CV: R2(test): 0.538, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.948, R2(test): 0.465
# inner CV: R2(test): 0.517, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.872, R2(test): 0.477
# inner CV: R2(test): 0.507, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.865, R2(test): 0.642
# inner CV: R2(test): 0.552, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.947, R2(test): 0.517
# inner CV: R2(test): 0.483, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.936, R2(test): 0.616
# inner CV: R2(test): 0.506, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.945, R2(test): 0.495
# inner CV: R2(test): 0.554, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.878, R2(test): 0.484
# inner CV: R2(test): 0.502, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.935, R2(test): 0.608
# inner CV: R2(test): 0.523, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.941, R2(test): 0.611
# inner CV: R2(test): 0.499, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.937, R2(test): 0.668
# inner CV: R2(test): 0.591, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.956, R2(test): 0.459
# inner CV: R2(test): 0.579, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.947, R2(test): 0.369
# inner CV: R2(test): 0.526, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.871, R2(test): 0.624
# inner CV: R2(test): 0.430, params: {'randomforestregressor__max_depth': 15, 'randomforestregressor__min_samples_leaf': 2, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.853, R2(test): 0.707
# inner CV: R2(test): 0.504, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.924, R2(test): 0.578
# inner CV: R2(test): 0.624, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.947, R2(test): 0.463
# [RandomForest] total result = R2(train): 0.920, R2(test): 0.561
# ---------- SVR ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.425, params: {'svr__C': 1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.715, R2(test): 0.554
# inner CV: R2(test): 0.437, params: {'svr__C': 1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.686, R2(test): 0.481
# inner CV: R2(test): 0.538, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.895, R2(test): 0.359
# inner CV: R2(test): 0.407, params: {'svr__C': 1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.688, R2(test): 0.559
# inner CV: R2(test): 0.529, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.851, R2(test): 0.446
# inner CV: R2(test): 0.503, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.897, R2(test): 0.297
# inner CV: R2(test): 0.420, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.845, R2(test): 0.527
# inner CV: R2(test): 0.444, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.849, R2(test): 0.505
# inner CV: R2(test): 0.482, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.904, R2(test): 0.419
# inner CV: R2(test): 0.420, params: {'svr__C': 1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.676, R2(test): 0.460
# inner CV: R2(test): 0.457, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.869, R2(test): 0.512
# inner CV: R2(test): 0.497, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.897, R2(test): 0.419
# inner CV: R2(test): 0.487, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.859, R2(test): 0.515
# inner CV: R2(test): 0.433, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.880, R2(test): 0.598
# inner CV: R2(test): 0.444, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.865, R2(test): 0.433
# inner CV: R2(test): 0.441, params: {'svr__C': 1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.721, R2(test): 0.378
# inner CV: R2(test): 0.521, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.903, R2(test): 0.441
# inner CV: R2(test): 0.435, params: {'svr__C': 1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.714, R2(test): 0.491
# inner CV: R2(test): 0.420, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.822, R2(test): 0.474
# inner CV: R2(test): 0.488, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.884, R2(test): 0.423
# inner CV: R2(test): 0.445, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.867, R2(test): 0.499
# inner CV: R2(test): 0.487, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.866, R2(test): 0.425
# inner CV: R2(test): 0.386, params: {'svr__C': 1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.699, R2(test): 0.604
# inner CV: R2(test): 0.494, params: {'svr__C': 100, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.886, R2(test): 0.535
# inner CV: R2(test): 0.418, params: {'svr__C': 1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.718, R2(test): 0.508
# inner CV: R2(test): 0.512, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.895, R2(test): 0.054
# inner CV: R2(test): 0.466, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.855, R2(test): 0.506
# inner CV: R2(test): 0.387, params: {'svr__C': 1, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.696, R2(test): 0.562
# inner CV: R2(test): 0.431, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.849, R2(test): 0.469
# inner CV: R2(test): 0.559, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale', 'svr__kernel': 'rbf'}, outer CV R2(train): 0.897, R2(test): 0.418
# [SVR] total result = R2(train): 0.822, R2(test): 0.462
# ---------- XGBoost ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.569, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.770, R2(test): 0.566
# inner CV: R2(test): 0.532, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.932, R2(test): 0.605
# inner CV: R2(test): 0.518, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.938, R2(test): 0.594
# inner CV: R2(test): 0.444, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.749, R2(test): 0.721
# inner CV: R2(test): 0.626, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.941, R2(test): 0.567
# inner CV: R2(test): 0.599, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.815, R2(test): 0.476
# inner CV: R2(test): 0.509, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 10, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.967, R2(test): 0.636
# inner CV: R2(test): 0.529, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.784, R2(test): 0.598
# inner CV: R2(test): 0.583, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.950, R2(test): 0.518
# inner CV: R2(test): 0.469, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 10, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.965, R2(test): 0.518
# inner CV: R2(test): 0.520, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.938, R2(test): 0.581
# inner CV: R2(test): 0.655, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.958, R2(test): 0.511
# inner CV: R2(test): 0.644, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.956, R2(test): 0.509
# inner CV: R2(test): 0.527, params: {'xgbregressor__colsample_bytree': 1.0, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.793, R2(test): 0.467
# inner CV: R2(test): 0.563, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.951, R2(test): 0.499
# inner CV: R2(test): 0.498, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.926, R2(test): 0.486
# inner CV: R2(test): 0.502, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.938, R2(test): 0.609
# inner CV: R2(test): 0.608, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.918, R2(test): 0.403
# inner CV: R2(test): 0.525, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.927, R2(test): 0.626
# inner CV: R2(test): 0.512, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 10, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.969, R2(test): 0.557
# inner CV: R2(test): 0.543, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.871, R2(test): 0.518
# inner CV: R2(test): 0.534, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.934, R2(test): 0.617
# inner CV: R2(test): 0.542, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.940, R2(test): 0.640
# inner CV: R2(test): 0.506, params: {'xgbregressor__colsample_bytree': 0.8, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.795, R2(test): 0.604
# inner CV: R2(test): 0.616, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 10, 'xgbregressor__n_estimators': 200, 'xgbregressor__subsample': 0.8}, outer CV R2(train): 0.999, R2(test): 0.482
# inner CV: R2(test): 0.596, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 50, 'xgbregressor__subsample': 1.0}, outer CV R2(train): 0.966, R2(test): 0.380
# inner CV: R2(test): 0.536, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.761, R2(test): 0.604
# inner CV: R2(test): 0.434, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.929, R2(test): 0.711
# inner CV: R2(test): 0.507, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 2, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.770, R2(test): 0.675
# inner CV: R2(test): 0.649, params: {'xgbregressor__colsample_bytree': 0.6, 'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100, 'xgbregressor__subsample': 0.6}, outer CV R2(train): 0.943, R2(test): 0.477
# [XGBoost] total result = R2(train): 0.900, R2(test): 0.559
# ---------- LightGBM ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.252, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.841, R2(test): 0.582
# inner CV: R2(test): 0.413, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.834, R2(test): 0.557
# inner CV: R2(test): 0.260, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.827, R2(test): 0.534
# inner CV: R2(test): 0.278, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.772, R2(test): 0.623
# inner CV: R2(test): 0.320, params: {'lgbmregressor__colsample_bytree': 1.0, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.860, R2(test): 0.528
# inner CV: R2(test): 0.446, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.851, R2(test): 0.478
# inner CV: R2(test): 0.174, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.807, R2(test): 0.670
# inner CV: R2(test): 0.387, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.840, R2(test): 0.530
# inner CV: R2(test): 0.366, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.859, R2(test): 0.454
# inner CV: R2(test): 0.328, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.826, R2(test): 0.507
# inner CV: R2(test): 0.328, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.834, R2(test): 0.507
# inner CV: R2(test): 0.344, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.864, R2(test): 0.465
# inner CV: R2(test): 0.333, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.848, R2(test): 0.508
# inner CV: R2(test): 0.392, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.827, R2(test): 0.466
# inner CV: R2(test): 0.343, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.857, R2(test): 0.393
# inner CV: R2(test): 0.191, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.801, R2(test): 0.536
# inner CV: R2(test): 0.345, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.824, R2(test): 0.647
# inner CV: R2(test): 0.398, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.879, R2(test): 0.484
# inner CV: R2(test): 0.191, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.760, R2(test): 0.604
# inner CV: R2(test): 0.292, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.827, R2(test): 0.581
# inner CV: R2(test): 0.392, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.832, R2(test): 0.548
# inner CV: R2(test): 0.334, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.834, R2(test): 0.573
# inner CV: R2(test): 0.238, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.813, R2(test): 0.592
# inner CV: R2(test): 0.386, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.844, R2(test): 0.507
# inner CV: R2(test): 0.370, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.867, R2(test): 0.545
# inner CV: R2(test): 0.328, params: {'lgbmregressor__colsample_bytree': 0.6, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.842, R2(test): 0.504
# inner CV: R2(test): 0.332, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.809, R2(test): 0.590
# inner CV: R2(test): 0.243, params: {'lgbmregressor__colsample_bytree': 0.8, 'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 3, 'lgbmregressor__n_estimators': 200, 'lgbmregressor__subsample': 0.6}, outer CV R2(train): 0.825, R2(test): 0.641
# ...
# inner CV: R2(test): 0.224, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.750, R2(test): 0.554
# inner CV: R2(test): 0.167, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.772, R2(test): 0.599
# inner CV: R2(test): 0.293, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.695, R2(test): 0.480
# inner CV: R2(test): 0.292, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 7, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.782, R2(test): 0.562
# inner CV: R2(test): 0.227, params: {'histgradientboostingregressor__l2_regularization': 0.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.738, R2(test): 0.498
# inner CV: R2(test): 0.243, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.524, R2(test): 0.309
# inner CV: R2(test): 0.165, params: {'histgradientboostingregressor__l2_regularization': 0.1, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 3, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.448, R2(test): 0.360
# inner CV: R2(test): 0.309, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 1, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.540, R2(test): 0.330
# inner CV: R2(test): 0.245, params: {'histgradientboostingregressor__l2_regularization': 1.0, 'histgradientboostingregressor__learning_rate': 0.2, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.776, R2(test): 0.515
# [HistGB] total result = R2(train): 0.693, R2(test): 0.457
# ---------- KNN ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.288, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.459
# inner CV: R2(test): 0.333, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.263
# inner CV: R2(test): 0.337, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.014
# inner CV: R2(test): 0.272, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.379
# inner CV: R2(test): 0.353, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.202
# inner CV: R2(test): 0.356, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.372
# inner CV: R2(test): 0.254, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.356
# inner CV: R2(test): 0.297, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.320
# inner CV: R2(test): 0.284, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.263
# inner CV: R2(test): 0.261, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.287
# inner CV: R2(test): 0.278, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.428
# inner CV: R2(test): 0.339, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.317
# inner CV: R2(test): 0.334, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.498
# inner CV: R2(test): 0.279, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.252
# inner CV: R2(test): 0.306, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.391
# inner CV: R2(test): 0.292, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): -0.032
# inner CV: R2(test): 0.337, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.394
# inner CV: R2(test): 0.318, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.299
# inner CV: R2(test): 0.244, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.316
# inner CV: R2(test): 0.282, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.440
# inner CV: R2(test): 0.291, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.429
# inner CV: R2(test): 0.288, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 10, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.247
# inner CV: R2(test): 0.252, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.650
# inner CV: R2(test): 0.349, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.267
# inner CV: R2(test): 0.219, params: {'kneighborsregressor__metric': 'euclidean', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.253
# inner CV: R2(test): 0.331, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.243
# inner CV: R2(test): 0.292, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.485
# inner CV: R2(test): 0.221, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.521
# inner CV: R2(test): 0.335, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.323
# inner CV: R2(test): 0.325, params: {'kneighborsregressor__metric': 'manhattan', 'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__p': 1, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.097
# [KNN] total result = R2(train): 1.000, R2(test): 0.324
# ---------- MLP ----------
# params, R2(train), R2(test)
# inner CV: R2(test): 0.316, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.509, R2(test): 0.320
# inner CV: R2(test): 0.283, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.532, R2(test): 0.472
# inner CV: R2(test): 0.362, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.746, R2(test): 0.392
# inner CV: R2(test): 0.328, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.630, R2(test): 0.274
# inner CV: R2(test): 0.383, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.586, R2(test): 0.129
# inner CV: R2(test): 0.413, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.706, R2(test): 0.271
# inner CV: R2(test): 0.273, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.621, R2(test): 0.549
# inner CV: R2(test): 0.334, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.673, R2(test): 0.409
# inner CV: R2(test): 0.296, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.630, R2(test): 0.339
# inner CV: R2(test): 0.321, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.630, R2(test): 0.433
# inner CV: R2(test): 0.309, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.535, R2(test): 0.246
# inner CV: R2(test): 0.355, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.595, R2(test): 0.489
# inner CV: R2(test): 0.336, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.674, R2(test): 0.440
# inner CV: R2(test): 0.323, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.725, R2(test): 0.486
# inner CV: R2(test): 0.298, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.596, R2(test): 0.490
# inner CV: R2(test): 0.389, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.721, R2(test): 0.284
# inner CV: R2(test): 0.330, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.536, R2(test): 0.310
# inner CV: R2(test): 0.344, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.652, R2(test): 0.422
# inner CV: R2(test): 0.302, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.677, R2(test): 0.527
# inner CV: R2(test): 0.370, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.624, R2(test): 0.209
# inner CV: R2(test): 0.299, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.589, R2(test): 0.470
# inner CV: R2(test): 0.373, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.731, R2(test): 0.368
# inner CV: R2(test): 0.317, params: {'mlpregressor__alpha': 0.01, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.663, R2(test): 0.473
# inner CV: R2(test): 0.339, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.692, R2(test): 0.421
# inner CV: R2(test): 0.323, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.742, R2(test): 0.500
# inner CV: R2(test): 0.306, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50, 20), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.739, R2(test): 0.360
# inner CV: R2(test): 0.330, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.497, R2(test): 0.334
# inner CV: R2(test): 0.275, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.295, R2(test): 0.263
# inner CV: R2(test): 0.322, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.620, R2(test): 0.365
# inner CV: R2(test): 0.405, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,), 'mlpregressor__learning_rate_init': 0.001}, outer CV R2(train): 0.750, R2(test): 0.333
# [MLP] total result = R2(train): 0.631, R2(test): 0.379

# %%
from screening import *

df = pd.read_csv('Morgan_descriptors_revise.csv')
df2 = df.iloc[:,5:].dropna()
X = df2.iloc[:,:8]
y = df2.iloc[:,8]

# %%
y = df2.iloc[:,8]
X = df2.iloc[:,9:]

# %%
exe = True
run_screening(X, y)
# Out:
# ---------- Linear ----------
# # no-parameters
# total points = 1 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 90 (points)
# ----- 3 x 3 cross validation
# outer CV R2(train): 0.790, R2(test): 0.544
# outer CV R2(train): 0.814, R2(test): 0.438
# outer CV R2(train): 0.768, R2(test): 0.633
# outer CV R2(train): 0.747, R2(test): 0.679
# outer CV R2(train): 0.804, R2(test): 0.536
# outer CV R2(train): 0.804, R2(test): 0.523
# outer CV R2(train): 0.759, R2(test): 0.631
# outer CV R2(train): 0.794, R2(test): 0.538
# outer CV R2(train): 0.809, R2(test): 0.445
# outer CV R2(train): 0.763, R2(test): 0.565
# outer CV R2(train): 0.792, R2(test): 0.503
# outer CV R2(train): 0.826, R2(test): 0.473
# outer CV R2(train): 0.815, R2(test): 0.460
# outer CV R2(train): 0.792, R2(test): 0.475
# outer CV R2(train): 0.803, R2(test): 0.237
# outer CV R2(train): 0.779, R2(test): 0.515
# outer CV R2(train): 0.780, R2(test): 0.511
# outer CV R2(train): 0.809, R2(test): 0.452
# outer CV R2(train): 0.819, R2(test): 0.439
# outer CV R2(train): 0.765, R2(test): 0.584
# outer CV R2(train): 0.787, R2(test): 0.522
# outer CV R2(train): 0.774, R2(test): 0.614
# outer CV R2(train): 0.794, R2(test): 0.553
# outer CV R2(train): 0.790, R2(test): 0.573
# outer CV R2(train): 0.814, R2(test): 0.495
# outer CV R2(train): 0.821, R2(test): 0.310
# outer CV R2(train): 0.772, R2(test): 0.554
# outer CV R2(train): 0.746, R2(test): 0.695
# outer CV R2(train): 0.766, R2(test): 0.688
# outer CV R2(train): 0.825, R2(test): 0.513
# [Linear] total result = R2(train): 0.791, R2(test): 0.523
# running time: 1.2270 seconds
#
# ---------- Lasso ----------
# # alpha [0.001, 0.01, 0.1, 1, 10, 100]
# total points = 6 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 540 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.538, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.714, R2(test): 0.594
# 2, inner CV R2(test): 0.549, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.731, R2(test): 0.424
# 3, inner CV R2(test): 0.472, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.705, R2(test): 0.521
# 4, inner CV R2(test): 0.399, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.672, R2(test): 0.712
# 5, inner CV R2(test): 0.550, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.727, R2(test): 0.510
# 6, inner CV R2(test): 0.593, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.741, R2(test): 0.469
# 7, inner CV R2(test): 0.417, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.664, R2(test): 0.693
# 8, inner CV R2(test): 0.486, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.724, R2(test): 0.573
# 9, inner CV R2(test): 0.518, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.739, R2(test): 0.519
# 10, inner CV R2(test): 0.436, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.681, R2(test): 0.532
# 11, inner CV R2(test): 0.511, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.717, R2(test): 0.579
# 12, inner CV R2(test): 0.562, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.754, R2(test): 0.542
# 13, inner CV R2(test): 0.565, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.731, R2(test): 0.555
# 14, inner CV R2(test): 0.481, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.704, R2(test): 0.520
# 15, inner CV R2(test): 0.557, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.740, R2(test): 0.349
# 16, inner CV R2(test): 0.428, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.687, R2(test): 0.503
# 17, inner CV R2(test): 0.524, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.712, R2(test): 0.566
# 18, inner CV R2(test): 0.532, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.737, R2(test): 0.514
# 19, inner CV R2(test): 0.505, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.723, R2(test): 0.497
# 20, inner CV R2(test): 0.452, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.696, R2(test): 0.575
# 21, inner CV R2(test): 0.509, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.710, R2(test): 0.554
# 22, inner CV R2(test): 0.509, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.714, R2(test): 0.594
# 23, inner CV R2(test): 0.481, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.705, R2(test): 0.630
# 24, inner CV R2(test): 0.472, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.720, R2(test): 0.575
# 25, inner CV R2(test): 0.485, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.722, R2(test): 0.490
# 26, inner CV R2(test): 0.546, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.741, R2(test): 0.551
# 27, inner CV R2(test): 0.500, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.708, R2(test): 0.627
# 28, inner CV R2(test): 0.391, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.672, R2(test): 0.689
# 29, inner CV R2(test): 0.519, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.705, R2(test): 0.603
# 30, inner CV R2(test): 0.530, params: {'lasso__alpha': 0.1}, outer CV R2(train): 0.750, R2(test): 0.526
# [Lasso] total result = R2(train): 0.715, R2(test): 0.553
# running time: 9.2259 seconds
#
# ---------- Ridge ----------
# # alpha [0.001, 0.01, 0.1, 1, 10, 100]
# total points = 6 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 540 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.550, params: {'ridge__alpha': 100}, outer CV R2(train): 0.775, R2(test): 0.602
# 2, inner CV R2(test): 0.541, params: {'ridge__alpha': 100}, outer CV R2(train): 0.797, R2(test): 0.500
# 3, inner CV R2(test): 0.451, params: {'ridge__alpha': 100}, outer CV R2(train): 0.757, R2(test): 0.665
# 4, inner CV R2(test): 0.414, params: {'ridge__alpha': 100}, outer CV R2(train): 0.733, R2(test): 0.733
# 5, inner CV R2(test): 0.556, params: {'ridge__alpha': 100}, outer CV R2(train): 0.791, R2(test): 0.568
# 6, inner CV R2(test): 0.585, params: {'ridge__alpha': 100}, outer CV R2(train): 0.793, R2(test): 0.532
# 7, inner CV R2(test): 0.423, params: {'ridge__alpha': 100}, outer CV R2(train): 0.740, R2(test): 0.700
# 8, inner CV R2(test): 0.463, params: {'ridge__alpha': 100}, outer CV R2(train): 0.783, R2(test): 0.573
# 9, inner CV R2(test): 0.547, params: {'ridge__alpha': 100}, outer CV R2(train): 0.795, R2(test): 0.505
# 10, inner CV R2(test): 0.443, params: {'ridge__alpha': 100}, outer CV R2(train): 0.750, R2(test): 0.562
# 11, inner CV R2(test): 0.531, params: {'ridge__alpha': 100}, outer CV R2(train): 0.779, R2(test): 0.567
# 12, inner CV R2(test): 0.574, params: {'ridge__alpha': 100}, outer CV R2(train): 0.812, R2(test): 0.515
# 13, inner CV R2(test): 0.579, params: {'ridge__alpha': 100}, outer CV R2(train): 0.799, R2(test): 0.527
# 14, inner CV R2(test): 0.522, params: {'ridge__alpha': 100}, outer CV R2(train): 0.777, R2(test): 0.516
# 15, inner CV R2(test): 0.575, params: {'ridge__alpha': 100}, outer CV R2(train): 0.794, R2(test): 0.309
# 16, inner CV R2(test): 0.428, params: {'ridge__alpha': 100}, outer CV R2(train): 0.760, R2(test): 0.566
# 17, inner CV R2(test): 0.514, params: {'ridge__alpha': 100}, outer CV R2(train): 0.766, R2(test): 0.553
# 18, inner CV R2(test): 0.551, params: {'ridge__alpha': 100}, outer CV R2(train): 0.797, R2(test): 0.513
# 19, inner CV R2(test): 0.503, params: {'ridge__alpha': 100}, outer CV R2(train): 0.800, R2(test): 0.546
# 20, inner CV R2(test): 0.428, params: {'ridge__alpha': 100}, outer CV R2(train): 0.755, R2(test): 0.592
# 21, inner CV R2(test): 0.505, params: {'ridge__alpha': 100}, outer CV R2(train): 0.773, R2(test): 0.544
# 22, inner CV R2(test): 0.494, params: {'ridge__alpha': 100}, outer CV R2(train): 0.761, R2(test): 0.634
# 23, inner CV R2(test): 0.503, params: {'ridge__alpha': 100}, outer CV R2(train): 0.776, R2(test): 0.624
# 24, inner CV R2(test): 0.481, params: {'ridge__alpha': 100}, outer CV R2(train): 0.780, R2(test): 0.584
# 25, inner CV R2(test): 0.513, params: {'ridge__alpha': 100}, outer CV R2(train): 0.802, R2(test): 0.537
# 26, inner CV R2(test): 0.587, params: {'ridge__alpha': 100}, outer CV R2(train): 0.805, R2(test): 0.420
# 27, inner CV R2(test): 0.497, params: {'ridge__alpha': 100}, outer CV R2(train): 0.757, R2(test): 0.630
# 28, inner CV R2(test): 0.380, params: {'ridge__alpha': 100}, outer CV R2(train): 0.734, R2(test): 0.716
# 29, inner CV R2(test): 0.471, params: {'ridge__alpha': 100}, outer CV R2(train): 0.758, R2(test): 0.668
# 30, inner CV R2(test): 0.583, params: {'ridge__alpha': 100}, outer CV R2(train): 0.809, R2(test): 0.542
# [Ridge] total result = R2(train): 0.777, R2(test): 0.568
# running time: 8.9220 seconds
#
# ---------- ElasticNet ----------
# # alpha [0.01, 0.1, 1, 10]
# # l1_ratio [0.2, 0.5, 0.8]
# total points = 12 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 1080 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.561, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.761, R2(test): 0.610
# 2, inner CV R2(test): 0.563, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.777, R2(test): 0.480
# 3, inner CV R2(test): 0.472, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.724, R2(test): 0.609
# 4, inner CV R2(test): 0.401, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.693, R2(test): 0.723
# 5, inner CV R2(test): 0.575, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.775, R2(test): 0.553
# 6, inner CV R2(test): 0.601, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.758, R2(test): 0.487
# 7, inner CV R2(test): 0.426, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.688, R2(test): 0.706
# 8, inner CV R2(test): 0.483, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.743, R2(test): 0.592
# 9, inner CV R2(test): 0.538, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.779, R2(test): 0.535
# 10, inner CV R2(test): 0.446, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.703, R2(test): 0.556
# 11, inner CV R2(test): 0.521, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.763, R2(test): 0.591
# 12, inner CV R2(test): 0.580, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.798, R2(test): 0.549
# 13, inner CV R2(test): 0.587, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.783, R2(test): 0.560
# 14, inner CV R2(test): 0.506, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.756, R2(test): 0.561
# 15, inner CV R2(test): 0.573, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.757, R2(test): 0.354
# 16, inner CV R2(test): 0.424, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.741, R2(test): 0.554
# 17, inner CV R2(test): 0.532, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.729, R2(test): 0.577
# 18, inner CV R2(test): 0.561, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.785, R2(test): 0.532
# 19, inner CV R2(test): 0.508, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.746, R2(test): 0.531
# 20, inner CV R2(test): 0.455, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.716, R2(test): 0.600
# 21, inner CV R2(test): 0.509, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.728, R2(test): 0.579
# 22, inner CV R2(test): 0.514, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.731, R2(test): 0.607
# 23, inner CV R2(test): 0.493, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.757, R2(test): 0.654
# 24, inner CV R2(test): 0.477, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.738, R2(test): 0.589
# 25, inner CV R2(test): 0.508, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.782, R2(test): 0.534
# 26, inner CV R2(test): 0.567, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.785, R2(test): 0.494
# 27, inner CV R2(test): 0.502, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.727, R2(test): 0.633
# 28, inner CV R2(test): 0.396, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.691, R2(test): 0.706
# 29, inner CV R2(test): 0.520, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.8}, outer CV R2(train): 0.722, R2(test): 0.626
# 30, inner CV R2(test): 0.559, params: {'elasticnet__alpha': 0.1, 'elasticnet__l1_ratio': 0.5}, outer CV R2(train): 0.797, R2(test): 0.548
# [ElasticNet] total result = R2(train): 0.748, R2(test): 0.574
# running time: 13.6242 seconds
#
# ---------- PolyRidge ----------
# # degree [2, 3]
# # alpha [0.001, 0.01, 0.1, 1, 10, 100]
# total points = 12 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 1080 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.427, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.892, R2(test): 0.589
# 2, inner CV R2(test): 0.461, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.908, R2(test): 0.354
# 3, inner CV R2(test): 0.365, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.878, R2(test): 0.427
# 4, inner CV R2(test): 0.347, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.869, R2(test): 0.436
# 5, inner CV R2(test): 0.407, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.889, R2(test): 0.469
# 6, inner CV R2(test): 0.433, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.894, R2(test): 0.433
# 7, inner CV R2(test): 0.287, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.846, R2(test): 0.559
# 8, inner CV R2(test): 0.394, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.912, R2(test): 0.470
# 9, inner CV R2(test): 0.423, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.899, R2(test): 0.327
# 10, inner CV R2(test): 0.333, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.883, R2(test): 0.379
# 11, inner CV R2(test): 0.392, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.891, R2(test): 0.436
# 12, inner CV R2(test): 0.415, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.914, R2(test): 0.373
# 13, inner CV R2(test): 0.401, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.892, R2(test): 0.577
# 14, inner CV R2(test): 0.415, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.873, R2(test): 0.237
# 15, inner CV R2(test): 0.450, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.907, R2(test): 0.258
# 16, inner CV R2(test): 0.268, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.840, R2(test): 0.437
# 17, inner CV R2(test): 0.392, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.903, R2(test): 0.507
# 18, inner CV R2(test): 0.413, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.891, R2(test): 0.577
# 19, inner CV R2(test): 0.372, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.904, R2(test): 0.314
# 20, inner CV R2(test): 0.376, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.884, R2(test): 0.479
# 21, inner CV R2(test): 0.432, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.906, R2(test): 0.282
# 22, inner CV R2(test): 0.356, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.883, R2(test): 0.422
# 23, inner CV R2(test): 0.379, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.871, R2(test): 0.707
# 24, inner CV R2(test): 0.400, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.900, R2(test): 0.496
# 25, inner CV R2(test): 0.349, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.908, R2(test): 0.409
# 26, inner CV R2(test): 0.539, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.915, R2(test): 0.055
# 27, inner CV R2(test): 0.406, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.884, R2(test): 0.483
# 28, inner CV R2(test): 0.352, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.892, R2(test): 0.552
# 29, inner CV R2(test): 0.370, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.890, R2(test): 0.537
# 30, inner CV R2(test): 0.443, params: {'polynomialfeatures__degree': 2, 'ridge__alpha': 100}, outer CV R2(train): 0.885, R2(test): 0.438
# [PolyRidge] total result = R2(train): 0.890, R2(test): 0.434
# running time: 13.4704 seconds
#
# ---------- GPR ----------
# # n_components [10, 20, 30]
# # alpha [1e-06, 1e-05, 0.0001]
# # kernel [RBF(length_scale=0.1), RBF(length_scale=1), RBF(length_scale=10)]
# total points = 27 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 2430 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.187, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.500
# 2, inner CV R2(test): 0.310, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.261
# 3, inner CV R2(test): 0.248, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.051
# 4, inner CV R2(test): 0.218, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.304
# 5, inner CV R2(test): 0.422, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.053
# 6, inner CV R2(test): 0.277, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.272
# 7, inner CV R2(test): 0.159, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.460
# 8, inner CV R2(test): 0.270, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.390
# 9, inner CV R2(test): 0.341, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): -0.154
# 10, inner CV R2(test): 0.165, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.257
# 11, inner CV R2(test): 0.238, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.272
# 12, inner CV R2(test): 0.416, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.349
# 13, inner CV R2(test): 0.417, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.266
# 14, inner CV R2(test): 0.200, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.199
# 15, inner CV R2(test): 0.236, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.359
# 16, inner CV R2(test): 0.028, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.098
# 17, inner CV R2(test): 0.303, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.376
# 18, inner CV R2(test): 0.420, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.103
# 19, inner CV R2(test): 0.247, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.397
# 20, inner CV R2(test): 0.259, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.195
# 21, inner CV R2(test): 0.283, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.360
# 22, inner CV R2(test): 0.241, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.336
# 23, inner CV R2(test): 0.190, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.336
# 24, inner CV R2(test): 0.317, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.250
# 25, inner CV R2(test): 0.421, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.323
# 26, inner CV R2(test): 0.275, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.146
# 27, inner CV R2(test): 0.208, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.352
# 28, inner CV R2(test): 0.259, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.148
# 29, inner CV R2(test): 0.205, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.349
# 30, inner CV R2(test): 0.424, params: {'gaussianprocessregressor__alpha': 0.0001, 'gaussianprocessregressor__kernel': RBF(length_scale=1), 'pca__n_components': 20}, outer CV R2(train): 1.000, R2(test): 0.198
# [GPR] total result = R2(train): 1.000, R2(test): 0.260
# running time: 24.2304 seconds
#
# ---------- RandomForest ----------
# # n_estimators [50, 75, 100]
# # max_depth [5, 10]
# total points = 6 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 540 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.533, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.927, R2(test): 0.646
# 2, inner CV R2(test): 0.525, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.938, R2(test): 0.531
# 3, inner CV R2(test): 0.473, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.869, R2(test): 0.409
# 4, inner CV R2(test): 0.429, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.926, R2(test): 0.713
# 5, inner CV R2(test): 0.565, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.945, R2(test): 0.515
# 6, inner CV R2(test): 0.583, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.944, R2(test): 0.524
# 7, inner CV R2(test): 0.439, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.932, R2(test): 0.695
# 8, inner CV R2(test): 0.493, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.937, R2(test): 0.611
# 9, inner CV R2(test): 0.509, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.943, R2(test): 0.517
# 10, inner CV R2(test): 0.457, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.933, R2(test): 0.548
# 11, inner CV R2(test): 0.430, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.921, R2(test): 0.701
# 12, inner CV R2(test): 0.581, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.945, R2(test): 0.536
# 13, inner CV R2(test): 0.587, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.945, R2(test): 0.550
# 14, inner CV R2(test): 0.477, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 50}, outer CV R2(train): 0.928, R2(test): 0.526
# 15, inner CV R2(test): 0.553, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.935, R2(test): 0.524
# 16, inner CV R2(test): 0.390, params: {'randomforestregressor__max_depth': 5, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.824, R2(test): 0.531
# 17, inner CV R2(test): 0.488, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.925, R2(test): 0.641
# 18, inner CV R2(test): 0.562, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.946, R2(test): 0.573
# 19, inner CV R2(test): 0.456, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.931, R2(test): 0.533
# 20, inner CV R2(test): 0.509, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.940, R2(test): 0.554
# 21, inner CV R2(test): 0.522, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.937, R2(test): 0.568
# 22, inner CV R2(test): 0.489, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.935, R2(test): 0.611
# 23, inner CV R2(test): 0.465, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.932, R2(test): 0.719
# 24, inner CV R2(test): 0.512, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.940, R2(test): 0.571
# 25, inner CV R2(test): 0.524, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.944, R2(test): 0.530
# 26, inner CV R2(test): 0.561, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.939, R2(test): 0.410
# 27, inner CV R2(test): 0.509, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 75}, outer CV R2(train): 0.935, R2(test): 0.663
# 28, inner CV R2(test): 0.438, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.938, R2(test): 0.706
# 29, inner CV R2(test): 0.474, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.935, R2(test): 0.613
# 30, inner CV R2(test): 0.536, params: {'randomforestregressor__max_depth': 10, 'randomforestregressor__n_estimators': 100}, outer CV R2(train): 0.941, R2(test): 0.569
# [RandomForest] total result = R2(train): 0.930, R2(test): 0.578
# running time: 24.3006 seconds
#
# ---------- SVR ----------
# # C [0.1, 1, 10]
# # epsilon [0.5, 1.0]
# # gamma ['scale', 'auto']
# total points = 12 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 1080 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.530, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.818, R2(test): 0.678
# 2, inner CV R2(test): 0.555, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.852, R2(test): 0.545
# 3, inner CV R2(test): 0.538, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.896, R2(test): 0.663
# 4, inner CV R2(test): 0.500, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.890, R2(test): 0.732
# 5, inner CV R2(test): 0.590, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.845, R2(test): 0.593
# 6, inner CV R2(test): 0.592, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.844, R2(test): 0.505
# 7, inner CV R2(test): 0.467, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.879, R2(test): 0.669
# 8, inner CV R2(test): 0.511, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.851, R2(test): 0.660
# 9, inner CV R2(test): 0.585, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.847, R2(test): 0.514
# 10, inner CV R2(test): 0.467, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.806, R2(test): 0.549
# 11, inner CV R2(test): 0.557, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.827, R2(test): 0.633
# 12, inner CV R2(test): 0.625, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.861, R2(test): 0.517
# 13, inner CV R2(test): 0.612, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.895, R2(test): 0.520
# 14, inner CV R2(test): 0.530, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.822, R2(test): 0.539
# 15, inner CV R2(test): 0.582, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.847, R2(test): 0.458
# 16, inner CV R2(test): 0.481, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.884, R2(test): 0.589
# 17, inner CV R2(test): 0.533, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.824, R2(test): 0.639
# 18, inner CV R2(test): 0.624, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.856, R2(test): 0.530
# 19, inner CV R2(test): 0.520, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.842, R2(test): 0.631
# 20, inner CV R2(test): 0.507, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.899, R2(test): 0.557
# 21, inner CV R2(test): 0.543, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.835, R2(test): 0.563
# 22, inner CV R2(test): 0.558, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.830, R2(test): 0.660
# 23, inner CV R2(test): 0.499, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.885, R2(test): 0.669
# 24, inner CV R2(test): 0.541, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.894, R2(test): 0.599
# 25, inner CV R2(test): 0.579, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.857, R2(test): 0.597
# 26, inner CV R2(test): 0.587, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.861, R2(test): 0.435
# 27, inner CV R2(test): 0.502, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.817, R2(test): 0.633
# 28, inner CV R2(test): 0.485, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.888, R2(test): 0.644
# 29, inner CV R2(test): 0.522, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'scale'}, outer CV R2(train): 0.897, R2(test): 0.645
# 30, inner CV R2(test): 0.602, params: {'svr__C': 10, 'svr__epsilon': 0.5, 'svr__gamma': 'auto'}, outer CV R2(train): 0.845, R2(test): 0.591
# [SVR] total result = R2(train): 0.857, R2(test): 0.592
# running time: 12.6557 seconds
#
# ---------- XGBoost ----------
# # learning_rate [0.05, 0.1]
# # max_depth [5, 10]
# # n_estimators [100, 200]
# total points = 8 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 720 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.543, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.938, R2(test): 0.643
# 2, inner CV R2(test): 0.543, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.945, R2(test): 0.556
# 3, inner CV R2(test): 0.508, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.956, R2(test): 0.525
# 4, inner CV R2(test): 0.477, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.932, R2(test): 0.721
# 5, inner CV R2(test): 0.592, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.953, R2(test): 0.547
# 6, inner CV R2(test): 0.605, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.957, R2(test): 0.490
# 7, inner CV R2(test): 0.451, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.934, R2(test): 0.718
# 8, inner CV R2(test): 0.527, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.941, R2(test): 0.618
# 9, inner CV R2(test): 0.544, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.958, R2(test): 0.529
# 10, inner CV R2(test): 0.480, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.950, R2(test): 0.591
# 11, inner CV R2(test): 0.464, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.938, R2(test): 0.703
# 12, inner CV R2(test): 0.613, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.957, R2(test): 0.553
# 13, inner CV R2(test): 0.618, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.958, R2(test): 0.560
# 14, inner CV R2(test): 0.512, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.949, R2(test): 0.537
# 15, inner CV R2(test): 0.565, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.949, R2(test): 0.553
# 16, inner CV R2(test): 0.398, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.935, R2(test): 0.609
# 17, inner CV R2(test): 0.505, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.953, R2(test): 0.671
# 18, inner CV R2(test): 0.601, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.959, R2(test): 0.569
# 19, inner CV R2(test): 0.492, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.946, R2(test): 0.559
# 20, inner CV R2(test): 0.525, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 10, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.983, R2(test): 0.561
# 21, inner CV R2(test): 0.543, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.956, R2(test): 0.631
# 22, inner CV R2(test): 0.523, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.949, R2(test): 0.640
# 23, inner CV R2(test): 0.492, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.948, R2(test): 0.705
# 24, inner CV R2(test): 0.544, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.954, R2(test): 0.594
# 25, inner CV R2(test): 0.575, params: {'xgbregressor__learning_rate': 0.1, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.987, R2(test): 0.595
# 26, inner CV R2(test): 0.577, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.949, R2(test): 0.514
# 27, inner CV R2(test): 0.525, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.943, R2(test): 0.652
# 28, inner CV R2(test): 0.453, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.949, R2(test): 0.694
# 29, inner CV R2(test): 0.490, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.943, R2(test): 0.666
# 30, inner CV R2(test): 0.582, params: {'xgbregressor__learning_rate': 0.05, 'xgbregressor__max_depth': 5, 'xgbregressor__n_estimators': 100}, outer CV R2(train): 0.963, R2(test): 0.571
# [XGBoost] total result = R2(train): 0.951, R2(test): 0.602
# running time: 45.6756 seconds
#
# ---------- LightGBM ----------
# # learning_rate [0.05, 0.1]
# # max_depth [5, 10]
# # n_estimators [100, 200]
# total points = 8 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 720 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.353, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.826, R2(test): 0.525
# 2, inner CV R2(test): 0.388, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 100}, outer CV R2(train): 0.760, R2(test): 0.528
# 3, inner CV R2(test): 0.470, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.833, R2(test): 0.444
# 4, inner CV R2(test): 0.278, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.772, R2(test): 0.697
# 5, inner CV R2(test): 0.465, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.831, R2(test): 0.454
# 6, inner CV R2(test): 0.468, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.849, R2(test): 0.444
# 7, inner CV R2(test): 0.241, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.801, R2(test): 0.613
# 8, inner CV R2(test): 0.423, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.833, R2(test): 0.376
# 9, inner CV R2(test): 0.463, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.819, R2(test): 0.533
# 10, inner CV R2(test): 0.366, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 100}, outer CV R2(train): 0.723, R2(test): 0.559
# 11, inner CV R2(test): 0.322, params: {'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.751, R2(test): 0.597
# 12, inner CV R2(test): 0.430, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.843, R2(test): 0.458
# 13, inner CV R2(test): 0.455, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.836, R2(test): 0.408
# 14, inner CV R2(test): 0.407, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.828, R2(test): 0.412
# 15, inner CV R2(test): 0.331, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.823, R2(test): 0.489
# 16, inner CV R2(test): 0.236, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.757, R2(test): 0.532
# 17, inner CV R2(test): 0.415, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.804, R2(test): 0.536
# 18, inner CV R2(test): 0.397, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.857, R2(test): 0.315
# 19, inner CV R2(test): 0.295, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.820, R2(test): 0.385
# 20, inner CV R2(test): 0.387, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.807, R2(test): 0.431
# 21, inner CV R2(test): 0.399, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.853, R2(test): 0.538
# 22, inner CV R2(test): 0.371, params: {'lgbmregressor__learning_rate': 0.05, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.730, R2(test): 0.489
# 23, inner CV R2(test): 0.314, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.813, R2(test): 0.583
# 24, inner CV R2(test): 0.402, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.821, R2(test): 0.584
# 25, inner CV R2(test): 0.434, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.827, R2(test): 0.492
# 26, inner CV R2(test): 0.378, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.825, R2(test): 0.437
# 27, inner CV R2(test): 0.400, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.821, R2(test): 0.565
# 28, inner CV R2(test): 0.366, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.816, R2(test): 0.648
# 29, inner CV R2(test): 0.338, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 100}, outer CV R2(train): 0.714, R2(test): 0.554
# 30, inner CV R2(test): 0.425, params: {'lgbmregressor__learning_rate': 0.1, 'lgbmregressor__max_depth': 5, 'lgbmregressor__n_estimators': 200}, outer CV R2(train): 0.849, R2(test): 0.491
# [LightGBM] total result = R2(train): 0.808, R2(test): 0.504
# running time: 95.7177 seconds
#
# ---------- HistGB ----------
# # learning_rate [0.05, 0.1]
# # max_depth [5, 10]
# # max_iter [100, 200]
# total points = 8 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 720 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.248, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.441, R2(test): 0.406
# 2, inner CV R2(test): 0.324, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.714, R2(test): 0.454
# 3, inner CV R2(test): 0.356, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.731, R2(test): 0.373
# 4, inner CV R2(test): 0.167, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.507, R2(test): 0.567
# 5, inner CV R2(test): 0.334, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.736, R2(test): 0.408
# 6, inner CV R2(test): 0.402, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.704, R2(test): 0.426
# 7, inner CV R2(test): 0.153, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.565, R2(test): 0.575
# 8, inner CV R2(test): 0.328, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.711, R2(test): 0.405
# 9, inner CV R2(test): 0.378, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.575, R2(test): 0.371
# 10, inner CV R2(test): 0.271, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.683, R2(test): 0.518
# 11, inner CV R2(test): 0.269, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.724, R2(test): 0.540
# 12, inner CV R2(test): 0.341, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.794, R2(test): 0.382
# 13, inner CV R2(test): 0.331, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.607, R2(test): 0.317
# 14, inner CV R2(test): 0.314, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.737, R2(test): 0.466
# 15, inner CV R2(test): 0.224, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.656, R2(test): 0.567
# 16, inner CV R2(test): 0.204, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.561, R2(test): 0.420
# 17, inner CV R2(test): 0.353, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.719, R2(test): 0.382
# 18, inner CV R2(test): 0.310, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.621, R2(test): 0.367
# 19, inner CV R2(test): 0.183, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.677, R2(test): 0.418
# 20, inner CV R2(test): 0.332, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.712, R2(test): 0.523
# 21, inner CV R2(test): 0.288, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.706, R2(test): 0.403
# 22, inner CV R2(test): 0.317, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.587, R2(test): 0.461
# 23, inner CV R2(test): 0.213, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.712, R2(test): 0.575
# 24, inner CV R2(test): 0.319, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.629, R2(test): 0.406
# 25, inner CV R2(test): 0.359, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.648, R2(test): 0.365
# 26, inner CV R2(test): 0.290, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.725, R2(test): 0.571
# 27, inner CV R2(test): 0.288, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.688, R2(test): 0.517
# 28, inner CV R2(test): 0.271, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.687, R2(test): 0.620
# 29, inner CV R2(test): 0.306, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 10, 'histgradientboostingregressor__max_iter': 200}, outer CV R2(train): 0.538, R2(test): 0.403
# 30, inner CV R2(test): 0.309, params: {'histgradientboostingregressor__learning_rate': 0.1, 'histgradientboostingregressor__max_depth': 5, 'histgradientboostingregressor__max_iter': 100}, outer CV R2(train): 0.755, R2(test): 0.496
# [HistGB] total result = R2(train): 0.662, R2(test): 0.457
# running time: 332.6074 seconds
#
# ---------- KNN ----------
# # n_neighbors [3, 5, 7]
# # weights ['uniform', 'distance']
# total points = 6 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 540 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): 0.376, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.503
# 2, inner CV R2(test): 0.388, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.338
# 3, inner CV R2(test): 0.413, params: {'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.366
# 4, inner CV R2(test): 0.355, params: {'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.485
# 5, inner CV R2(test): 0.472, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.339
# 6, inner CV R2(test): 0.401, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.572
# 7, inner CV R2(test): 0.354, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.549
# 8, inner CV R2(test): 0.314, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.470
# 9, inner CV R2(test): 0.489, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.234
# 10, inner CV R2(test): 0.316, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.437
# 11, inner CV R2(test): 0.422, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.419
# 12, inner CV R2(test): 0.391, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.519
# 13, inner CV R2(test): 0.490, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.361
# 14, inner CV R2(test): 0.387, params: {'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.421
# 15, inner CV R2(test): 0.407, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.399
# 16, inner CV R2(test): 0.282, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.416
# 17, inner CV R2(test): 0.405, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.494
# 18, inner CV R2(test): 0.438, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.396
# 19, inner CV R2(test): 0.376, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.404
# 20, inner CV R2(test): 0.365, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.284
# 21, inner CV R2(test): 0.396, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.406
# 22, inner CV R2(test): 0.372, params: {'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.492
# 23, inner CV R2(test): 0.320, params: {'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.571
# 24, inner CV R2(test): 0.419, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.398
# 25, inner CV R2(test): 0.363, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.415
# 26, inner CV R2(test): 0.501, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.277
# 27, inner CV R2(test): 0.311, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.574
# 28, inner CV R2(test): 0.315, params: {'kneighborsregressor__n_neighbors': 7, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.588
# 29, inner CV R2(test): 0.362, params: {'kneighborsregressor__n_neighbors': 5, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.636
# 30, inner CV R2(test): 0.491, params: {'kneighborsregressor__n_neighbors': 3, 'kneighborsregressor__weights': 'distance'}, outer CV R2(train): 1.000, R2(test): 0.257
# [KNN] total result = R2(train): 1.000, R2(test): 0.434
# running time: 10.8302 seconds
#
# ---------- MLP ----------
# # hidden_layer_sizes [(50,), (100,)]
# # alpha [0.0001, 0.001]
# total points = 4 (grid search) x 10 (n_repeats) x 3 (inner-CV) x 3 (outer-CV) = 360 (points)
# ----- 3 x 3 cross validation
# 1, inner CV R2(test): -0.059, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.720, R2(test): 0.459
# 2, inner CV R2(test): 0.172, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.821, R2(test): 0.385
# 3, inner CV R2(test): 0.032, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): 0.846, R2(test): 0.419
# 4, inner CV R2(test): -0.072, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.753, R2(test): 0.639
# 5, inner CV R2(test): -0.208, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.846, R2(test): 0.507
# 6, inner CV R2(test): 0.337, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): 0.838, R2(test): 0.318
# 7, inner CV R2(test): -0.377, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): -5.014, R2(test): -3.832
# 8, inner CV R2(test): 0.009, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): 0.860, R2(test): 0.438
# 9, inner CV R2(test): 0.138, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.892, R2(test): 0.165
# 10, inner CV R2(test): 0.054, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.617, R2(test): 0.188
# 11, inner CV R2(test): 0.068, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): 0.800, R2(test): 0.400
# 12, inner CV R2(test): -0.030, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.795, R2(test): 0.356
# 13, inner CV R2(test): 0.115, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.862, R2(test): 0.270
# 14, inner CV R2(test): 0.114, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): 0.863, R2(test): 0.372
# 15, inner CV R2(test): -0.010, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.951, R2(test): 0.472
# 16, inner CV R2(test): -0.130, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): -0.843, R2(test): -1.639
# 17, inner CV R2(test): 0.137, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.756, R2(test): 0.358
# 18, inner CV R2(test): 0.180, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.782, R2(test): 0.360
# 19, inner CV R2(test): 0.028, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.596, R2(test): -0.087
# 20, inner CV R2(test): 0.185, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): 0.809, R2(test): 0.462
# 21, inner CV R2(test): 0.114, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.894, R2(test): 0.326
# 22, inner CV R2(test): 0.116, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): 0.743, R2(test): 0.339
# 23, inner CV R2(test): -0.161, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.920, R2(test): 0.477
# 24, inner CV R2(test): -0.020, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.900, R2(test): 0.406
# 25, inner CV R2(test): -0.119, params: {'mlpregressor__alpha': 0.0001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.934, R2(test): 0.138
# 26, inner CV R2(test): 0.309, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.729, R2(test): 0.285
# 27, inner CV R2(test): 0.214, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.825, R2(test): 0.655
# 28, inner CV R2(test): -0.183, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): 0.780, R2(test): 0.517
# 29, inner CV R2(test): -0.062, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (100,)}, outer CV R2(train): 0.853, R2(test): 0.448
# 30, inner CV R2(test): 0.305, params: {'mlpregressor__alpha': 0.001, 'mlpregressor__hidden_layer_sizes': (50,)}, outer CV R2(train): 0.899, R2(test): 0.180
# [MLP] total result = R2(train): 0.568, R2(test): 0.159
# running time: 62.3888 seconds
